# %% [markdown]
# <h1><center><img src="https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true" width="240" height="360" /><centre><h1>

# %% [markdown]
# <h1><center> MACHINE LEARNING ON AUTOMOBILE CO2 EMISSIONS<h1>
#
# <img src="https://images3.alphacoders.com/890/thumb-1920-89045.jpg"/>

# %% [markdown]
# ## Table of Contents
#
# 1. [Introduction](#section1)<br>
#     - 1.1[Fuel consumption testing & determination of CO2 emissions](#section11)<br>
#     - 1.2[Data Collection](#section12)<br>
# 2. [Problem Statement](#section2)<br>
# 3. [Selecting the important Python libraries](#section3)<br>
# 4. [Data Loading and Description](#section4)<br>
#     - 4.1[Data Loading](#section41)<br>
#     - 4.2[Description of the data](#section42)<br>
# 5. [Exploratory Data Analysis](#section5)<br>
#     - 5.1[Basic understanding of columns and dropping unwanted columns](#section51)<br>
#     - 5.2[Pandas Profiling](#section52)<br>
#     - 5.3[Removing Duplicate Entries](#section53)<br>
#     - 5.4[Understanding the distribution of each columns](#section54)<br>
#         - 5.4.1[MAKE](#section541)<br>
#         - 5.4.2[VEHICLE CLASS](#section542)<br>
#         - 5.4.3[ENGINE SIZE](#section543)<br>
#         - 5.4.4[CYLINDERS](#section544)<br>
#         - 5.4.5[TRANSMISSION](#section545)<br>
#         - 5.4.6[FUEL TYPE](#section546)<br>
#         - 5.4.7[FUEL CONSUMPTION CITY](#section547)<br>
#         - 5.4.8[FUEL CONSUMPTION HIGHWAY](#section548)<br>
#         - 5.4.9[FUEL CONSUMPTION COMBINATION](#section549)<br>
#         - 5.4.10[CO2 EMISSIONS](#section5410)<br>
#         - 5.4.11[PAIR PLOT](#section5411)<br>
#         - 5.4.12[HEAT MAP](section5412)<br>
#         - 5.4.13[Conclusion of EDA](#section5412)<br>
# 6. [Linear Regression](#section6)<br>
#     - 6.1[Data Preparation for ML](#section61)<br>
#     - 6.1[LINEAR REGRESSION ASSUMPTIONS¶](#section62)<br>
#     - 6.3[Train Test Split](#section63)<br>
#     - 6.4[Data Scaling](#section64)<br>
#     - 6.5[Linear Regression](#section65)<br>
#         - 6.5.1[Linear Regression Equation Development](#section651)<br>
#         - 6.5.2[Plotting Predicted vs Actual](#section652)<br>
#         - 6.5.3[Finding out RMSE and Adjusted R-squared for Train and Test Linear Regression Model](#section653)<br>
#     - 6.6 [Summary of Linear Regression](#section66)<br>
# 7. [Decision Tree](#section7)<br>
#     - 7.1[Decision Tree Model 1](#section71)<br>
#         - 7.1.1[Model Development](#section711)<br>
#         - 7.1.2[Plotting the model](#section712)<br>
#         - 7.1.3[Finding out RMSE and Adjusted R-squared for Train and Test Linear Regression Model](#section713)<br>
#     - 7.2[Decision Tree Model 2](#section72)<br>
#         - 7.2.1[Model Development](#section721)<br>
#         - 7.2.2[Plotting the model](#section722)<br>
#         - 7.2.3[Finding out RMSE and Adjusted R-squared for Train and Test Linear Regression Model](#section723)<br>
#     - 7.3[Decision Tree GridSearchCV Model](#section73)<br>
#         - 7.3.1[Model Development](#section731)<br>
#         - 7.3.2[Plotting the model](#section732)<br>
#         - 7.3.3[Finding out RMSE and Adjusted R-squared for Train and Test Linear Regression Model](#section733)<br>
#     - 7.4[Summary of Decision Tree](#section74)<br>
# 8. [Random Forest Regressor](#section8)<br>
#     - 8.1[Random Forest Model 1](#section81)<br>
#         - 8.1.1[Model Development](#section811)<br>
#         - 8.1.2[Plotting the model](#section812)<br>
#         - 8.1.3[Finding out RMSE and Adjusted R-squared for Train and Test Linear Regression Model](#section813)<br>
#     - 8.2[Random Forest Model 2](#section82)<br>
#         - 8.2.1[Model Development](#section821)<br>
#         - 8.2.2[Plotting the model](#section822)<br>
#         - 8.2.3[Finding out RMSE and Adjusted R-squared for Train and Test Linear Regression Model](#section823)<br>
#     - 8.3[Random Forest Model 3](#section83)<br>
#         - 8.3.1[Model Development](#section831)<br>
#         - 8.3.2[Plotting the model](#section832)<br>
#         - 8.3.3[Finding out RMSE and Adjusted R-squared for Train and Test Linear Regression Model](#section833)<br>
#         - 8.3.4[Summary of Random Forest](#section834)<br>
# 9. [Conclusion](#section9)<br>

# %% [markdown]
# <a id=section1></a>

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# <a id=section11></a>

# %% [markdown]
# ### 1.1 Fuel consumption testing & determination of CO2 emissions
# It would be difficult to drive every model of new vehicle on the road to measure fuel consumption and CO2 emission. And it would be impossible to get repeatable results that way because so many factors – road conditions and weather, to name just two – can affect a vehicle’s performance.
#
# That is why vehicle manufacturers use standard, controlled laboratory testing and analytical procedures to generate the fuel consumption data that appear on the **EnerGuide label** for vehicles.
#
# Environment and Climate Change Canada collects the data from vehicle manufacturers. Natural Resources Canada puts the data and other information together and publish the Fuel Consumption & CO2 emissions. We will be using the dataset published by Natural Resources Canada on

# %% [markdown]
# <a id=section12></a>

# %% [markdown]
# ###  1.2 Data Collection
#
#
# Manufacturers use the 2-cycle testing procedure, by testing vehicles under simulated city and highway conditions to find out how much fuel they use and what will be the CO2 emissions.
#
# **The city test** simulates urban driving in stop-and-go traffic with an average speed of 34 km/h and a top speed of 90 km/h. The test runs for approximately 31 minutes and includes 23 stops. The test begins from a cold engine start, which is similar to starting a vehicle after it has been parked overnight during the summer. The final phase of the test repeats the first eight minutes of the cycle but with a hot engine start. This simulates restarting a vehicle after it has been warmed up, driven and then stopped for a short time. Over five minutes of test time are spent idling, to represent waiting at traffic lights.
#
# The City test parameters are as under;
#
# |Parameter Name||Values|
# |---------||-----------|
# |Test Cell Temperature:|| 20°-30°C|
# |Total Time:|| 31 minutes, 14 seconds|
# |Distance: ||17.8 km|
# |Top Speed: ||90 km/h|
# |Average Speed:|| 34 km/h|
# |Maximum Acceleration: ||5.3 km/h per second|
# |Number of Stops:|| 23|
# |Idling Time: ||18% of total time|
# |Engine Start:|| Cold|
#
# **The highway test** simulates a mixture of open highway and rural road driving, with an average speed of 78 km/h and a top speed of 97 km/h. The test runs for approximately 13 minutes and does not include any stops. The test begins from a hot engine start.
#
# The Highway test parameters are as under;
#
# |Parameter Name||Variable|
# |--------------||---------|
# |Test Cell Temperature:||20°-30°C|
# |Total Time:||12 minutes, 45 seconds|
# |Distance:||16.5 km|
# |Top Speed:||97 km/h|
# |Average Speed:||78 km/h|
# |Maximum Acceleration:||5.2 km/h per second|
# |Number of Stops:||0|
# |Idling Time:||0|
# |Engine Start:||Warm|

# %% [markdown]
# <a id=section2></a>

# %% [markdown]
# ## 2. Problem Statement

# %% [markdown]
# Nowadays, one of the biggest challenges to face is the reduction of greenhouse gas (GHG) from the transport industry. In particular, the road transport sector accounts for about 80% of the whole energy demand required by transportation and, due to its reliance on fossil fuels, represents one of the most important sources of Greed House Gases emissions in the world.
#
# Here we have the dataset of new light duty vehicles for retail sale in Canada, where we have different Car models and their corresponding **CO2 emissions** when drove over Highway as well as on City roads.
#
# Using this Dataset let us try to find out the following;
# 1. What are the variables that directly influence the CO2 emissions?
# 2. Develop an equation which gives the relationship between the CO2 emissions and the variables that influence it?

# %% [markdown]
# <a id=section3></a>

# %% [markdown]
# ## 3. Selecting the important Python Libraries

# %%
import pandas as pd #Python library to import the dataset and work on it
pd.set_option('mode.chained_assignment', None)      # To suppress pandas warnings.
pd.set_option('display.max_colwidth', None)           # To display all the data in each column
pd.options.display.max_columns = 50                 # To display every column of the dataset in head()

import numpy as np # Python library to perform mathematical operations on the dataset
import matplotlib.pyplot as plt #Python library to plot the graphs
# %matplotlib inline 
import warnings
warnings.filterwarnings('ignore') #to ignore the errors which doesnt affect the output

# %%
import seaborn as sns #Python library to plot the graph
sns.set(style='whitegrid', font_scale=1.3, color_codes=True)      # To apply seaborn styles to the plots.
from pandas_profiling import ProfileReport

# %%
import sklearn as sk  #Python library to perfrom Linear Regression,Train Test Split error calculation etc

# %% [markdown]
# <a id=section4></a>

# %% [markdown]
# ## 4. Data Loading and Description

# %% [markdown]
# <a id=section41></a>

# %% [markdown]
# ### 4.1 Data Loading
#
# We have downloaded the dataset from the website https://www.canada.ca/en.html and uploaded in my public github repository. We will directly import the date from the repository using pandas as shown under

# %%
#importing the data from Github library
df=pd.read_csv('https://raw.githubusercontent.com/Avinash-Monteiro/Datasets/master/FuelConsumptionCo2.csv')
df.head(5) # to display the data
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# 1                   9.6                        29           221
# 2                   5.9                        48           136
# 3                  11.1                        25           255
# 4                  10.6                        27           244

# %% [markdown]
# <a id=section42></a>

# %% [markdown]
# ### 4.2 Description of the data

# %% [markdown]
# From the above **```df.head()```** function we have observed that there are 13 columns. The description of the individual columns are as under;
#
# |Column Name||Description|
# |------------||----------|
# |MODEL YEAR|| The year during which the car model was manufactured|
# |MAKE||Name of the Car Manufacturer. Eg., DODGE, BMW, AUDI, etc|
# |MODEL||Name of the Car Model eg., 4WD means 4 Wheel Drive|
# |VEHICLE CLASS||The type of Car;SUV,Compact, Two seater etc.|
# |ENGINESIZE||The Capacity of the engine. It is measured as total volume of the cylinders in the engine. It is measured in cc|
# |CYLINDERS||It generally denotes how many cylinders a vehicle has|
# |TRANSMISSION||It represents the type of gear system in Car. A stands for Automatic (A4, A5 etc) and M stands for Manual (M5, M7 etc)|
# |FUEL TYPE||It represents the type of fuel used in the car. The common types of fuel are X = Regular gasoline; Z = Premium gasoline; D = Diesel; E = E85;|
# |FUELCONSUMPTION_CITY||It is the Fuel consumed during City test. Its unit is Liters/100Km|
# |FUELCONSUMPTION_HWY||It is the Fuel consumed during Highway test. Its unit is Liters/100Km|
# |FUELCONSUMPTION_COMB||This reflects 55% of fuel consumption during City test + 45% of fuel consumption during Highway test|
# |FUELCONSUMPTION_COMB_MPG||It is the combined Fuel consumption in terms of Miles per Gallon. mpg=282.48/FUELCONSUMPTION_COMB|
# |CO2EMISSIONS||It is the Carbon-di-oxide emissions measured from tailpipe. Its unit is g/Km. This is our target variable|

# %% [markdown]
# <a id=section5></a>

# %% [markdown]
# ## 5. Exploratory Data Analysis

# %% [markdown]
# Now we have the dataset loaded and ready to use. We will not start with Exploratory data Analysis whereby we explore all the columns and also their relationship with other columns

# %% [markdown]
# <a id=section51></a>

# %% [markdown]
# ### 5.1 Basic understanding of columns and dropping unwanted columns

# %% [markdown]
# Checking the overview of the data through ```.info()``` and check for missing variables, type of cell etc.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   object
#  2   MODEL                     1067 non-null   object
#  3   VEHICLECLASS              1067 non-null   object
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   object
#  7   FUELTYPE                  1067 non-null   object
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 108.5+ KB

# %% [markdown]
# Observations from ```.info()``` are as under;
# - 1.There are no missing values in the dataset
# - 2.We have 13 columns and 1067 rows of data.
# - 3.Out of the 13 columns, 5 columns have objects and balance 8 columns are numerical
#
# Checking the flow of the 8 numerical columns using ```.describe()``` function as under;

# %%
df.describe(include='all')
# Out:
#         MODELYEAR  MAKE     MODEL VEHICLECLASS   ENGINESIZE    CYLINDERS  \
# count      1067.0  1067      1067         1067  1067.000000  1067.000000
# unique        NaN    39       663           16          NaN          NaN
# top           NaN  FORD  F150 FFV     MID-SIZE          NaN          NaN
# freq          NaN    90         8          178          NaN          NaN
# mean       2014.0   NaN       NaN          NaN     3.346298     5.794752
# std           0.0   NaN       NaN          NaN     1.415895     1.797447
# min        2014.0   NaN       NaN          NaN     1.000000     3.000000
# 25%        2014.0   NaN       NaN          NaN     2.000000     4.000000
# 50%        2014.0   NaN       NaN          NaN     3.400000     6.000000
# 75%        2014.0   NaN       NaN          NaN     4.300000     8.000000
# max        2014.0   NaN       NaN          NaN     8.400000    12.000000
#
#        TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# count          1067     1067           1067.000000          1067.000000
# unique           22        4                   NaN                  NaN
# top              A6        X                   NaN                  NaN
# freq            222      514                   NaN                  NaN
# mean            NaN      NaN             13.296532             9.474602
# std             NaN      NaN              4.101253             2.794510
# min             NaN      NaN              4.600000             4.900000
# 25%             NaN      NaN             10.250000             7.500000
# 50%             NaN      NaN             12.600000             8.800000
# 75%             NaN      NaN             15.550000            10.850000
# max             NaN      NaN             30.200000            20.500000
#
#         FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# count            1067.000000               1067.000000   1067.000000
# unique                   NaN                       NaN           NaN
# top                      NaN                       NaN           NaN
# freq                     NaN                       NaN           NaN
# mean               11.580881                 26.441425    256.228679
# std                 3.485595                  7.468702     63.372304
# min                 4.700000                 11.000000    108.000000
# 25%                 9.000000                 21.000000    207.000000
# 50%                10.900000                 26.000000    251.000000
# 75%                13.350000                 31.000000    294.000000
# max                25.800000                 60.000000    488.000000

# %% [markdown]
# Observations from ```.describe()``` are as under;
#
# - All the car models are manufactured during the year 2014. So **MODELYEAR** column is no use for us and hence we need to drop it.
# - **MODEL** column has 663 unique entries and we can drop this column as this will not be any use for developing model.
# - We will study the **VEHICLE CLASS, TRANSMISSION & FUELTYPE**  columns during EDA and decide whether to drop it.
# - **ENGINESIZE,CYLINDERS,FUELCONSUMPTION_CITY, FUELCONSUMPTION_HWY, FUELCONSUMPTION_COMB, FUELCONSUMPTION_COMB_MPG** are all looks like normally distributed
# - We will also drop **FUELCONSUMPTION_COMB_MPG** column as it is derived from **FUELCONSUMPTION_COMB** column.

# %% [markdown]
# #### Dropping unwanted columns

# %%
df.drop(columns=['MODELYEAR','FUELCONSUMPTION_COMB_MPG','MODEL'], axis=0, inplace=True)

# %% [markdown]
# After deleting the two columns, our dataset looks as under;

# %%
df.head()
# Out:
#     MAKE VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  \
# 0  ACURA      COMPACT         2.0          4          AS5        Z
# 1  ACURA      COMPACT         2.4          4           M6        Z
# 2  ACURA      COMPACT         1.5          4          AV7        Z
# 3  ACURA  SUV - SMALL         3.5          6          AS6        Z
# 4  ACURA  SUV - SMALL         3.5          6          AS6        Z
#
#    FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 0                   9.9                  6.7                   8.5
# 1                  11.2                  7.7                   9.6
# 2                   6.0                  5.8                   5.9
# 3                  12.7                  9.1                  11.1
# 4                  12.1                  8.7                  10.6
#
#    CO2EMISSIONS
# 0           196
# 1           221
# 2           136
# 3           255
# 4           244

# %% [markdown]
# <a id=section52></a>

# %% [markdown]
# ### 5.2 Pandas Profiling

# %%
profile=ProfileReport(df)
#profile.to_file('Automotive_data.html')

# %% [markdown]
# #### Observations from Pandas Profiling are as under;
# - There are **10** columns, 6 Numerical and 4 Categorical
# - There are no missing values in the data
# - Out of 1067 columns, there are 115 duplicate entries (about 10.8%)which needs to be dropped
# - CYLINDERS is highly correlated with ENGINESIZE
# - FUELCONSUMPTION_HWY is highly correlated with FUELCONSUMPTION_CITY and FUELCONSUMPTION_COMB.

# %% [markdown]
# <a id=section53></a>

# %% [markdown]
# ### 5.3 Removing duplicate entries

# %%
df=df.drop_duplicates()
df.reset_index()
# Out:
#      index   MAKE    VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION  \
# 0        0  ACURA         COMPACT         2.0          4          AS5
# 1        1  ACURA         COMPACT         2.4          4           M6
# 2        2  ACURA         COMPACT         1.5          4          AV7
# 3        3  ACURA     SUV - SMALL         3.5          6          AS6
# 4        4  ACURA     SUV - SMALL         3.5          6          AS6
# ..     ...    ...             ...         ...        ...          ...
# 947   1061  VOLVO     SUV - SMALL         3.2          6          AS6
# 948   1062  VOLVO     SUV - SMALL         3.0          6          AS6
# 949   1063  VOLVO     SUV - SMALL         3.2          6          AS6
# 950   1065  VOLVO     SUV - SMALL         3.2          6          AS6
# 951   1066  VOLVO  SUV - STANDARD         3.2          6          AS6
#
#     FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 0          Z                   9.9                  6.7                   8.5
# 1          Z                  11.2                  7.7                   9.6
# 2          Z                   6.0                  5.8                   5.9
# 3          Z                  12.7                  9.1                  11.1
# 4          Z                  12.1                  8.7                  10.6
# ..       ...                   ...                  ...                   ...
# 947        X                  13.0                  8.9                  11.2
# 948        X                  13.4                  9.8                  11.8
# 949        X                  13.2                  9.5                  11.5
# 950        X                  12.9                  9.3                  11.3
# 951        X                  14.9                 10.2                  12.8
#
#      CO2EMISSIONS
# 0             196
# 1             221
# 2             136
# 3             255
# 4             244
# ..            ...
# 947           258
# 948           271
# 949           264
# 950           260
# 951           294
#
# [952 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 952 entries, 0 to 1066
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   MAKE                  952 non-null    object
#  1   VEHICLECLASS          952 non-null    object
#  2   ENGINESIZE            952 non-null    float64
#  3   CYLINDERS             952 non-null    int64
#  4   TRANSMISSION          952 non-null    object
#  5   FUELTYPE              952 non-null    object
#  6   FUELCONSUMPTION_CITY  952 non-null    float64
#  7   FUELCONSUMPTION_HWY   952 non-null    float64
#  8   FUELCONSUMPTION_COMB  952 non-null    float64
#  9   CO2EMISSIONS          952 non-null    int64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 81.8+ KB

# %% [markdown]
# Ater removing all the duplicate values, we now have 952 rows of data for our analysis and model creation

# %% [markdown]
# <a id=section54></a>

# %% [markdown]
# ### 5.4 Understanding the distribution of each columns

# %% [markdown]
# <a id=section541></a>

# %% [markdown]
# #### 5.4.1 MAKE:

# %%
len(df['MAKE'].value_counts()) #checking the numbe of verities of car brands
# Out:
# 39

# %% [markdown]
# There are 39 verities of cars in the dataset

# %%
plt.figure(figsize=(12,12))
sns.countplot(y='MAKE',data=df,order=df['MAKE'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='MAKE'>

# %% [markdown]
# Out of the 39 varieties of cars, **FORD, CHEVROLET, BMW & MERCEDES-BENZ** are very common. 8% of the dataset contains the data only from **FORD** Cars.

# %% [markdown]
# #### MAKE v/s CO2 EMISSIONS

# %%
A=df[['MAKE','CO2EMISSIONS']]
B= A.groupby(by='MAKE').mean().sort_values(by='CO2EMISSIONS',ascending= False) # calculating the mean CO2 emissions for each brand
B
# Out:
#                CO2EMISSIONS
# MAKE
# LAMBORGHINI      394.000000
# SRT              389.000000
# ROLLS-ROYCE      383.166667
# BENTLEY          356.000000
# ASTON MARTIN     352.500000
# GMC              330.261905
# MASERATI         325.200000
# LAND ROVER       308.692308
# RAM              291.230769
# JAGUAR           284.400000
# CADILLAC         282.433333
# MERCEDES-BENZ    274.800000
# CHEVROLET        269.101266
# AUDI             268.536585
# LINCOLN          268.181818
# FORD             265.955556
# PORSCHE          262.500000
# JEEP             259.333333
# INFINITI         256.761905
# VOLVO            256.500000
# BMW              252.702128
# CHRYSLER         252.235294
# NISSAN           251.393939
# DODGE            249.324324
# LEXUS            244.095238
# BUICK            238.800000
# TOYOTA           233.895833
# ACURA            226.000000
# SUBARU           225.130435
# KIA              217.515152
# HYUNDAI          217.250000
# VOLKSWAGEN       216.000000
# MITSUBISHI       210.500000
# HONDA            203.714286
# SCION            198.888889
# MAZDA            195.400000
# MINI             184.666667
# FIAT             179.333333
# SMART            147.000000

# %%
plt.figure(figsize=(12,10))
sns.set(font_scale = 1)
sns.barplot(y=B.index, x=B['CO2EMISSIONS'],)
plt.xlabel('CO2 EMISSIONS in g/Km')
# Out:
# Text(0.5, 0, 'CO2 EMISSIONS in g/Km')

# %% [markdown]
# The top 10 car brands of Canada with highest amount of CO2 emissions are as under;
#
# - LAMBORGHINI
# - SRT
# - ROLLS-ROYCE
# - BENTLEY
# - ASTON MARTIN
# - GMC
# - MASERATI
# - LAND ROVER
# - RAM
# - JAGUAR

# %%
B.tail()
# Out:
#        CO2EMISSIONS
# MAKE
# SCION    198.888889
# MAZDA    195.400000
# MINI     184.666667
# FIAT     179.333333
# SMART    147.000000

# %% [markdown]
# Car Brands such as **GMC, MASERATI, LAND LOVER, RAM & JAGUAR** are better options as their CO2 emissions are lower

# %% [markdown]
# <a id=section542></a>

# %% [markdown]
# ####  5.4.2 VEHICLE CLASS

# %%
plt.figure(figsize=(8,8))
sns.countplot(y='VEHICLECLASS',data=df,order=df['VEHICLECLASS'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='VEHICLECLASS'>

# %%
df['VEHICLECLASS'].value_counts()
# Out:
# MID-SIZE                    167
# COMPACT                     151
# SUV - SMALL                 145
# SUV - STANDARD               92
# FULL-SIZE                    71
# PICKUP TRUCK - STANDARD      62
# SUBCOMPACT                   61
# TWO-SEATER                   51
# STATION WAGON - SMALL        36
# MINICOMPACT                  33
# VAN - PASSENGER              25
# VAN - CARGO                  20
# MINIVAN                      14
# PICKUP TRUCK - SMALL         12
# SPECIAL PURPOSE VEHICLE       7
# STATION WAGON - MID-SIZE      5
# Name: VEHICLECLASS, dtype: int64

# %% [markdown]
# From the above count plot and the table, we understand that out of 952 rows of data, the data of 463 columns are only for smaller economical cars

# %% [markdown]
# #### VEHICLECLASS v/s CO2EMISSIONS

# %%
C=df[['VEHICLECLASS','CO2EMISSIONS']]
D= C.groupby(by='VEHICLECLASS').mean().sort_values(by='CO2EMISSIONS',ascending= False).head(10)
D
# Out:
#                          CO2EMISSIONS
# VEHICLECLASS
# VAN - PASSENGER            401.000000
# VAN - CARGO                359.650000
# PICKUP TRUCK - STANDARD    309.096774
# SUV - STANDARD             307.282609
# PICKUP TRUCK - SMALL       284.250000
# FULL-SIZE                  264.521127
# TWO-SEATER                 263.941176
# MINIVAN                    260.142857
# SUBCOMPACT                 253.032787
# SUV - SMALL                243.434483

# %%
sns.light_palette("seagreen", as_cmap=True)
plt.figure(figsize=(8,8))
sns.barplot(y=D.index, x=D['CO2EMISSIONS'],)
plt.xlabel('CO2 EMISSIONS in g/Km')
# Out:
# Text(0.5, 0, 'CO2 EMISSIONS in g/Km')

# %% [markdown]
# The top 10 class of cars in Canada with highest amount of CO2 emissions are as under;
#
# - VAN - PASSENGER
# - VAN - CARGO
# - PICKUP TRUCK - STANDARD
# - SUV - STANDARD
# - PICKUP TRUCK - SMALL
# - FULL-SIZE
# - TWO-SEATER
# - MINIVAN
# - SUBCOMPACT
# - SUV - SMALL
#
# The compact SUV car models are better models for controlling CO2 emissions

# %% [markdown]
# <a id=section543></a>

# %% [markdown]
# #### 5.4.3 ENGINESIZE

# %% [markdown]
# Engine size is nothing but the capacity of the engine measured in terms of stroke length of the piston inside the cylinder of the engine.
# Let us plot the distribution of ENGINESIZE and understand the behaviour

# %%
sns.distplot(df['ENGINESIZE'])
plt.xlabel('ENGINESIZE in cc')
# Out:
# Text(0.5, 0, 'ENGINESIZE in cc')

# %% [markdown]
# From the above we noticed that the distribution of EngineSize is not 100% uniform. But let us see the behaviour with CO2

# %% [markdown]
# #### ENGINESIZE v/s CO2EMISSIONS

# %%
plt.figure(figsize=(10,10))
sns.set(font_scale = 1.5)
sns.lineplot(df['ENGINESIZE'],df['CO2EMISSIONS'])
plt.xlabel('ENGINESIZE in cc')
plt.ylabel('CO2EMISSIONS in g/Km')
# Out:
# Text(0, 0.5, 'CO2EMISSIONS in g/Km')

# %% [markdown]
# From the above plot we notice that as the engine size increases, the CO2 emissions increases.
#
# Therefore in order to reduce the CO2 emissions, we should always go for lower cc engines

# %% [markdown]
# <a id=section544></a>

# %% [markdown]
# #### 5.4.4 CYLINDERS

# %%
df['CYLINDERS'].unique()
# Out:
# array([ 4,  6, 12,  8, 10,  3,  5], dtype=int64)

# %% [markdown]
# Here we have 7 varities of engine cylinders, 3,4,5,6,8,10 and 12

# %%
df['CYLINDERS'].value_counts()
# Out:
# 4     381
# 6     329
# 8     210
# 12     14
# 5       9
# 10      6
# 3       3
# Name: CYLINDERS, dtype: int64

# %%
sns.light_palette("seagreen", as_cmap=True)
plt.figure(figsize=(7,6))
sns.set(font_scale = 1.5)
sns.countplot('CYLINDERS', data=df, order=df['CYLINDERS'].value_counts().index)
plt.xlabel('Number of engine cylinders')
# Out:
# Text(0.5, 0, 'Number of engine cylinders')

# %% [markdown]
# Out of the 7 varieties of cylinders, 4, 6 and 8 are very common cylinder types. About 97% of the data contains only these cylinder types.

# %% [markdown]
# #### CYLINDERS v/s CO2EMISSIONS

# %%
E=df[['CYLINDERS','CO2EMISSIONS']]
F= E.groupby(by='CYLINDERS').mean().sort_values(by='CO2EMISSIONS',ascending= False).head(10)
F
# Out:
#            CO2EMISSIONS
# CYLINDERS
# 10           400.166667
# 12           376.500000
# 8            334.314286
# 6            261.288754
# 5            223.888889
# 4            201.406824
# 3            144.000000

# %%
sns.light_palette("seagreen", as_cmap=True)
plt.figure(figsize=(8,8))
sns.barplot(x=F.index, y=F['CO2EMISSIONS'])
plt.ylabel('CO2 EMISSIONS in g/Km')
plt.xlabel('Number of engine cylinders')
# Out:
# Text(0.5, 0, 'Number of engine cylinders')

# %% [markdown]
# From the above count plot, it is understood that the CO2 emissions increases with increase in Number of cylinders. As for 12 cylinder engine, there is drop in CO2 emissions because of very less data on 12 cylinder engines (only 12 rows of data)
#
# Therefore in order to have better control on emissions, we should go for more 3 or 4 cylinder engines

# %% [markdown]
# <a id=section545></a>

# %% [markdown]
# #### 5.4.5 TRANSMISSION

# %%
len(df['TRANSMISSION'].unique())
# Out:
# 22

# %% [markdown]
# We have 22 tyes of Engine Transmissions in the dataset

# %%
plt.figure(figsize=(12,12))
sns.set(font_scale = 1.5)
sns.countplot('TRANSMISSION',data=df,order=df['TRANSMISSION'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='TRANSMISSION', ylabel='count'>

# %% [markdown]
# **M6, AS6 & A6** transmissions are commonly preferred compared to others

# %% [markdown]
# #### TRANSMISSIONS v/s CO2EMISSIONS

# %%
G=df[['TRANSMISSION','CO2EMISSIONS']]
H= G.groupby(by='TRANSMISSION').mean().sort_values(by='CO2EMISSIONS',ascending= False)
H
# Out:
#               CO2EMISSIONS
# TRANSMISSION
# A4              326.651163
# A7              310.777778
# A5              300.310345
# AS8             287.828125
# AS7             271.819444
# A8              267.753425
# AM7             266.750000
# A6              263.928571
# AS5             257.111111
# M7              251.625000
# AS6             248.478261
# A9              242.625000
# M6              234.508475
# AM6             232.833333
# AS4             228.000000
# AS9             225.000000
# AV8             213.000000
# M5              199.785714
# AV6             193.272727
# AV              181.977778
# AV7             160.200000
# AM5             147.000000

# %%
plt.figure(figsize=(12,12))
sns.set(font_scale = 1.5)
sns.barplot(y=H.index, x=H['CO2EMISSIONS'])
plt.xlabel('CO2 EMISSIONS in g/Km')
# Out:
# Text(0.5, 0, 'CO2 EMISSIONS in g/Km')

# %% [markdown]
# M6, AS6 & A6 transmissions are commonly preferred as the CO2 emissions are comparatively lower than other transmissions

# %% [markdown]
# <a id=section546></a>

# %% [markdown]
# #### 5.4.6 FUELTYPE

# %%
df['FUELTYPE'].unique()
# Out:
# array(['Z', 'D', 'X', 'E'], dtype=object)

# %% [markdown]
# There are 4 tyoes of Fuels used, Z, D, X & E

# %%
plt.figure(figsize=(12,7))
sns.countplot('FUELTYPE',data=df,order=df['FUELTYPE'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='FUELTYPE', ylabel='count'>

# %% [markdown]
# Fuel type  X & Z are more commonly used then E & D

# %% [markdown]
# #### FUELTYPE v/s CO2EMISSIONS

# %%
I=df[['FUELTYPE','CO2EMISSIONS']]
J= I.groupby(by='FUELTYPE').mean().sort_values(by='CO2EMISSIONS',ascending= False)
J
# Out:
#           CO2EMISSIONS
# FUELTYPE
# E           290.404762
# Z           269.168539
# X           240.495885
# D           227.923077

# %%
plt.figure(figsize=(8,8))
sns.barplot(x=J.index, y=J['CO2EMISSIONS'],)
plt.ylabel('CO2 EMISSIONS in g/Km')
# Out:
# Text(0, 0.5, 'CO2 EMISSIONS in g/Km')

# %% [markdown]
# Fuel type Z and X have lower CO2 emissions compared to Fuel type E. Fuel Type D has lowest emissions.
#
# Car manufacturers must manufacturer engines with type D fuel variant

# %% [markdown]
# <a id=section547></a>

# %% [markdown]
# #### 5.4.7 FUEL CONSUMPTION CITY

# %%
sns.distplot(df['FUELCONSUMPTION_CITY'], bins=50)
plt.xlabel('FUELCONSUMPTION_CITY in Liters/100Km')
# Out:
# Text(0.5, 0, 'FUELCONSUMPTION_CITY in Liters/100Km')

# %% [markdown]
# FUEL CONSUNPTION CITY is almost normally distributed with slightly right skew

# %% [markdown]
# #### FUELCONSUMPTION_CITY v/s CO2EMISSIONS

# %%
sns.scatterplot(df['FUELCONSUMPTION_CITY'], df['CO2EMISSIONS'])
plt.xlabel('FUELCONSUMPTION_CITY in Liters/100Km')
plt.ylabel('CO2 EMISSIONS in g/Km')
# Out:
# Text(0, 0.5, 'CO2 EMISSIONS in g/Km')

# %% [markdown]
# The above curve gave two distinct patterns where the isolated pattern shows same CO2 emissions with increased higher Fuel Consumption. Let us find out which **FUELTYPE** is giving this output using ```hue``` function

# %%
sns.scatterplot(df['FUELCONSUMPTION_CITY'], df['CO2EMISSIONS'], hue=df['FUELTYPE'])
plt.xlabel('FUELCONSUMPTION_CITY in Liters/100Km')
plt.ylabel('CO2 EMISSIONS in g/Km')
# Out:
# Text(0, 0.5, 'CO2 EMISSIONS in g/Km')

# %% [markdown]
# From the above plot it is clear on why **E type Fuel** is not commonly used as the fuel consumption is more compared to other fuels

# %% [markdown]
# <a id=section548></a>

# %% [markdown]
# #### 5.4.8 FUEL CONSUMPTION HIGHWAY

# %%
sns.distplot(df['FUELCONSUMPTION_HWY'], bins=50)
plt.xlabel('FUELCONSUMPTION_HWY in Liters/100Km')
# Out:
# Text(0.5, 0, 'FUELCONSUMPTION_HWY in Liters/100Km')

# %% [markdown]
# #### FUELCONSUMPTION_HWY v/s CO2EMISSIONS

# %%
sns.scatterplot(df['FUELCONSUMPTION_HWY'], df['CO2EMISSIONS'])
plt.xlabel('FUELCONSUMPTION_HWY in Liters/100Km')
plt.ylabel('CO2 EMISSIONS in g/Km')
# Out:
# Text(0, 0.5, 'CO2 EMISSIONS in g/Km')

# %%
sns.scatterplot(df['FUELCONSUMPTION_HWY'], df['CO2EMISSIONS'], hue=df['FUELTYPE'])
plt.xlabel('FUELCONSUMPTION_HWY in Liters/100Km')
plt.ylabel('CO2 EMISSIONS in g/Km')
# Out:
# Text(0, 0.5, 'CO2 EMISSIONS in g/Km')

# %% [markdown]
# FUEL CONSUMPTION in HIGHWAY has same behaviour as that of FUEL CONSMPTION in CITY

# %% [markdown]
# <a id=section549></a>

# %% [markdown]
# #### 5.4.9 FUEL CONSUMPTION COMBINATION

# %%
sns.distplot(df['FUELCONSUMPTION_COMB'])
plt.xlabel('FUELCONSUMPTION_COMB in Liters/100Km')
# Out:
# Text(0.5, 0, 'FUELCONSUMPTION_COMB in Liters/100Km')

# %% [markdown]
# #### FUELCONSUMPTION_COMB v/s CO2EMISSIONS

# %%
sns.scatterplot(df['FUELCONSUMPTION_COMB'],df['CO2EMISSIONS'])
plt.xlabel('FUELCONSUMPTION_COMB in Liters/100Km')
plt.ylabel('CO2 EMISSIONS in g/Km')
# Out:
# Text(0, 0.5, 'CO2 EMISSIONS in g/Km')

# %%
sns.scatterplot(df['FUELCONSUMPTION_COMB'],df['CO2EMISSIONS'], hue=df['FUELTYPE'])
plt.xlabel('FUELCONSUMPTION_COMB in Liters/100Km')
plt.ylabel('CO2 EMISSIONS in g/Km')
# Out:
# Text(0, 0.5, 'CO2 EMISSIONS in g/Km')

# %% [markdown]
# Since FUELCONSUMPTION_COMB is derived from FUELCONSUMPTION_CITY & FUELCONSUMPTION_HWY, it is best to delete it as it is derived column

# %% [markdown]
# Let us delete FUELCONSMPTION_CTY & FUELCONSMPTION_HWY and keep only FUELCONSUMPTION_COMB.

# %%
df.drop(columns=['FUELCONSUMPTION_COMB'], axis=0, inplace= True)

# %%
df.head()
# Out:
#     MAKE VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  \
# 0  ACURA      COMPACT         2.0          4          AS5        Z
# 1  ACURA      COMPACT         2.4          4           M6        Z
# 2  ACURA      COMPACT         1.5          4          AV7        Z
# 3  ACURA  SUV - SMALL         3.5          6          AS6        Z
# 4  ACURA  SUV - SMALL         3.5          6          AS6        Z
#
#    FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  CO2EMISSIONS
# 0                   9.9                  6.7           196
# 1                  11.2                  7.7           221
# 2                   6.0                  5.8           136
# 3                  12.7                  9.1           255
# 4                  12.1                  8.7           244

# %% [markdown]
# <a id=section5410></a>

# %% [markdown]
# #### 5.4.10 CO2 EMISSIONS

# %%
sns.distplot(df['CO2EMISSIONS'])
plt.xlabel('CO2 EMISSIONS in g/Km')
# Out:
# Text(0.5, 0, 'CO2 EMISSIONS in g/Km')

# %% [markdown]
# CO2EMISSIONS columns column is normally distributed

# %% [markdown]
# <a id=section5411></a>

# %% [markdown]
# #### 5.4.11 PAIR PLOT

# %%
sns.light_palette("seagreen", as_cmap=True)
sns.set(font_scale = 1)
sns.pairplot(data=df)

# %% [markdown]
# <a id=section5412></a>

# %% [markdown]
# #### 5.4.12 HEATMAP

# %%
df.corr()
# Out:
#                       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  \
# ENGINESIZE              1.000000   0.934377              0.825390
# CYLINDERS               0.934377   1.000000              0.788633
# FUELCONSUMPTION_CITY    0.825390   0.788633              1.000000
# FUELCONSUMPTION_HWY     0.772854   0.719775              0.965839
# CO2EMISSIONS            0.869835   0.843533              0.897429
#
#                       FUELCONSUMPTION_HWY  CO2EMISSIONS
# ENGINESIZE                       0.772854      0.869835
# CYLINDERS                        0.719775      0.843533
# FUELCONSUMPTION_CITY             0.965839      0.897429
# FUELCONSUMPTION_HWY              1.000000      0.860853
# CO2EMISSIONS                     0.860853      1.000000

# %%
sns.heatmap(df.corr(), annot=True, cmap='RdBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id=section5412></a>

# %% [markdown]
# #### 5.4.12 Conclusion from EDA

# %% [markdown]
# #### From EDA we have the following conclusions;
#    - **Engine size** has linear relationship with **CO2 emissions.**
#    - As the Number of **Engine Cylinder** increases, the **CO2 Emission** increases
#    - Fuel Type **E** has high fuel consumption but same **CO2 Emissions**
#    - The Target Variable **CO2 EMISSIONS** is normally distributed.
#    - **ENGINE SIZE, CYLINDERS, FUELCONSUMPTION_CITY, FUELCONSUMPTION_HWY, & CO2EMISSIONS** are highly co-related with each other

# %% [markdown]
# <a id=section6></a>

# %% [markdown]
# ## 6. Linear Regression

# %% [markdown]
# Now we will more forward and design different Machine Learning models for the dataset and decide what will be the best model for accurately predicting the CO2 emissions

# %% [markdown]
# <a id=section61></a>

# %% [markdown]
# ### 6.1. Data Preparation for ML

# %% [markdown]
# Before we move forward with applying Machine learning algorithms, we need to first convet the categorical object column **FUELTYPE** into categorical numerical column using ```getdummies()``` function

# %%
df=pd.get_dummies(data=df, columns=['FUELTYPE'],drop_first=True )

# %%
df.head()
# Out:
#     MAKE VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION  \
# 0  ACURA      COMPACT         2.0          4          AS5
# 1  ACURA      COMPACT         2.4          4           M6
# 2  ACURA      COMPACT         1.5          4          AV7
# 3  ACURA  SUV - SMALL         3.5          6          AS6
# 4  ACURA  SUV - SMALL         3.5          6          AS6
#
#    FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  CO2EMISSIONS  FUELTYPE_E  \
# 0                   9.9                  6.7           196           0
# 1                  11.2                  7.7           221           0
# 2                   6.0                  5.8           136           0
# 3                  12.7                  9.1           255           0
# 4                  12.1                  8.7           244           0
#
#    FUELTYPE_X  FUELTYPE_Z
# 0           0           1
# 1           0           1
# 2           0           1
# 3           0           1
# 4           0           1

# %% [markdown]
# <a id=section62></a>

# %% [markdown]
# <a id=section62></a>

# %% [markdown]
# ### 6.2 LINEAR REGRESSION ASSUMPTIONS

# %% [markdown]
# **1. The Target Variable must be normally distributed**

# %%
sns.distplot(df['CO2EMISSIONS'])
plt.xlabel('CO2 EMISSIONS in g/Km')
# Out:
# Text(0.5, 0, 'CO2 EMISSIONS in g/Km')

# %% [markdown]
# From the above plot it is clear that the target variable ```df['CO2EMISSIONS']``` is normally distributed

# %% [markdown]
# **2. Explanatory variables must not be co-related with each other**

# %% [markdown]
# We have the independent feature variables as : ```['MAKE', 'VEHICLECLASS', 'ENGINESIZE', 'CYLINDERS', 'TRANSMISSION','FUELCONSUMPTION_CITY', 'FUELCONSUMPTION_HWY','FUELTYPE_E', 'FUELTYPE_X', 'FUELTYPE_Z']```
#
# Let us see the correlation matrix and drop the variables which are having co-relation, |r|<0.8

# %%
columns= ['MAKE', 'VEHICLECLASS', 'ENGINESIZE', 'CYLINDERS', 'TRANSMISSION','FUELCONSUMPTION_CITY', 'FUELCONSUMPTION_HWY','FUELTYPE_E', 'FUELTYPE_X', 'FUELTYPE_Z']
columns
# Out:
# ['MAKE',
#  'VEHICLECLASS',
#  'ENGINESIZE',
#  'CYLINDERS',
#  'TRANSMISSION',
#  'FUELCONSUMPTION_CITY',
#  'FUELCONSUMPTION_HWY',
#  'FUELTYPE_E',
#  'FUELTYPE_X',
#  'FUELTYPE_Z']

# %%
sns.heatmap(df[columns].corr(), annot =True, cmap='RdBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# We need to drop the columns: ```ENGINESIZE, FUELCONSUMPTION_HWY``` as they are highly co-related with other columns. Let's drop these columns and check for co-relation again

# %%
df.drop(columns=['ENGINESIZE', 'FUELCONSUMPTION_HWY'], axis=0, inplace=True)

# %%
columns= ['CYLINDERS', 'FUELCONSUMPTION_CITY', 'FUELTYPE_E', 'FUELTYPE_X', 'FUELTYPE_Z']
columns
# Out:
# ['CYLINDERS', 'FUELCONSUMPTION_CITY', 'FUELTYPE_E', 'FUELTYPE_X', 'FUELTYPE_Z']

# %%
sns.heatmap(df[columns].corr(), annot =True, cmap='RdBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Thus assumption 2 is satisfied**

# %% [markdown]
# **3. Linear relationship between independent and dependent variable**

# %% [markdown]
# The target variable as ```CO2EMISSIONS```
# The independent variables are: ```['CYLINDERS','FUELCONSUMPTION_CITY', 'FUELTYPE_E', 'FUELTYPE_X', 'FUELTYPE_Z']```
#
# Let us check for linear relationship as under

# %%
for col in columns:
    plt.figure(figsize=(8,8))
    sns.scatterplot(x=df[col],y=df['CO2EMISSIONS'])

# %% [markdown]
# **Thus assumption 3 is satisfied**

# %% [markdown]
# **4. Homoscedasticity : constant variance**

# %% [markdown]
# Since the first 3 assumptions are satisfied, we can assume that this assumption is automatically satisfied

# %% [markdown]
# <a id=section63></a>

# %% [markdown]
# ## 6.3 Train Test Split

# %%
features= ['CYLINDERS', 'FUELCONSUMPTION_CITY', 'FUELTYPE_E', 'FUELTYPE_X', 'FUELTYPE_Z']
features
# Out:
# ['CYLINDERS', 'FUELCONSUMPTION_CITY', 'FUELTYPE_E', 'FUELTYPE_X', 'FUELTYPE_Z']

# %%
#We have the X and Y are as under;

X=df[features]
X.head()
# Out:
#    CYLINDERS  FUELCONSUMPTION_CITY  FUELTYPE_E  FUELTYPE_X  FUELTYPE_Z
# 0          4                   9.9           0           0           1
# 1          4                  11.2           0           0           1
# 2          4                   6.0           0           0           1
# 3          6                  12.7           0           0           1
# 4          6                  12.1           0           0           1

# %%
y=df['CO2EMISSIONS']
y.head()
# Out:
# 0    196
# 1    221
# 2    136
# 3    255
# 4    244
# Name: CO2EMISSIONS, dtype: int64

# %%
print('Shape of X is :', X.shape)
print('Shape of y is :',y.shape)
# Out:
# Shape of X is : (952, 5)
# Shape of y is : (952,)

# %%
#splitting the data into 80% train and 20% test

from sklearn.model_selection import train_test_split

def split(X,y):
    return train_test_split(X,y, test_size=0.2, random_state=1)

X_train, X_test, y_train, y_test=split(X,y)

# %%
print('Shape of X_train is :', X_train.shape)
print('Shape of y_train is :',y_train.shape)
# Out:
# Shape of X_train is : (761, 5)
# Shape of y_train is : (761,)

# %%
print('Shape of X_test is :', X_test.shape)
print('Shape of y_test is :',y_test.shape)
# Out:
# Shape of X_test is : (191, 5)
# Shape of y_test is : (191,)

# %% [markdown]
# <a id=section64></a>

# %% [markdown]
# ## 6.4 Data Scaling

# %% [markdown]
# We need to bring all the X columns  to have same uniformity. That is why we scale the data as under;

# %%
#Scaling the X part of data
from sklearn.preprocessing import MinMaxScaler
scalar=MinMaxScaler() # defining object
scalar.fit(X_train) #defining the scal
X_train_s=scalar.transform(X_train)#actual scaling
X_test_s=scalar.transform(X_test)

# %% [markdown]
# <a id=section65></a>

# %% [markdown]
# ## 6.5 Linear Regression

# %% [markdown]
# Now that all the assumptions are satisfied for linear regression,we are ready for our model development, let us develop our first model from linear regression model. Normally the model is defined as under;
#
# ### **Y=B0+B1X1+B2X2+B3X3+.........+BmXm  ==> Y=BX**

# %% [markdown]
# <a id=section651></a>

# %% [markdown]
# ### 6.5.1 Linear Regression Equation Development

# %%
from sklearn.linear_model import LinearRegression
linreg=LinearRegression()
linreg.fit(X_train_s, y_train) #calculates B0 and B1
y_pred_train_lg=linreg.predict(X_train_s)
y_pred_test_lg=linreg.predict(X_test_s)

# %%
#print b0 and b1
print('Intercept:',linreg.intercept_)          # print the intercept 
print('Coefficients:',linreg.coef_)
# Out:
# Intercept: 132.8637950936449
# Coefficients: [   6.52582556  463.10356975 -135.89143334  -24.65412073  -26.86910225]

# %%
features.insert(0,'Intercept')# Appending the columns to show the B values side by side
coef = linreg.coef_.tolist()            
coef.insert(0, linreg.intercept_)

# %%
eq1 = zip(features, coef)

for c1,c2 in eq1:
    print(c1,c2)
# Out:
# Intercept 132.8637950936449
# CYLINDERS 6.525825563099857
# FUELCONSUMPTION_CITY 463.10356975405136
# FUELTYPE_E -135.8914333365215
# FUELTYPE_X -24.65412072555284
# FUELTYPE_Z -26.86910224810943

# %% [markdown]
# Therefore we have the final Linear regression equation as under;
#
# **CO2 Emissions=132.86+6.52*X_train['CYLINDERS']+463.10*X_train['FUELCONSUMPTION_CITY']-135.89*X_train['FUELTYPE_E']-24.65*X_train['FUELTYPE_X']-26.87*X_train['FUELTYPE_Z']**
#
# From the above linear regression equation, we have observed the following;
#     - The CO2 Emissions are highly dependent on Fuel Consumption. For one unit increase in fuel consunption,
# the CO2 emissions increases by 463 counts.
#     - The CO2 Emissions are also dependent on the number of engine cylinders. The CO2 emissions will get increased
# by 6 counts
#     - The use of different type of fuel always tend to reduce the CO2 emissions. Basically the Fuel type E has very high effect on reducing the CO2 emissions as it recues the CO2 emissions by 136 counts

# %%
x_plot_train=132.86+6.52*X_train['CYLINDERS']+463.10*X_train['FUELCONSUMPTION_CITY']-135.89*X_train['FUELTYPE_E']-24.65*X_train['FUELTYPE_X']-26.87*X_train['FUELTYPE_Z']

# %% [markdown]
# <a id=section652></a>

# %% [markdown]
# ### 6.5.2 Plotting Predicted vs Actual

# %% [markdown]
# Let us plot the Predictd value with actual value and check the behaviour

# %% [markdown]
# PLotting for test data first

# %%
plt.figure(figsize=(12,12))
sns.lineplot(x=x_plot_train,y=y_pred_train_lg, label='Predicted')
sns.lineplot(x=x_plot_train,y=y_train, label='Actual')
plt.xlabel("x_plot=132.86+6.52*X_train['CYLINDERS']+463.10*X_train['FUELCONSUMPTION_CITY']-135.89*X_train['FUELTYPE_E']-24.65*X_train['FUELTYPE_X']-26.87*X_train['FUELTYPE_Z']")
plt.ylabel('CO2 Emissions')
plt.legend(loc='upper left')

# %% [markdown]
# Let us also check for linear behaviour of actual and predicted values for test data

# %%
plt.figure(figsize=(8,8))
plt.axes(aspect='equal')
plt.scatter(y_train, y_pred_train_lg,marker='.')
plt.xlabel('Actual CO2 Values')
plt.ylabel('Predicted CO2 Values')
# Out:
# Text(0, 0.5, 'Predicted CO2 Values')

# %% [markdown]
# Now Let us check for the test dataset

# %%
x_plot_test=132.86+6.52*X_test['CYLINDERS']+463.10*X_test['FUELCONSUMPTION_CITY']-135.89*X_test['FUELTYPE_E']-24.65*X_test['FUELTYPE_X']-26.87*X_test['FUELTYPE_Z']

# %%
plt.figure(figsize=(12,12))
sns.lineplot(x=x_plot_test,y=y_pred_test_lg, label='Predicted')
sns.lineplot(x=x_plot_test,y=y_test, label='Actual')
plt.xlabel("x_plot_test=132.86+6.52*X_test['CYLINDERS']+463.10*X_test['FUELCONSUMPTION_CITY']-135.89*X_test['FUELTYPE_E']-24.65*X_test['FUELTYPE_X']-26.87*X_test['FUELTYPE_Z']")
plt.ylabel('CO2 Emissions')
plt.legend(loc='upper left')

# %% [markdown]
# Checcking for predicted vs actual for test dataset

# %%
plt.figure(figsize=(8,22))
plt.axes(aspect='equal')
sns.lineplot(y_test, y_pred_test_lg,marker='.')
plt.xlabel('Actual CO2 Values')
plt.ylabel('Predicted CO2 Values')
# Out:
# Text(0, 0.5, 'Predicted CO2 Values')

# %% [markdown]
# From the above train and test plots its clear that the model is very good for predicting the CO2 Emissions

# %% [markdown]
# <a id=section6523></a>

# %% [markdown]
# ### 6.5.2 FInding RMSE, R-squared and Adjusted R-squared

# %% [markdown]
# #### RMSE

# %%
#finding RMSE values
from sklearn import metrics
RMSE_train_lg=np.sqrt(metrics.mean_squared_error(y_train,y_pred_train_lg))
print('the Root Mean Squared Error for Train data is  :',RMSE_train_lg)
# Out:
# the Root Mean Squared Error for Train data is  : 8.821916441033645

# %%
from sklearn import metrics
RMSE_test_lg=np.sqrt(metrics.mean_squared_error(y_test,y_pred_test_lg))
print('the Root Mean Squared Error for Test data is  :',RMSE_test_lg)
# Out:
# the Root Mean Squared Error for Test data is  : 8.226951721037688

# %% [markdown]
# #### R Squared

# %%
from sklearn.metrics import r2_score
r2_train_lg=r2_score(y_train, y_pred_train_lg)
print('The R-square value for Train dataset is  :', r2_train_lg)
# Out:
# The R-square value for Train dataset is  : 0.9804954207149876

# %%
from sklearn.metrics import r2_score
r2_test_lg=r2_score(y_test, y_pred_test_lg)
print('The R-square value for Test dataset is  :', r2_test_lg)
# Out:
# The R-square value for Test dataset is  : 0.9832121945333532

# %% [markdown]
# #### Adjusted R-Square

# %% [markdown]
# Let us develop a ```Function``` to calculate the Adjusted R square so that we can call the function anytime during the program

# %% [markdown]
# def Adjusted_r2(r_square,P,N)
#
#     return(1-(((1-r_square)*(N-1))/(N-P-1)))

# %% [markdown]
# - Were r_square is the R-Square value
# - P is the number of independent variables. In this case it is 5.
# - N is the length of the dependent variables.
#
# Since we already know the value of P=5, let us modify the above equation as udner

# %%
def Adjusted_r2(r_square,N): #creating function so that we can call the function again and again
    return(1-(((1-r_square)*(N-1))/(N-6)))

# %%
adj_r2_train=Adjusted_r2(r2_train_lg,len(X_train))
print('The Adjusted R-square of Linear Regression Train Dataset is :', adj_r2_train)
adj_r2_test=Adjusted_r2(r2_test_lg,len(X_test))
print('The Adjusted R-square of Linear Regression Test Dataset is :', adj_r2_test)
# Out:
# The Adjusted R-square of Linear Regression Train Dataset is : 0.9803662513157492
# The Adjusted R-square of Linear Regression Test Dataset is : 0.9827584700612817

# %%
X_train.shape[-1]
# Out:
# 5

# %% [markdown]
# **From the above RMSE and R-squared values, we ca say that the model is very accurate with the accuracy of 98% for train and test dataset**

# %% [markdown]
# <a id=section66></a>

# %% [markdown]
# ## 6.6 Summary of Linear Regression

# %% [markdown]
# We have the equation for linear regression for CO2 as ;
#
# **CO2 Emissions=132.86+6.52*X_train['CYLINDERS']+463.10*X_train['FUELCONSUMPTION_CITY']-135.89*X_train['FUELTYPE_E']-24.65*X_train['FUELTYPE_X']-26.87*X_train['FUELTYPE_Z']**
#
# From the above linear regression equation, we have observed the following;
#    - The CO2 Emissions are highly dependent on Fuel Consumption. For one unit increase in fuel consunption, the CO2 emissions increases by 463 counts.
#    - The CO2 Emissions are also dependent on the number of engine cylinders. The CO2 emissions will get increased by 6 counts
#    - The use of different type of fuel always tend to reduce the CO2 emissions. Basically the Fuel type E has very high effect on reducing the CO2 emissions as it recues the CO2 emissions by 136 counts
#
# After evaluating this model, we have the following results
#
# |RMSE Score Train||RMSE Score Test ||R-square Value Train||R-square Value Test|| Adjusted R-squared Value Train||Adjusted R-squared Value test|
# |------------||-------------||------||-------------||-----------||---------|
# | 8.8219  ||8.2269|| 0.9804   ||0.9832|| 0.9803||   0.9827|

# %% [markdown]
# <a id=section7></a>

# %% [markdown]
# ## 7. Decision Tree

# %% [markdown]
# Developing some more models under Decision Tree Regression

# %% [markdown]
# <a id=section71></a>

# %% [markdown]
# ### 7.1 Decision Tree Model 1

# %% [markdown]
# <a id=section711></a>

# %% [markdown]
# ### 7.1.1 Model Development

# %%
# Importing and developing simple Decision Tree Model
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor(criterion='mse')
model.fit(X_train_s, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_train_pred_dt=model.predict(X_train_s)
y_test_pred_dt=model.predict(X_test_s)

# %% [markdown]
# <a id=section712></a>

# %% [markdown]
# ### 7.1.2 Plotting the model

# %%
#Importing libraries for visvalizing the Tree
from pydotplus import graph_from_dot_data
from sklearn.tree import export_graphviz

# %%
#importing OS
import os
os.environ['PATH'] = os.environ['PATH'] + ';' + os.environ['CONDA_PREFIX'] + r"\Library\bin\graphviz"

# %%
#Generating DOT File
dot_data = export_graphviz(model, filled=True, rounded=True, feature_names=X.columns, out_file=None)
graph = graph_from_dot_data(dot_data)

# %%
from IPython.display import Image
Image(filename='tree.png')

# %%
from sklearn.tree import plot_tree
 
plt.figure(figsize=(8, 6))
plot_tree(model, feature_names=X_train.columns, filled=True, rounded=True)
# Out:
# [Text(214.20067044100117, 313.61538461538464, 'FUELCONSUMPTION_CITY <= 0.339\nmse = 3990.151\nsamples = 761\nvalue = 256.388'),
#  Text(106.27106674612632, 288.5261538461539, 'FUELCONSUMPTION_CITY <= 0.237\nmse = 1103.27\nsamples = 448\nvalue = 215.125'),
#  Text(48.53402860548271, 263.4369230769231, 'FUELCONSUMPTION_CITY <= 0.175\nmse = 410.958\nsamples = 217\nvalue = 187.544'),
#  Text(18.622169249106076, 238.34769230769234, 'FUELCONSUMPTION_CITY <= 0.106\nmse = 274.361\nsamples = 107\nvalue = 172.112'),
#  Text(4.256495828367103, 213.25846153846157, 'FUELCONSUMPTION_CITY <= 0.033\nmse = 111.714\nsamples = 14\nvalue = 138.0'),
#  Text(2.1282479141835515, 188.16923076923078, 'FUELCONSUMPTION_CITY <= 0.012\nmse = 68.5\nsamples = 4\nvalue = 124.0'),
#  Text(1.0641239570917758, 163.08, 'mse = 0.0\nsamples = 1\nvalue = 110.0'),
#  Text(3.192371871275327, 163.08, 'FUELCONSUMPTION_CITY <= 0.027\nmse = 4.222\nsamples = 3\nvalue = 128.667'),
#  Text(2.1282479141835515, 137.99076923076925, 'mse = 0.0\nsamples = 1\nvalue = 126.0'),
#  Text(4.256495828367103, 137.99076923076925, 'mse = 1.0\nsamples = 2\nvalue = 130.0'),
#  Text(6.384743742550654, 188.16923076923078, 'FUELCONSUMPTION_CITY <= 0.057\nmse = 19.24\nsamples = 10\nvalue = 143.6'),
#  Text(5.320619785458879, 163.08, 'mse = 0.0\nsamples = 3\nvalue = 138.0'),
#  Text(7.44886769964243, 163.08, 'FUELCONSUMPTION_CITY <= 0.094\nmse = 8.286\nsamples = 7\nvalue = 146.0'),
#  Text(6.384743742550654, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.08\nmse = 2.667\nsamples = 6\nvalue = 145.0'),
#  Text(5.320619785458879, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.073\nmse = 1.0\nsamples = 4\nvalue = 144.0'),
#  Text(4.256495828367103, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 143.0'),
#  Text(6.384743742550654, 87.81230769230771, 'mse = 0.889\nsamples = 3\nvalue = 144.333'),
#  Text(7.44886769964243, 112.90153846153848, 'mse = 0.0\nsamples = 2\nvalue = 147.0'),
#  Text(8.512991656734206, 137.99076923076925, 'mse = 0.0\nsamples = 1\nvalue = 152.0'),
#  Text(32.98784266984505, 213.25846153846157, 'FUELCONSUMPTION_CITY <= 0.147\nmse = 97.304\nsamples = 93\nvalue = 177.247'),
#  Text(22.080572109654348, 188.16923076923078, 'FUELTYPE_X <= 0.5\nmse = 128.798\nsamples = 38\nvalue = 171.789'),
#  Text(15.163766388557805, 163.08, 'FUELCONSUMPTION_CITY <= 0.131\nmse = 34.43\nsamples = 11\nvalue = 184.455'),
#  Text(12.237425506555422, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.122\nmse = 22.025\nsamples = 9\nvalue = 182.556'),
#  Text(9.577115613825981, 112.90153846153848, 'CYLINDERS <= 0.222\nmse = 8.0\nsamples = 3\nvalue = 179.0'),
#  Text(8.512991656734206, 87.81230769230771, 'mse = 0.0\nsamples = 2\nvalue = 181.0'),
#  Text(10.641239570917758, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 175.0'),
#  Text(14.89773539928486, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.127\nmse = 19.556\nsamples = 6\nvalue = 184.333'),
#  Text(12.769487485101308, 87.81230769230771, 'FUELTYPE_Z <= 0.5\nmse = 1.688\nsamples = 4\nvalue = 186.75'),
#  Text(11.705363528009533, 62.72307692307692, 'mse = 0.0\nsamples = 3\nvalue = 186.0'),
#  Text(13.833611442193085, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 189.0'),
#  Text(17.025983313468412, 87.81230769230771, 'FUELTYPE_Z <= 0.5\nmse = 20.25\nsamples = 2\nvalue = 179.5'),
#  Text(15.961859356376637, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 184.0'),
#  Text(18.09010727056019, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 175.0'),
#  Text(18.09010727056019, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.135\nmse = 1.0\nsamples = 2\nvalue = 193.0'),
#  Text(17.025983313468412, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 192.0'),
#  Text(19.154231227651962, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 194.0'),
#  Text(28.99737783075089, 163.08, 'CYLINDERS <= 0.222\nmse = 75.27\nsamples = 27\nvalue = 166.63'),
#  Text(26.071036948748507, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.131\nmse = 34.022\nsamples = 25\nvalue = 164.76'),
#  Text(23.410727056019066, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.124\nmse = 14.857\nsamples = 14\nvalue = 161.0'),
#  Text(21.282479141835516, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.12\nmse = 2.816\nsamples = 7\nvalue = 158.429'),
#  Text(20.21835518474374, 62.72307692307692, 'FUELCONSUMPTION_CITY <= 0.116\nmse = 2.16\nsamples = 5\nvalue = 157.8'),
#  Text(19.154231227651962, 37.63384615384615, 'mse = 2.0\nsamples = 3\nvalue = 158.0'),
#  Text(21.282479141835516, 37.63384615384615, 'mse = 2.25\nsamples = 2\nvalue = 157.5'),
#  Text(22.34660309892729, 62.72307692307692, 'mse = 1.0\nsamples = 2\nvalue = 160.0'),
#  Text(25.538974970202617, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.127\nmse = 13.673\nsamples = 7\nvalue = 163.571'),
#  Text(24.474851013110843, 62.72307692307692, 'mse = 20.25\nsamples = 2\nvalue = 163.5'),
#  Text(26.603098927294393, 62.72307692307692, 'mse = 11.04\nsamples = 5\nvalue = 163.6'),
#  Text(28.731346841477947, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.135\nmse = 17.521\nsamples = 11\nvalue = 169.545'),
#  Text(27.66722288438617, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 177.0'),
#  Text(29.79547079856972, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.143\nmse = 13.16\nsamples = 10\nvalue = 168.8'),
#  Text(28.731346841477947, 62.72307692307692, 'FUELCONSUMPTION_CITY <= 0.139\nmse = 14.24\nsamples = 5\nvalue = 170.6'),
#  Text(27.66722288438617, 37.63384615384615, 'mse = 0.0\nsamples = 1\nvalue = 166.0'),
#  Text(29.79547079856972, 37.63384615384615, 'mse = 11.188\nsamples = 4\nvalue = 171.75'),
#  Text(30.859594755661497, 62.72307692307692, 'mse = 5.6\nsamples = 5\nvalue = 167.0'),
#  Text(31.923718712753274, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.127\nmse = 1.0\nsamples = 2\nvalue = 190.0'),
#  Text(30.859594755661497, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 189.0'),
#  Text(32.98784266984505, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 191.0'),
#  Text(43.89511323003575, 188.16923076923078, 'FUELCONSUMPTION_CITY <= 0.159\nmse = 40.745\nsamples = 55\nvalue = 181.018'),
#  Text(39.90464839094159, 163.08, 'FUELTYPE_X <= 0.5\nmse = 37.594\nsamples = 31\nvalue = 179.226'),
#  Text(37.24433849821215, 137.99076923076925, 'FUELTYPE_Z <= 0.5\nmse = 53.471\nsamples = 11\nvalue = 183.727'),
#  Text(35.1160905840286, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.153\nmse = 4.222\nsamples = 3\nvalue = 194.333'),
#  Text(34.051966626936824, 87.81230769230771, 'mse = 2.25\nsamples = 2\nvalue = 195.5'),
#  Text(36.18021454112038, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 192.0'),
#  Text(39.372586412395705, 112.90153846153848, 'CYLINDERS <= 0.222\nmse = 13.938\nsamples = 8\nvalue = 179.75'),
#  Text(38.308462455303925, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.151\nmse = 1.959\nsamples = 7\nvalue = 178.429'),
#  Text(37.24433849821215, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 175.0'),
#  Text(39.372586412395705, 62.72307692307692, 'mse = 0.0\nsamples = 6\nvalue = 179.0'),
#  Text(40.43671036948748, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 189.0'),
#  Text(42.56495828367103, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.151\nmse = 11.588\nsamples = 20\nvalue = 176.75'),
#  Text(41.50083432657925, 112.90153846153848, 'mse = 11.222\nsamples = 6\nvalue = 173.667'),
#  Text(43.629082240762806, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.155\nmse = 5.923\nsamples = 14\nvalue = 178.071'),
#  Text(42.56495828367103, 87.81230769230771, 'mse = 0.75\nsamples = 4\nvalue = 176.5'),
#  Text(44.69320619785458, 87.81230769230771, 'mse = 6.61\nsamples = 10\nvalue = 178.7'),
#  Text(47.885578069129906, 163.08, 'FUELCONSUMPTION_CITY <= 0.163\nmse = 35.306\nsamples = 24\nvalue = 183.333'),
#  Text(46.82145411203813, 137.99076923076925, 'mse = 59.76\nsamples = 5\nvalue = 181.8'),
#  Text(48.949702026221686, 137.99076923076925, 'FUELTYPE_Z <= 0.5\nmse = 28.089\nsamples = 19\nvalue = 183.737'),
#  Text(47.885578069129906, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.167\nmse = 34.0\nsamples = 15\nvalue = 184.0'),
#  Text(46.82145411203813, 87.81230769230771, 'mse = 16.56\nsamples = 5\nvalue = 184.2'),
#  Text(48.949702026221686, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.171\nmse = 42.69\nsamples = 10\nvalue = 183.9'),
#  Text(47.885578069129906, 62.72307692307692, 'mse = 1.0\nsamples = 2\nvalue = 183.0'),
#  Text(50.01382598331346, 62.72307692307692, 'mse = 52.859\nsamples = 8\nvalue = 184.125'),
#  Text(50.01382598331346, 112.90153846153848, 'mse = 4.688\nsamples = 4\nvalue = 182.75'),
#  Text(78.44588796185934, 238.34769230769234, 'FUELCONSUMPTION_CITY <= 0.206\nmse = 86.865\nsamples = 110\nvalue = 202.555'),
#  Text(66.37473182359952, 213.25846153846157, 'CYLINDERS <= 0.222\nmse = 42.15\nsamples = 54\nvalue = 196.13'),
#  Text(61.45315852205005, 188.16923076923078, 'FUELCONSUMPTION_CITY <= 0.198\nmse = 22.252\nsamples = 50\nvalue = 195.22'),
#  Text(57.99475566150178, 163.08, 'FUELCONSUMPTION_CITY <= 0.19\nmse = 17.256\nsamples = 36\nvalue = 193.722'),
#  Text(54.27032181168057, 137.99076923076925, 'FUELTYPE_X <= 0.5\nmse = 18.154\nsamples = 21\nvalue = 192.476'),
#  Text(52.14207389749701, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.182\nmse = 16.472\nsamples = 6\nvalue = 194.833'),
#  Text(51.07794994040523, 87.81230769230771, 'mse = 13.36\nsamples = 5\nvalue = 193.8'),
#  Text(53.20619785458879, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 200.0'),
#  Text(56.398569725864114, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.186\nmse = 15.716\nsamples = 15\nvalue = 191.533'),
#  Text(55.33444576877234, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.178\nmse = 13.6\nsamples = 10\nvalue = 191.0'),
#  Text(54.27032181168057, 62.72307692307692, 'mse = 1.0\nsamples = 2\nvalue = 190.0'),
#  Text(56.398569725864114, 62.72307692307692, 'FUELCONSUMPTION_CITY <= 0.182\nmse = 16.438\nsamples = 8\nvalue = 191.25'),
#  Text(55.33444576877234, 37.63384615384615, 'mse = 26.0\nsamples = 3\nvalue = 191.0'),
#  Text(57.462693682955894, 37.63384615384615, 'mse = 10.64\nsamples = 5\nvalue = 191.4'),
#  Text(57.462693682955894, 87.81230769230771, 'mse = 18.24\nsamples = 5\nvalue = 192.6'),
#  Text(61.719189511322995, 137.99076923076925, 'FUELTYPE_Z <= 0.5\nmse = 10.782\nsamples = 15\nvalue = 195.467'),
#  Text(60.65506555423122, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.194\nmse = 11.929\nsamples = 13\nvalue = 195.615'),
#  Text(59.59094159713944, 87.81230769230771, 'mse = 11.136\nsamples = 9\nvalue = 195.444'),
#  Text(61.719189511322995, 87.81230769230771, 'mse = 13.5\nsamples = 4\nvalue = 196.0'),
#  Text(62.78331346841477, 112.90153846153848, 'mse = 2.25\nsamples = 2\nvalue = 194.5'),
#  Text(64.91156138259832, 163.08, 'FUELCONSUMPTION_CITY <= 0.202\nmse = 14.495\nsamples = 14\nvalue = 199.071'),
#  Text(63.84743742550655, 137.99076923076925, 'mse = 11.959\nsamples = 7\nvalue = 197.429'),
#  Text(65.9756853396901, 137.99076923076925, 'FUELTYPE_Z <= 0.5\nmse = 11.633\nsamples = 7\nvalue = 200.714'),
#  Text(64.91156138259832, 112.90153846153848, 'mse = 11.04\nsamples = 5\nvalue = 201.4'),
#  Text(67.03980929678187, 112.90153846153848, 'mse = 9.0\nsamples = 2\nvalue = 199.0'),
#  Text(71.29630512514898, 188.16923076923078, 'FUELTYPE_Z <= 0.5\nmse = 151.25\nsamples = 4\nvalue = 207.5'),
#  Text(69.16805721096543, 163.08, 'FUELCONSUMPTION_CITY <= 0.188\nmse = 30.25\nsamples = 2\nvalue = 218.5'),
#  Text(68.10393325387365, 137.99076923076925, 'mse = 0.0\nsamples = 1\nvalue = 213.0'),
#  Text(70.2321811680572, 137.99076923076925, 'mse = 0.0\nsamples = 1\nvalue = 224.0'),
#  Text(73.42455303933252, 163.08, 'FUELCONSUMPTION_CITY <= 0.184\nmse = 30.25\nsamples = 2\nvalue = 196.5'),
#  Text(72.36042908224076, 137.99076923076925, 'mse = 0.0\nsamples = 1\nvalue = 191.0'),
#  Text(74.4886769964243, 137.99076923076925, 'mse = 0.0\nsamples = 1\nvalue = 202.0'),
#  Text(90.51704410011918, 213.25846153846157, 'CYLINDERS <= 0.222\nmse = 51.795\nsamples = 56\nvalue = 208.75'),
#  Text(84.19880810488675, 188.16923076923078, 'FUELCONSUMPTION_CITY <= 0.218\nmse = 39.501\nsamples = 52\nvalue = 207.865'),
#  Text(78.74517282479141, 163.08, 'FUELCONSUMPTION_CITY <= 0.214\nmse = 35.202\nsamples = 21\nvalue = 203.81'),
#  Text(76.61692491060785, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.21\nmse = 32.959\nsamples = 11\nvalue = 201.636'),
#  Text(75.55280095351608, 112.90153846153848, 'FUELTYPE_Z <= 0.5\nmse = 37.5\nsamples = 8\nvalue = 203.0'),
#  Text(74.4886769964243, 87.81230769230771, 'mse = 29.667\nsamples = 6\nvalue = 204.0'),
#  Text(76.61692491060785, 87.81230769230771, 'mse = 49.0\nsamples = 2\nvalue = 200.0'),
#  Text(77.68104886769963, 112.90153846153848, 'mse = 2.667\nsamples = 3\nvalue = 198.0'),
#  Text(80.87342073897496, 137.99076923076925, 'FUELTYPE_X <= 0.5\nmse = 26.76\nsamples = 10\nvalue = 206.2'),
#  Text(79.80929678188318, 112.90153846153848, 'mse = 42.688\nsamples = 4\nvalue = 207.25'),
#  Text(81.93754469606674, 112.90153846153848, 'mse = 14.917\nsamples = 6\nvalue = 205.5'),
#  Text(89.6524433849821, 163.08, 'FUELCONSUMPTION_CITY <= 0.229\nmse = 23.721\nsamples = 31\nvalue = 210.613'),
#  Text(86.72610250297973, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.222\nmse = 27.747\nsamples = 20\nvalue = 209.55'),
#  Text(84.06579261025028, 112.90153846153848, 'FUELTYPE_Z <= 0.5\nmse = 8.556\nsamples = 6\nvalue = 212.667'),
#  Text(83.0016686531585, 87.81230769230771, 'mse = 10.889\nsamples = 3\nvalue = 213.667'),
#  Text(85.12991656734206, 87.81230769230771, 'mse = 4.222\nsamples = 3\nvalue = 211.667'),
#  Text(89.38641239570916, 112.90153846153848, 'FUELTYPE_Z <= 0.5\nmse = 30.026\nsamples = 14\nvalue = 208.214'),
#  Text(87.25816448152561, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.225\nmse = 20.444\nsamples = 9\nvalue = 207.667'),
#  Text(86.19404052443383, 62.72307692307692, 'mse = 20.25\nsamples = 2\nvalue = 211.5'),
#  Text(88.32228843861739, 62.72307692307692, 'mse = 15.102\nsamples = 7\nvalue = 206.571'),
#  Text(91.51466030989272, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.225\nmse = 45.76\nsamples = 5\nvalue = 209.2'),
#  Text(90.45053635280094, 62.72307692307692, 'mse = 13.688\nsamples = 4\nvalue = 206.25'),
#  Text(92.57878426698448, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 221.0'),
#  Text(92.57878426698448, 137.99076923076925, 'FUELTYPE_Z <= 0.5\nmse = 10.612\nsamples = 11\nvalue = 212.545'),
#  Text(91.51466030989272, 112.90153846153848, 'mse = 3.84\nsamples = 5\nvalue = 215.6'),
#  Text(93.64290822407627, 112.90153846153848, 'mse = 2.0\nsamples = 6\nvalue = 210.0'),
#  Text(96.83528009535159, 188.16923076923078, 'FUELCONSUMPTION_CITY <= 0.22\nmse = 69.188\nsamples = 4\nvalue = 220.25'),
#  Text(95.77115613825981, 163.08, 'FUELCONSUMPTION_CITY <= 0.21\nmse = 2.25\nsamples = 2\nvalue = 228.5'),
#  Text(94.70703218116805, 137.99076923076925, 'mse = 0.0\nsamples = 1\nvalue = 227.0'),
#  Text(96.83528009535159, 137.99076923076925, 'mse = 0.0\nsamples = 1\nvalue = 230.0'),
#  Text(97.89940405244337, 163.08, 'mse = 0.0\nsamples = 2\nvalue = 212.0'),
#  Text(164.00810488676993, 263.4369230769231, 'FUELCONSUMPTION_CITY <= 0.284\nmse = 367.696\nsamples = 231\nvalue = 241.035'),
#  Text(137.73754469606672, 238.34769230769234, 'FUELTYPE_E <= 0.5\nmse = 273.713\nsamples = 109\nvalue = 226.89'),
#  Text(124.10345649582835, 213.25846153846157, 'FUELCONSUMPTION_CITY <= 0.265\nmse = 134.786\nsamples = 105\nvalue = 229.229'),
#  Text(109.20572109654348, 188.16923076923078, 'FUELCONSUMPTION_CITY <= 0.249\nmse = 67.007\nsamples = 61\nvalue = 223.328'),
#  Text(102.15589988081047, 163.08, 'CYLINDERS <= 0.278\nmse = 23.623\nsamples = 24\nvalue = 218.292'),
#  Text(98.96352800953514, 137.99076923076925, 'FUELTYPE_X <= 0.5\nmse = 20.628\nsamples = 22\nvalue = 218.909'),
#  Text(95.77115613825981, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.241\nmse = 11.09\nsamples = 10\nvalue = 216.1'),
#  Text(94.70703218116805, 87.81230769230771, 'mse = 6.56\nsamples = 5\nvalue = 213.8'),
#  Text(96.83528009535159, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.245\nmse = 5.04\nsamples = 5\nvalue = 218.4'),
#  Text(95.77115613825981, 62.72307692307692, 'mse = 4.222\nsamples = 3\nvalue = 218.333'),
#  Text(97.89940405244337, 62.72307692307692, 'mse = 6.25\nsamples = 2\nvalue = 218.5'),
#  Text(102.15589988081047, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.245\nmse = 16.521\nsamples = 12\nvalue = 221.25'),
#  Text(101.0917759237187, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.241\nmse = 16.975\nsamples = 11\nvalue = 221.545'),
#  Text(100.02765196662692, 62.72307692307692, 'mse = 6.688\nsamples = 4\nvalue = 221.75'),
#  Text(102.15589988081047, 62.72307692307692, 'mse = 22.816\nsamples = 7\nvalue = 221.429'),
#  Text(103.22002383790225, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 218.0'),
#  Text(105.34827175208581, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.243\nmse = 6.25\nsamples = 2\nvalue = 211.5'),
#  Text(104.28414779499403, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 214.0'),
#  Text(106.41239570917757, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 209.0'),
#  Text(116.2555423122765, 163.08, 'FUELTYPE_Z <= 0.5\nmse = 68.025\nsamples = 37\nvalue = 226.595'),
#  Text(109.6047675804529, 137.99076923076925, 'FUELTYPE_X <= 0.5\nmse = 87.213\nsamples = 27\nvalue = 227.481'),
#  Text(108.54064362336113, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 267.0'),
#  Text(110.66889153754468, 112.90153846153848, 'CYLINDERS <= 0.167\nmse = 28.191\nsamples = 26\nvalue = 225.962'),
#  Text(107.47651966626935, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.261\nmse = 23.633\nsamples = 17\nvalue = 227.882'),
#  Text(106.41239570917757, 62.72307692307692, 'FUELCONSUMPTION_CITY <= 0.253\nmse = 7.148\nsamples = 13\nvalue = 225.923'),
#  Text(105.34827175208581, 37.63384615384615, 'mse = 0.64\nsamples = 5\nvalue = 224.6'),
#  Text(107.47651966626935, 37.63384615384615, 'FUELCONSUMPTION_CITY <= 0.257\nmse = 9.438\nsamples = 8\nvalue = 226.75'),
#  Text(106.41239570917757, 12.544615384615383, 'mse = 5.556\nsamples = 3\nvalue = 226.667'),
#  Text(108.54064362336113, 12.544615384615383, 'mse = 11.76\nsamples = 5\nvalue = 226.8'),
#  Text(108.54064362336113, 62.72307692307692, 'mse = 24.188\nsamples = 4\nvalue = 234.25'),
#  Text(113.86126340882001, 87.81230769230771, 'CYLINDERS <= 0.278\nmse = 16.667\nsamples = 9\nvalue = 222.333'),
#  Text(112.79713945172823, 62.72307692307692, 'FUELCONSUMPTION_CITY <= 0.261\nmse = 27.44\nsamples = 5\nvalue = 223.4'),
#  Text(111.73301549463646, 37.63384615384615, 'FUELCONSUMPTION_CITY <= 0.257\nmse = 33.5\nsamples = 4\nvalue = 223.0'),
#  Text(110.66889153754468, 12.544615384615383, 'mse = 44.667\nsamples = 3\nvalue = 223.0'),
#  Text(112.79713945172823, 12.544615384615383, 'mse = 0.0\nsamples = 1\nvalue = 223.0'),
#  Text(113.86126340882001, 37.63384615384615, 'mse = 0.0\nsamples = 1\nvalue = 225.0'),
#  Text(114.92538736591179, 62.72307692307692, 'mse = 0.0\nsamples = 4\nvalue = 221.0'),
#  Text(122.9063170441001, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.257\nmse = 8.36\nsamples = 10\nvalue = 224.2'),
#  Text(120.24600715137066, 112.90153846153848, 'CYLINDERS <= 0.222\nmse = 8.286\nsamples = 7\nvalue = 225.0'),
#  Text(118.11775923718712, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.253\nmse = 10.64\nsamples = 5\nvalue = 225.4'),
#  Text(117.05363528009534, 62.72307692307692, 'mse = 6.25\nsamples = 2\nvalue = 225.5'),
#  Text(119.18188319427888, 62.72307692307692, 'mse = 13.556\nsamples = 3\nvalue = 225.333'),
#  Text(122.37425506555421, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.253\nmse = 1.0\nsamples = 2\nvalue = 224.0'),
#  Text(121.31013110846244, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 225.0'),
#  Text(123.43837902264599, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 223.0'),
#  Text(125.56662693682954, 112.90153846153848, 'CYLINDERS <= 0.222\nmse = 3.556\nsamples = 3\nvalue = 222.333'),
#  Text(124.50250297973777, 87.81230769230771, 'mse = 4.0\nsamples = 2\nvalue = 223.0'),
#  Text(126.63075089392132, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 221.0'),
#  Text(139.0011918951132, 188.16923076923078, 'FUELTYPE_Z <= 0.5\nmse = 113.56\nsamples = 44\nvalue = 237.409'),
#  Text(130.8872467222884, 163.08, 'FUELTYPE_X <= 0.5\nmse = 215.152\nsamples = 16\nvalue = 241.188'),
#  Text(128.75899880810488, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.275\nmse = 2.25\nsamples = 2\nvalue = 276.5'),
#  Text(127.6948748510131, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 275.0'),
#  Text(129.82312276519664, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 278.0'),
#  Text(133.01549463647197, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.269\nmse = 41.98\nsamples = 14\nvalue = 236.143'),
#  Text(131.9513706793802, 112.90153846153848, 'mse = 1.0\nsamples = 2\nvalue = 231.0'),
#  Text(134.07961859356374, 112.90153846153848, 'CYLINDERS <= 0.167\nmse = 43.667\nsamples = 12\nvalue = 237.0'),
#  Text(131.4193087008343, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.276\nmse = 49.01\nsamples = 10\nvalue = 237.7'),
#  Text(129.29106078665075, 62.72307692307692, 'FUELCONSUMPTION_CITY <= 0.273\nmse = 78.25\nsamples = 6\nvalue = 238.5'),
#  Text(128.22693682955898, 37.63384615384615, 'mse = 14.889\nsamples = 3\nvalue = 238.667'),
#  Text(130.35518474374254, 37.63384615384615, 'mse = 141.556\nsamples = 3\nvalue = 238.333'),
#  Text(133.54755661501787, 62.72307692307692, 'FUELCONSUMPTION_CITY <= 0.28\nmse = 2.75\nsamples = 4\nvalue = 236.5'),
#  Text(132.48343265792607, 37.63384615384615, 'mse = 0.889\nsamples = 3\nvalue = 235.667'),
#  Text(134.61168057210963, 37.63384615384615, 'mse = 0.0\nsamples = 1\nvalue = 239.0'),
#  Text(136.7399284862932, 87.81230769230771, 'CYLINDERS <= 0.278\nmse = 2.25\nsamples = 2\nvalue = 233.5'),
#  Text(135.6758045292014, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 232.0'),
#  Text(137.80405244338496, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 235.0'),
#  Text(147.115137067938, 163.08, 'FUELCONSUMPTION_CITY <= 0.273\nmse = 42.688\nsamples = 28\nvalue = 235.25'),
#  Text(142.06054827175205, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.269\nmse = 20.173\nsamples = 9\nvalue = 230.222'),
#  Text(139.93230035756852, 112.90153846153848, 'CYLINDERS <= 0.222\nmse = 11.688\nsamples = 4\nvalue = 233.75'),
#  Text(138.86817640047673, 87.81230769230771, 'mse = 14.889\nsamples = 3\nvalue = 233.333'),
#  Text(140.9964243146603, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 235.0'),
#  Text(144.18879618593562, 112.90153846153848, 'CYLINDERS <= 0.222\nmse = 9.04\nsamples = 5\nvalue = 227.4'),
#  Text(143.12467222884385, 87.81230769230771, 'mse = 0.0\nsamples = 3\nvalue = 225.0'),
#  Text(145.25292014302738, 87.81230769230771, 'mse = 1.0\nsamples = 2\nvalue = 231.0'),
#  Text(152.16972586412393, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.28\nmse = 35.706\nsamples = 19\nvalue = 237.632'),
#  Text(149.5094159713945, 112.90153846153848, 'CYLINDERS <= 0.222\nmse = 48.691\nsamples = 9\nvalue = 239.556'),
#  Text(147.38116805721094, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.276\nmse = 32.75\nsamples = 4\nvalue = 241.5'),
#  Text(146.31704410011918, 62.72307692307692, 'mse = 0.0\nsamples = 2\nvalue = 246.0'),
#  Text(148.4452920143027, 62.72307692307692, 'mse = 25.0\nsamples = 2\nvalue = 237.0'),
#  Text(151.63766388557804, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.276\nmse = 56.0\nsamples = 5\nvalue = 238.0'),
#  Text(150.57353992848627, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 228.0'),
#  Text(152.70178784266983, 62.72307692307692, 'mse = 38.75\nsamples = 4\nvalue = 240.5'),
#  Text(154.83003575685336, 112.90153846153848, 'CYLINDERS <= 0.222\nmse = 17.69\nsamples = 10\nvalue = 235.9'),
#  Text(153.7659117997616, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 232.0'),
#  Text(155.89415971394516, 87.81230769230771, 'mse = 17.778\nsamples = 9\nvalue = 236.333'),
#  Text(151.3716328963051, 213.25846153846157, 'FUELCONSUMPTION_CITY <= 0.278\nmse = 8.25\nsamples = 4\nvalue = 165.5'),
#  Text(150.30750893921333, 188.16923076923078, 'FUELCONSUMPTION_CITY <= 0.273\nmse = 2.0\nsamples = 3\nvalue = 164.0'),
#  Text(149.24338498212154, 163.08, 'mse = 0.0\nsamples = 1\nvalue = 162.0'),
#  Text(151.3716328963051, 163.08, 'mse = 0.0\nsamples = 2\nvalue = 165.0'),
#  Text(152.43575685339687, 188.16923076923078, 'mse = 0.0\nsamples = 1\nvalue = 170.0'),
#  Text(190.27866507747316, 238.34769230769234, 'FUELCONSUMPTION_CITY <= 0.32\nmse = 113.204\nsamples = 122\nvalue = 253.672'),
#  Text(173.5852205005959, 213.25846153846157, 'FUELCONSUMPTION_CITY <= 0.292\nmse = 97.716\nsamples = 77\nvalue = 249.299'),
#  Text(164.40715137067934, 188.16923076923078, 'CYLINDERS <= 0.444\nmse = 133.107\nsamples = 21\nvalue = 243.476'),
#  Text(163.34302741358758, 163.08, 'FUELTYPE_Z <= 0.5\nmse = 121.747\nsamples = 20\nvalue = 242.55'),
#  Text(159.08653158522048, 137.99076923076925, 'FUELTYPE_X <= 0.5\nmse = 297.143\nsamples = 7\nvalue = 247.0'),
#  Text(158.0224076281287, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 286.0'),
#  Text(160.15065554231225, 112.90153846153848, 'CYLINDERS <= 0.222\nmse = 50.917\nsamples = 6\nvalue = 240.5'),
#  Text(158.0224076281287, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.288\nmse = 80.222\nsamples = 3\nvalue = 242.333'),
#  Text(156.95828367103692, 62.72307692307692, 'mse = 64.0\nsamples = 2\nvalue = 238.0'),
#  Text(159.08653158522048, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 251.0'),
#  Text(162.2789034564958, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.288\nmse = 14.889\nsamples = 3\nvalue = 238.667'),
#  Text(161.21477949940402, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 244.0'),
#  Text(163.34302741358758, 62.72307692307692, 'mse = 1.0\nsamples = 2\nvalue = 236.0'),
#  Text(167.59952324195467, 137.99076923076925, 'CYLINDERS <= 0.222\nmse = 10.899\nsamples = 13\nvalue = 240.154'),
#  Text(165.47127532777114, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.288\nmse = 3.556\nsamples = 3\nvalue = 236.333'),
#  Text(164.40715137067934, 87.81230769230771, 'mse = 4.0\nsamples = 2\nvalue = 237.0'),
#  Text(166.5353992848629, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 235.0'),
#  Text(169.72777115613823, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.288\nmse = 7.41\nsamples = 10\nvalue = 241.3'),
#  Text(168.66364719904647, 87.81230769230771, 'mse = 8.25\nsamples = 4\nvalue = 239.5'),
#  Text(170.79189511323, 87.81230769230771, 'mse = 3.25\nsamples = 6\nvalue = 242.5'),
#  Text(165.47127532777114, 163.08, 'mse = 0.0\nsamples = 1\nvalue = 262.0'),
#  Text(182.76328963051247, 188.16923076923078, 'FUELCONSUMPTION_CITY <= 0.308\nmse = 66.964\nsamples = 56\nvalue = 251.482'),
#  Text(176.64457687723478, 163.08, 'FUELTYPE_Z <= 0.5\nmse = 96.378\nsamples = 29\nvalue = 249.966'),
#  Text(173.98426698450533, 137.99076923076925, 'FUELTYPE_X <= 0.5\nmse = 152.109\nsamples = 16\nvalue = 252.375'),
#  Text(172.92014302741356, 112.90153846153848, 'mse = 0.0\nsamples = 2\nvalue = 281.0'),
#  Text(175.04839094159712, 112.90153846153848, 'CYLINDERS <= 0.222\nmse = 40.061\nsamples = 14\nvalue = 248.286'),
#  Text(172.92014302741356, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.302\nmse = 33.5\nsamples = 4\nvalue = 253.0'),
#  Text(171.8560190703218, 62.72307692307692, 'FUELCONSUMPTION_CITY <= 0.296\nmse = 42.889\nsamples = 3\nvalue = 252.333'),
#  Text(170.79189511323, 37.63384615384615, 'mse = 64.0\nsamples = 2\nvalue = 252.0'),
#  Text(172.92014302741356, 37.63384615384615, 'mse = 0.0\nsamples = 1\nvalue = 253.0'),
#  Text(173.98426698450533, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 255.0'),
#  Text(177.17663885578065, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.304\nmse = 30.24\nsamples = 10\nvalue = 246.4'),
#  Text(176.1125148986889, 62.72307692307692, 'FUELCONSUMPTION_CITY <= 0.3\nmse = 33.5\nsamples = 4\nvalue = 244.0'),
#  Text(175.04839094159712, 37.63384615384615, 'mse = 22.889\nsamples = 3\nvalue = 246.333'),
#  Text(177.17663885578065, 37.63384615384615, 'mse = 0.0\nsamples = 1\nvalue = 237.0'),
#  Text(178.24076281287245, 62.72307692307692, 'mse = 21.667\nsamples = 6\nvalue = 248.0'),
#  Text(179.3048867699642, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.296\nmse = 11.846\nsamples = 13\nvalue = 247.0'),
#  Text(178.24076281287245, 112.90153846153848, 'mse = 1.0\nsamples = 2\nvalue = 243.0'),
#  Text(180.36901072705598, 112.90153846153848, 'CYLINDERS <= 0.222\nmse = 10.38\nsamples = 11\nvalue = 247.727'),
#  Text(179.3048867699642, 87.81230769230771, 'mse = 4.0\nsamples = 2\nvalue = 244.0'),
#  Text(181.43313468414777, 87.81230769230771, 'CYLINDERS <= 0.444\nmse = 8.025\nsamples = 9\nvalue = 248.556'),
#  Text(180.36901072705598, 62.72307692307692, 'FUELCONSUMPTION_CITY <= 0.3\nmse = 8.109\nsamples = 8\nvalue = 248.875'),
#  Text(179.3048867699642, 37.63384615384615, 'mse = 4.222\nsamples = 3\nvalue = 250.667'),
#  Text(181.43313468414777, 37.63384615384615, 'FUELCONSUMPTION_CITY <= 0.304\nmse = 7.36\nsamples = 5\nvalue = 247.8'),
#  Text(180.36901072705598, 12.544615384615383, 'mse = 0.889\nsamples = 3\nvalue = 246.667'),
#  Text(182.49725864123954, 12.544615384615383, 'mse = 12.25\nsamples = 2\nvalue = 249.5'),
#  Text(182.49725864123954, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 246.0'),
#  Text(188.8820023837902, 163.08, 'CYLINDERS <= 0.222\nmse = 30.247\nsamples = 27\nvalue = 253.111'),
#  Text(185.68963051251487, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.316\nmse = 58.16\nsamples = 5\nvalue = 258.8'),
#  Text(184.6255065554231, 112.90153846153848, 'FUELTYPE_Z <= 0.5\nmse = 26.188\nsamples = 4\nvalue = 255.75'),
#  Text(183.5613825983313, 87.81230769230771, 'mse = 12.25\nsamples = 2\nvalue = 258.5'),
#  Text(185.68963051251487, 87.81230769230771, 'mse = 25.0\nsamples = 2\nvalue = 253.0'),
#  Text(186.75375446960663, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 271.0'),
#  Text(192.07437425506552, 137.99076923076925, 'FUELTYPE_X <= 0.5\nmse = 14.876\nsamples = 22\nvalue = 251.818'),
#  Text(188.8820023837902, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.312\nmse = 7.818\nsamples = 11\nvalue = 253.0'),
#  Text(187.81787842669843, 87.81230769230771, 'mse = 15.6\nsamples = 5\nvalue = 253.0'),
#  Text(189.94612634088196, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.316\nmse = 1.333\nsamples = 6\nvalue = 253.0'),
#  Text(188.8820023837902, 62.72307692307692, 'mse = 0.0\nsamples = 2\nvalue = 253.0'),
#  Text(191.01025029797376, 62.72307692307692, 'mse = 2.0\nsamples = 4\nvalue = 253.0'),
#  Text(195.26674612634085, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.316\nmse = 19.14\nsamples = 11\nvalue = 250.636'),
#  Text(194.20262216924908, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.312\nmse = 26.694\nsamples = 7\nvalue = 249.857'),
#  Text(193.1384982121573, 62.72307692307692, 'mse = 27.688\nsamples = 4\nvalue = 250.75'),
#  Text(195.26674612634085, 62.72307692307692, 'mse = 22.889\nsamples = 3\nvalue = 248.667'),
#  Text(196.33087008343261, 87.81230769230771, 'mse = 3.0\nsamples = 4\nvalue = 252.0'),
#  Text(206.9721096543504, 213.25846153846157, 'FUELCONSUMPTION_CITY <= 0.331\nmse = 50.976\nsamples = 45\nvalue = 261.156'),
#  Text(202.71561382598327, 188.16923076923078, 'FUELTYPE_Z <= 0.5\nmse = 73.485\nsamples = 26\nvalue = 259.769'),
#  Text(200.58736591179974, 163.08, 'FUELTYPE_X <= 0.5\nmse = 91.673\nsamples = 19\nvalue = 261.105'),
#  Text(199.52324195470794, 137.99076923076925, 'mse = 0.0\nsamples = 1\nvalue = 294.0'),
#  Text(201.6514898688915, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.327\nmse = 33.312\nsamples = 18\nvalue = 259.278'),
#  Text(199.52324195470794, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.324\nmse = 26.485\nsamples = 13\nvalue = 257.769'),
#  Text(198.45911799761618, 87.81230769230771, 'CYLINDERS <= 0.222\nmse = 36.938\nsamples = 8\nvalue = 257.25'),
#  Text(197.3949940405244, 62.72307692307692, 'mse = 59.556\nsamples = 3\nvalue = 256.667'),
#  Text(199.52324195470794, 62.72307692307692, 'mse = 23.04\nsamples = 5\nvalue = 257.6'),
#  Text(200.58736591179974, 87.81230769230771, 'mse = 8.64\nsamples = 5\nvalue = 258.6'),
#  Text(203.77973778307506, 112.90153846153848, 'CYLINDERS <= 0.222\nmse = 29.76\nsamples = 5\nvalue = 263.2'),
#  Text(202.71561382598327, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 274.0'),
#  Text(204.84386174016683, 87.81230769230771, 'mse = 0.75\nsamples = 4\nvalue = 260.5'),
#  Text(204.84386174016683, 163.08, 'FUELCONSUMPTION_CITY <= 0.325\nmse = 6.122\nsamples = 7\nvalue = 256.143'),
#  Text(203.77973778307506, 137.99076923076925, 'mse = 8.25\nsamples = 4\nvalue = 255.5'),
#  Text(205.90798569725862, 137.99076923076925, 'mse = 2.0\nsamples = 3\nvalue = 257.0'),
#  Text(211.22860548271748, 188.16923076923078, 'FUELCONSUMPTION_CITY <= 0.335\nmse = 13.945\nsamples = 19\nvalue = 263.053'),
#  Text(209.10035756853395, 163.08, 'FUELTYPE_X <= 0.5\nmse = 16.876\nsamples = 11\nvalue = 262.182'),
#  Text(208.03623361144216, 137.99076923076925, 'mse = 8.667\nsamples = 3\nvalue = 263.0'),
#  Text(210.16448152562572, 137.99076923076925, 'mse = 19.609\nsamples = 8\nvalue = 261.875'),
#  Text(213.35685339690104, 163.08, 'FUELTYPE_Z <= 0.5\nmse = 7.438\nsamples = 8\nvalue = 264.25'),
#  Text(212.29272943980928, 137.99076923076925, 'mse = 9.84\nsamples = 5\nvalue = 263.6'),
#  Text(214.4209773539928, 137.99076923076925, 'CYLINDERS <= 0.444\nmse = 1.556\nsamples = 3\nvalue = 265.333'),
#  Text(213.35685339690104, 112.90153846153848, 'mse = 1.0\nsamples = 2\nvalue = 266.0'),
#  Text(215.4851013110846, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 264.0'),
#  Text(322.130274135876, 288.5261538461539, 'CYLINDERS <= 0.444\nmse = 2197.174\nsamples = 313\nvalue = 315.447'),
#  Text(272.2660905840286, 263.4369230769231, 'FUELTYPE_E <= 0.5\nmse = 538.193\nsamples = 133\nvalue = 280.098'),
#  Text(257.35172824791414, 238.34769230769234, 'FUELCONSUMPTION_CITY <= 0.402\nmse = 290.679\nsamples = 99\nvalue = 288.374'),
#  Text(240.42550655542308, 213.25846153846157, 'FUELCONSUMPTION_CITY <= 0.363\nmse = 101.917\nsamples = 81\nvalue = 282.309'),
#  Text(227.58951132300353, 188.16923076923078, 'FUELCONSUMPTION_CITY <= 0.351\nmse = 24.724\nsamples = 33\nvalue = 272.939'),
#  Text(221.6038140643623, 163.08, 'FUELTYPE_Z <= 0.5\nmse = 12.734\nsamples = 16\nvalue = 269.875'),
#  Text(218.67747318235993, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.345\nmse = 9.837\nsamples = 7\nvalue = 268.857'),
#  Text(217.61334922526814, 112.90153846153848, 'mse = 2.333\nsamples = 6\nvalue = 270.0'),
#  Text(219.7415971394517, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 262.0'),
#  Text(224.5301549463647, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.343\nmse = 13.556\nsamples = 9\nvalue = 270.667'),
#  Text(221.86984505363526, 112.90153846153848, 'CYLINDERS <= 0.222\nmse = 30.25\nsamples = 2\nvalue = 272.5'),
#  Text(220.80572109654346, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 267.0'),
#  Text(222.93396901072703, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 278.0'),
#  Text(227.19046483909412, 112.90153846153848, 'CYLINDERS <= 0.222\nmse = 7.551\nsamples = 7\nvalue = 270.143'),
#  Text(225.0622169249106, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.347\nmse = 12.25\nsamples = 2\nvalue = 270.5'),
#  Text(223.9980929678188, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 274.0'),
#  Text(226.12634088200235, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 267.0'),
#  Text(229.31871275327768, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.347\nmse = 5.6\nsamples = 5\nvalue = 270.0'),
#  Text(228.2545887961859, 62.72307692307692, 'mse = 1.0\nsamples = 2\nvalue = 268.0'),
#  Text(230.38283671036945, 62.72307692307692, 'mse = 4.222\nsamples = 3\nvalue = 271.333'),
#  Text(233.57520858164477, 163.08, 'CYLINDERS <= 0.222\nmse = 18.851\nsamples = 17\nvalue = 275.824'),
#  Text(232.511084624553, 137.99076923076925, 'mse = 0.0\nsamples = 1\nvalue = 283.0'),
#  Text(234.63933253873657, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.355\nmse = 16.609\nsamples = 16\nvalue = 275.375'),
#  Text(232.511084624553, 112.90153846153848, 'FUELTYPE_X <= 0.5\nmse = 22.543\nsamples = 9\nvalue = 274.111'),
#  Text(231.44696066746124, 87.81230769230771, 'mse = 4.0\nsamples = 2\nvalue = 276.0'),
#  Text(233.57520858164477, 87.81230769230771, 'mse = 26.531\nsamples = 7\nvalue = 273.571'),
#  Text(236.7675804529201, 112.90153846153848, 'FUELTYPE_Z <= 0.5\nmse = 4.286\nsamples = 7\nvalue = 277.0'),
#  Text(235.70345649582833, 87.81230769230771, 'mse = 1.889\nsamples = 6\nvalue = 276.333'),
#  Text(237.8317044100119, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 281.0'),
#  Text(253.26150178784263, 188.16923076923078, 'FUELCONSUMPTION_CITY <= 0.39\nmse = 53.146\nsamples = 48\nvalue = 288.75'),
#  Text(247.40882002383788, 163.08, 'FUELCONSUMPTION_CITY <= 0.375\nmse = 34.514\nsamples = 33\nvalue = 286.303'),
#  Text(243.15232419547075, 137.99076923076925, 'FUELTYPE_Z <= 0.5\nmse = 35.0\nsamples = 16\nvalue = 284.0'),
#  Text(241.02407628128722, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.371\nmse = 45.174\nsamples = 11\nvalue = 282.909'),
#  Text(239.95995232419543, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.367\nmse = 26.188\nsamples = 4\nvalue = 285.25'),
#  Text(238.89582836710366, 62.72307692307692, 'mse = 0.889\nsamples = 3\nvalue = 282.333'),
#  Text(241.02407628128722, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 294.0'),
#  Text(242.088200238379, 87.81230769230771, 'mse = 51.102\nsamples = 7\nvalue = 281.571'),
#  Text(245.28057210965432, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.369\nmse = 4.24\nsamples = 5\nvalue = 286.4'),
#  Text(244.21644815256255, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 283.0'),
#  Text(246.34469606674608, 87.81230769230771, 'CYLINDERS <= 0.222\nmse = 1.688\nsamples = 4\nvalue = 287.25'),
#  Text(245.28057210965432, 62.72307692307692, 'mse = 0.0\nsamples = 3\nvalue = 288.0'),
#  Text(247.40882002383788, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 285.0'),
#  Text(251.66531585220497, 137.99076923076925, 'FUELTYPE_Z <= 0.5\nmse = 24.367\nsamples = 17\nvalue = 288.471'),
#  Text(249.5370679380214, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.38\nmse = 24.083\nsamples = 11\nvalue = 289.909'),
#  Text(248.47294398092964, 87.81230769230771, 'mse = 39.472\nsamples = 6\nvalue = 288.833'),
#  Text(250.6011918951132, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.386\nmse = 2.56\nsamples = 5\nvalue = 291.2'),
#  Text(249.5370679380214, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 292.0'),
#  Text(251.66531585220497, 62.72307692307692, 'mse = 3.0\nsamples = 4\nvalue = 291.0'),
#  Text(253.79356376638853, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.38\nmse = 14.139\nsamples = 6\nvalue = 285.833'),
#  Text(252.72943980929674, 87.81230769230771, 'mse = 0.0\nsamples = 2\nvalue = 283.0'),
#  Text(254.8576877234803, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.386\nmse = 15.188\nsamples = 4\nvalue = 287.25'),
#  Text(253.79356376638853, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 294.0'),
#  Text(255.92181168057206, 62.72307692307692, 'mse = 0.0\nsamples = 3\nvalue = 285.0'),
#  Text(259.1141835518474, 163.08, 'FUELTYPE_X <= 0.5\nmse = 51.982\nsamples = 15\nvalue = 294.133'),
#  Text(256.98593563766383, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.394\nmse = 18.5\nsamples = 4\nvalue = 287.0'),
#  Text(255.92181168057206, 112.90153846153848, 'mse = 4.0\nsamples = 2\nvalue = 283.0'),
#  Text(258.0500595947556, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.398\nmse = 1.0\nsamples = 2\nvalue = 291.0'),
#  Text(256.98593563766383, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 290.0'),
#  Text(259.1141835518474, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 292.0'),
#  Text(261.24243146603095, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.394\nmse = 38.926\nsamples = 11\nvalue = 296.727'),
#  Text(260.17830750893916, 112.90153846153848, 'mse = 33.556\nsamples = 3\nvalue = 299.667'),
#  Text(262.30655542312275, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.398\nmse = 36.484\nsamples = 8\nvalue = 295.625'),
#  Text(261.24243146603095, 87.81230769230771, 'mse = 41.265\nsamples = 7\nvalue = 295.857'),
#  Text(263.3706793802145, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 294.0'),
#  Text(274.2779499404052, 213.25846153846157, 'FUELCONSUMPTION_CITY <= 0.445\nmse = 229.667\nsamples = 18\nvalue = 315.667'),
#  Text(270.28748510131106, 188.16923076923078, 'FUELCONSUMPTION_CITY <= 0.414\nmse = 78.352\nsamples = 14\nvalue = 309.071'),
#  Text(267.6271752085816, 163.08, 'FUELTYPE_Z <= 0.5\nmse = 58.98\nsamples = 7\nvalue = 304.143'),
#  Text(265.4989272943981, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.408\nmse = 9.188\nsamples = 4\nvalue = 309.75'),
#  Text(264.4348033373063, 112.90153846153848, 'mse = 0.0\nsamples = 3\nvalue = 308.0'),
#  Text(266.5630512514898, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 315.0'),
#  Text(269.75542312276514, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.41\nmse = 27.556\nsamples = 3\nvalue = 296.667'),
#  Text(268.6912991656734, 112.90153846153848, 'mse = 25.0\nsamples = 2\nvalue = 299.0'),
#  Text(270.81954707985693, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 292.0'),
#  Text(272.94779499404046, 163.08, 'FUELCONSUMPTION_CITY <= 0.418\nmse = 49.143\nsamples = 7\nvalue = 314.0'),
#  Text(271.8836710369487, 137.99076923076925, 'mse = 0.0\nsamples = 1\nvalue = 322.0'),
#  Text(274.01191895113226, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.441\nmse = 44.889\nsamples = 6\nvalue = 312.667'),
#  Text(272.94779499404046, 112.90153846153848, 'FUELTYPE_Z <= 0.5\nmse = 32.96\nsamples = 5\nvalue = 310.8'),
#  Text(270.81954707985693, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.425\nmse = 14.889\nsamples = 3\nvalue = 313.333'),
#  Text(269.75542312276514, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 308.0'),
#  Text(271.8836710369487, 62.72307692307692, 'FUELCONSUMPTION_CITY <= 0.435\nmse = 1.0\nsamples = 2\nvalue = 316.0'),
#  Text(270.81954707985693, 37.63384615384615, 'mse = 0.0\nsamples = 1\nvalue = 315.0'),
#  Text(272.94779499404046, 37.63384615384615, 'mse = 0.0\nsamples = 1\nvalue = 317.0'),
#  Text(275.07604290822405, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.437\nmse = 36.0\nsamples = 2\nvalue = 307.0'),
#  Text(274.01191895113226, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 313.0'),
#  Text(276.1401668653158, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 301.0'),
#  Text(275.07604290822405, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 322.0'),
#  Text(278.2684147794994, 188.16923076923078, 'FUELCONSUMPTION_CITY <= 0.471\nmse = 74.188\nsamples = 4\nvalue = 338.75'),
#  Text(277.2042908224076, 163.08, 'FUELCONSUMPTION_CITY <= 0.451\nmse = 12.25\nsamples = 2\nvalue = 330.5'),
#  Text(276.1401668653158, 137.99076923076925, 'mse = 0.0\nsamples = 1\nvalue = 327.0'),
#  Text(278.2684147794994, 137.99076923076925, 'mse = 0.0\nsamples = 1\nvalue = 334.0'),
#  Text(279.3325387365911, 163.08, 'mse = 0.0\nsamples = 2\nvalue = 347.0'),
#  Text(287.180452920143, 238.34769230769234, 'FUELCONSUMPTION_CITY <= 0.502\nmse = 478.765\nsamples = 34\nvalue = 256.0'),
#  Text(281.4607866507747, 213.25846153846157, 'FUELCONSUMPTION_CITY <= 0.416\nmse = 141.432\nsamples = 9\nvalue = 225.889'),
#  Text(280.3966626936829, 188.16923076923078, 'mse = 0.0\nsamples = 1\nvalue = 195.0'),
#  Text(282.52491060786645, 188.16923076923078, 'FUELCONSUMPTION_CITY <= 0.488\nmse = 24.938\nsamples = 8\nvalue = 229.75'),
#  Text(281.4607866507747, 163.08, 'FUELCONSUMPTION_CITY <= 0.478\nmse = 9.889\nsamples = 6\nvalue = 227.333'),
#  Text(280.3966626936829, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.473\nmse = 8.667\nsamples = 3\nvalue = 225.0'),
#  Text(279.3325387365911, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.465\nmse = 6.25\nsamples = 2\nvalue = 226.5'),
#  Text(278.2684147794994, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 224.0'),
#  Text(280.3966626936829, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 229.0'),
#  Text(281.4607866507747, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 222.0'),
#  Text(282.52491060786645, 137.99076923076925, 'mse = 0.222\nsamples = 3\nvalue = 229.667'),
#  Text(283.58903456495824, 163.08, 'mse = 0.0\nsamples = 2\nvalue = 237.0'),
#  Text(292.90011918951126, 213.25846153846157, 'FUELCONSUMPTION_CITY <= 0.573\nmse = 156.294\nsamples = 25\nvalue = 266.84'),
#  Text(288.37759237187123, 188.16923076923078, 'FUELCONSUMPTION_CITY <= 0.549\nmse = 45.638\nsamples = 14\nvalue = 257.929'),
#  Text(285.7172824791418, 163.08, 'FUELCONSUMPTION_CITY <= 0.512\nmse = 5.265\nsamples = 7\nvalue = 252.143'),
#  Text(284.65315852205003, 137.99076923076925, 'mse = 0.0\nsamples = 2\nvalue = 250.0'),
#  Text(286.78140643623357, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.535\nmse = 4.8\nsamples = 5\nvalue = 253.0'),
#  Text(284.65315852205003, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.524\nmse = 1.0\nsamples = 2\nvalue = 255.0'),
#  Text(283.58903456495824, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 256.0'),
#  Text(285.7172824791418, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 254.0'),
#  Text(288.9096543504171, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.541\nmse = 2.889\nsamples = 3\nvalue = 251.667'),
#  Text(287.84553039332536, 87.81230769230771, 'mse = 0.25\nsamples = 2\nvalue = 250.5'),
#  Text(289.9737783075089, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 254.0'),
#  Text(291.0379022646007, 163.08, 'FUELCONSUMPTION_CITY <= 0.555\nmse = 19.061\nsamples = 7\nvalue = 263.714'),
#  Text(289.9737783075089, 137.99076923076925, 'mse = 0.0\nsamples = 2\nvalue = 259.0'),
#  Text(292.1020262216924, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.563\nmse = 14.24\nsamples = 5\nvalue = 265.6'),
#  Text(291.0379022646007, 112.90153846153848, 'mse = 17.0\nsamples = 4\nvalue = 266.0'),
#  Text(293.1661501787842, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 264.0'),
#  Text(297.42264600715134, 188.16923076923078, 'FUELCONSUMPTION_CITY <= 0.596\nmse = 67.421\nsamples = 11\nvalue = 278.182'),
#  Text(295.29439809296775, 163.08, 'FUELCONSUMPTION_CITY <= 0.582\nmse = 23.583\nsamples = 6\nvalue = 271.5'),
#  Text(294.230274135876, 137.99076923076925, 'mse = 33.5\nsamples = 4\nvalue = 272.0'),
#  Text(296.35852205005955, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.59\nmse = 2.25\nsamples = 2\nvalue = 270.5'),
#  Text(295.29439809296775, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 269.0'),
#  Text(297.42264600715134, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 272.0'),
#  Text(299.5508939213349, 163.08, 'FUELCONSUMPTION_CITY <= 0.604\nmse = 2.16\nsamples = 5\nvalue = 286.2'),
#  Text(298.4867699642431, 137.99076923076925, 'mse = 0.0\nsamples = 2\nvalue = 285.0'),
#  Text(300.61501787842667, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.614\nmse = 2.0\nsamples = 3\nvalue = 287.0'),
#  Text(299.5508939213349, 112.90153846153848, 'mse = 0.0\nsamples = 2\nvalue = 288.0'),
#  Text(301.6791418355184, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 285.0'),
#  Text(371.9944576877234, 263.4369230769231, 'FUELCONSUMPTION_CITY <= 0.476\nmse = 1817.446\nsamples = 180\nvalue = 341.567'),
#  Text(331.6076281287246, 238.34769230769234, 'FUELCONSUMPTION_CITY <= 0.437\nmse = 427.998\nsamples = 74\nvalue = 304.689'),
#  Text(316.5768772348033, 213.25846153846157, 'FUELCONSUMPTION_CITY <= 0.386\nmse = 166.572\nsamples = 44\nvalue = 290.705'),
#  Text(308.595947556615, 188.16923076923078, 'FUELCONSUMPTION_CITY <= 0.363\nmse = 80.65\nsamples = 10\nvalue = 271.5'),
#  Text(305.93563766388553, 163.08, 'FUELCONSUMPTION_CITY <= 0.351\nmse = 17.36\nsamples = 5\nvalue = 263.2'),
#  Text(304.87151370679373, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.347\nmse = 13.25\nsamples = 4\nvalue = 264.5'),
#  Text(303.807389749702, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.343\nmse = 14.889\nsamples = 3\nvalue = 263.667'),
#  Text(302.7432657926102, 87.81230769230771, 'mse = 12.25\nsamples = 2\nvalue = 265.5'),
#  Text(304.87151370679373, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 260.0'),
#  Text(305.93563766388553, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 267.0'),
#  Text(306.9997616209773, 137.99076923076925, 'mse = 0.0\nsamples = 1\nvalue = 258.0'),
#  Text(311.2562574493444, 163.08, 'FUELCONSUMPTION_CITY <= 0.378\nmse = 6.16\nsamples = 5\nvalue = 279.8'),
#  Text(309.12800953516086, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.375\nmse = 1.0\nsamples = 2\nvalue = 277.0'),
#  Text(308.06388557806906, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 276.0'),
#  Text(310.19213349225265, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 278.0'),
# ...
#  Text(336.795232419547, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.441\nmse = 74.0\nsamples = 3\nvalue = 318.0'),
#  Text(335.73110846245527, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 329.0'),
#  Text(337.8593563766388, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.445\nmse = 20.25\nsamples = 2\nvalue = 312.5'),
#  Text(336.795232419547, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 317.0'),
#  Text(338.9234803337306, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 308.0'),
#  Text(341.0517282479141, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.445\nmse = 26.333\nsamples = 6\nvalue = 315.0'),
#  Text(339.98760429082233, 112.90153846153848, 'mse = 44.667\nsamples = 3\nvalue = 313.0'),
#  Text(342.1158522050059, 112.90153846153848, 'mse = 0.0\nsamples = 3\nvalue = 317.0'),
#  Text(344.24410011918945, 163.08, 'FUELTYPE_X <= 0.5\nmse = 3.0\nsamples = 4\nvalue = 323.0'),
#  Text(343.17997616209766, 137.99076923076925, 'mse = 3.556\nsamples = 3\nvalue = 322.667'),
#  Text(345.30822407628125, 137.99076923076925, 'mse = 0.0\nsamples = 1\nvalue = 324.0'),
#  Text(351.6929678188319, 188.16923076923078, 'FUELTYPE_Z <= 0.5\nmse = 84.242\nsamples = 17\nvalue = 330.588'),
#  Text(348.5005959475566, 163.08, 'FUELCONSUMPTION_CITY <= 0.465\nmse = 8.688\nsamples = 4\nvalue = 338.75'),
#  Text(347.4364719904648, 137.99076923076925, 'mse = 0.0\nsamples = 2\nvalue = 336.0'),
#  Text(349.5647199046483, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.473\nmse = 2.25\nsamples = 2\nvalue = 341.5'),
#  Text(348.5005959475566, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 340.0'),
#  Text(350.6288438617401, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 343.0'),
#  Text(354.88533969010723, 163.08, 'FUELCONSUMPTION_CITY <= 0.473\nmse = 80.686\nsamples = 13\nvalue = 328.077'),
#  Text(353.82121573301544, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.469\nmse = 81.521\nsamples = 12\nvalue = 328.75'),
#  Text(352.75709177592364, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.463\nmse = 27.688\nsamples = 4\nvalue = 331.25'),
#  Text(351.6929678188319, 87.81230769230771, 'mse = 6.25\nsamples = 2\nvalue = 326.5'),
#  Text(353.82121573301544, 87.81230769230771, 'mse = 4.0\nsamples = 2\nvalue = 336.0'),
#  Text(354.88533969010723, 112.90153846153848, 'mse = 103.75\nsamples = 8\nvalue = 327.5'),
#  Text(355.94946364719897, 137.99076923076925, 'mse = 0.0\nsamples = 1\nvalue = 320.0'),
#  Text(412.38128724672225, 238.34769230769234, 'FUELTYPE_E <= 0.5\nmse = 1175.252\nsamples = 106\nvalue = 367.311'),
#  Text(391.2650774731823, 213.25846153846157, 'FUELCONSUMPTION_CITY <= 0.571\nmse = 878.172\nsamples = 77\nvalue = 376.506'),
#  Text(370.5811680572109, 188.16923076923078, 'FUELCONSUMPTION_CITY <= 0.508\nmse = 246.448\nsamples = 51\nvalue = 359.941'),
#  Text(361.80214541120375, 163.08, 'FUELCONSUMPTION_CITY <= 0.502\nmse = 68.651\nsamples = 17\nvalue = 343.235'),
#  Text(359.1418355184743, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.492\nmse = 38.222\nsamples = 12\nvalue = 341.333'),
#  Text(357.01358760429076, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.488\nmse = 41.556\nsamples = 6\nvalue = 344.333'),
#  Text(355.94946364719897, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.48\nmse = 13.688\nsamples = 4\nvalue = 340.75'),
#  Text(354.88533969010723, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 347.0'),
#  Text(357.01358760429076, 62.72307692307692, 'FUELCONSUMPTION_CITY <= 0.484\nmse = 0.889\nsamples = 3\nvalue = 338.667'),
#  Text(355.94946364719897, 37.63384615384615, 'mse = 0.0\nsamples = 2\nvalue = 338.0'),
#  Text(358.07771156138256, 37.63384615384615, 'mse = 0.0\nsamples = 1\nvalue = 340.0'),
#  Text(358.07771156138256, 87.81230769230771, 'mse = 20.25\nsamples = 2\nvalue = 351.5'),
#  Text(361.2700834326579, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.496\nmse = 16.889\nsamples = 6\nvalue = 338.333'),
#  Text(360.2059594755661, 87.81230769230771, 'FUELTYPE_Z <= 0.5\nmse = 11.688\nsamples = 4\nvalue = 336.75'),
#  Text(359.1418355184743, 62.72307692307692, 'mse = 20.25\nsamples = 2\nvalue = 335.5'),
#  Text(361.2700834326579, 62.72307692307692, 'mse = 0.0\nsamples = 2\nvalue = 338.0'),
#  Text(362.3342073897496, 87.81230769230771, 'mse = 12.25\nsamples = 2\nvalue = 341.5'),
#  Text(364.4624553039332, 137.99076923076925, 'FUELTYPE_Z <= 0.5\nmse = 112.16\nsamples = 5\nvalue = 347.8'),
#  Text(363.3983313468414, 112.90153846153848, 'mse = 1.0\nsamples = 2\nvalue = 355.0'),
#  Text(365.52657926102495, 112.90153846153848, 'mse = 128.667\nsamples = 3\nvalue = 343.0'),
#  Text(379.36019070321805, 163.08, 'FUELTYPE_Z <= 0.5\nmse = 126.031\nsamples = 34\nvalue = 368.294'),
#  Text(370.84719904648387, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.531\nmse = 56.916\nsamples = 15\nvalue = 376.133'),
#  Text(367.65482717520854, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.514\nmse = 25.25\nsamples = 4\nvalue = 366.5'),
#  Text(366.59070321811674, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 373.0'),
#  Text(368.7189511323003, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.52\nmse = 14.889\nsamples = 3\nvalue = 364.333'),
#  Text(367.65482717520854, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 359.0'),
#  Text(369.78307508939207, 62.72307692307692, 'FUELCONSUMPTION_CITY <= 0.525\nmse = 1.0\nsamples = 2\nvalue = 367.0'),
#  Text(368.7189511323003, 37.63384615384615, 'mse = 0.0\nsamples = 1\nvalue = 366.0'),
#  Text(370.84719904648387, 37.63384615384615, 'mse = 0.0\nsamples = 1\nvalue = 368.0'),
#  Text(374.0395709177592, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.539\nmse = 22.413\nsamples = 11\nvalue = 379.636'),
#  Text(372.9754469606674, 87.81230769230771, 'mse = 31.36\nsamples = 5\nvalue = 377.2'),
#  Text(375.10369487485093, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.563\nmse = 5.889\nsamples = 6\nvalue = 381.667'),
#  Text(374.0395709177592, 62.72307692307692, 'FUELCONSUMPTION_CITY <= 0.553\nmse = 6.4\nsamples = 5\nvalue = 382.0'),
#  Text(372.9754469606674, 37.63384615384615, 'mse = 6.75\nsamples = 4\nvalue = 381.5'),
#  Text(375.10369487485093, 37.63384615384615, 'mse = 0.0\nsamples = 1\nvalue = 384.0'),
#  Text(376.1678188319427, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 380.0'),
#  Text(387.87318235995224, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.535\nmse = 93.778\nsamples = 19\nvalue = 362.105'),
#  Text(382.5525625744934, 112.90153846153848, 'CYLINDERS <= 0.667\nmse = 27.333\nsamples = 9\nvalue = 356.667'),
#  Text(379.36019070321805, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.514\nmse = 30.472\nsamples = 6\nvalue = 354.833'),
#  Text(378.29606674612626, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 363.0'),
#  Text(380.42431466030985, 62.72307692307692, 'FUELCONSUMPTION_CITY <= 0.522\nmse = 20.56\nsamples = 5\nvalue = 353.2'),
#  Text(379.36019070321805, 37.63384615384615, 'mse = 0.0\nsamples = 1\nvalue = 352.0'),
#  Text(381.4884386174016, 37.63384615384615, 'FUELCONSUMPTION_CITY <= 0.527\nmse = 25.25\nsamples = 4\nvalue = 353.5'),
#  Text(380.42431466030985, 12.544615384615383, 'mse = 0.0\nsamples = 1\nvalue = 354.0'),
#  Text(382.5525625744934, 12.544615384615383, 'mse = 33.556\nsamples = 3\nvalue = 353.333'),
#  Text(385.7449344457687, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.525\nmse = 0.889\nsamples = 3\nvalue = 360.333'),
#  Text(384.6808104886769, 62.72307692307692, 'CYLINDERS <= 0.889\nmse = 1.0\nsamples = 2\nvalue = 360.0'),
#  Text(383.6166865315852, 37.63384615384615, 'mse = 0.0\nsamples = 1\nvalue = 361.0'),
#  Text(385.7449344457687, 37.63384615384615, 'mse = 0.0\nsamples = 1\nvalue = 359.0'),
#  Text(386.8090584028605, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 361.0'),
#  Text(393.19380214541115, 112.90153846153848, 'CYLINDERS <= 0.667\nmse = 103.0\nsamples = 10\nvalue = 367.0'),
#  Text(390.0014302741358, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.545\nmse = 40.24\nsamples = 5\nvalue = 375.4'),
#  Text(388.93730631704403, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 363.0'),
#  Text(391.06555423122757, 62.72307692307692, 'FUELCONSUMPTION_CITY <= 0.551\nmse = 2.25\nsamples = 4\nvalue = 378.5'),
#  Text(390.0014302741358, 37.63384615384615, 'mse = 0.0\nsamples = 1\nvalue = 380.0'),
#  Text(392.12967818831936, 37.63384615384615, 'mse = 2.0\nsamples = 3\nvalue = 378.0'),
#  Text(396.3861740166865, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.559\nmse = 24.64\nsamples = 5\nvalue = 358.6'),
#  Text(395.3220500595947, 62.72307692307692, 'CYLINDERS <= 0.889\nmse = 3.188\nsamples = 4\nvalue = 356.25'),
#  Text(394.2579261025029, 37.63384615384615, 'mse = 0.0\nsamples = 1\nvalue = 354.0'),
#  Text(396.3861740166865, 37.63384615384615, 'FUELCONSUMPTION_CITY <= 0.551\nmse = 2.0\nsamples = 3\nvalue = 357.0'),
#  Text(395.3220500595947, 12.544615384615383, 'mse = 2.25\nsamples = 2\nvalue = 357.5'),
#  Text(397.4502979737782, 12.544615384615383, 'mse = 0.0\nsamples = 1\nvalue = 356.0'),
#  Text(397.4502979737782, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 368.0'),
#  Text(411.9489868891537, 188.16923076923078, 'FUELCONSUMPTION_CITY <= 0.663\nmse = 523.231\nsamples = 26\nvalue = 409.0'),
#  Text(405.16519666269363, 163.08, 'FUELTYPE_X <= 0.5\nmse = 185.048\nsamples = 21\nvalue = 401.0'),
#  Text(400.1106078665077, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.582\nmse = 127.361\nsamples = 13\nvalue = 393.846'),
#  Text(399.0464839094159, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 407.0'),
#  Text(401.1747318235995, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.594\nmse = 122.354\nsamples = 12\nvalue = 392.75'),
#  Text(400.1106078665077, 87.81230769230771, 'mse = 0.0\nsamples = 3\nvalue = 382.0'),
#  Text(402.2388557806912, 87.81230769230771, 'CYLINDERS <= 0.667\nmse = 111.778\nsamples = 9\nvalue = 396.333'),
#  Text(399.5785458879618, 62.72307692307692, 'FUELCONSUMPTION_CITY <= 0.624\nmse = 36.0\nsamples = 2\nvalue = 413.0'),
#  Text(398.51442193087, 37.63384615384615, 'mse = 0.0\nsamples = 1\nvalue = 419.0'),
#  Text(400.64266984505355, 37.63384615384615, 'mse = 0.0\nsamples = 1\nvalue = 407.0'),
#  Text(404.89916567342067, 62.72307692307692, 'FUELCONSUMPTION_CITY <= 0.612\nmse = 31.388\nsamples = 7\nvalue = 391.571'),
#  Text(402.77091775923714, 37.63384615384615, 'CYLINDERS <= 0.889\nmse = 20.25\nsamples = 2\nvalue = 384.5'),
#  Text(401.70679380214534, 12.544615384615383, 'mse = 0.0\nsamples = 1\nvalue = 389.0'),
#  Text(403.8350417163289, 12.544615384615383, 'mse = 0.0\nsamples = 1\nvalue = 380.0'),
#  Text(407.0274135876042, 37.63384615384615, 'CYLINDERS <= 0.889\nmse = 7.84\nsamples = 5\nvalue = 394.4'),
#  Text(405.96328963051246, 12.544615384615383, 'mse = 0.0\nsamples = 1\nvalue = 400.0'),
#  Text(408.091537544696, 12.544615384615383, 'mse = 0.0\nsamples = 4\nvalue = 393.0'),
#  Text(410.2197854588796, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.61\nmse = 60.484\nsamples = 8\nvalue = 412.625'),
#  Text(408.091537544696, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.596\nmse = 4.0\nsamples = 2\nvalue = 400.0'),
#  Text(407.0274135876042, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 398.0'),
#  Text(409.1556615017878, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 402.0'),
#  Text(412.3480333730631, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.647\nmse = 8.472\nsamples = 6\nvalue = 416.833'),
#  Text(411.2839094159713, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.633\nmse = 9.188\nsamples = 4\nvalue = 415.75'),
#  Text(410.2197854588796, 62.72307692307692, 'FUELCONSUMPTION_CITY <= 0.62\nmse = 12.25\nsamples = 2\nvalue = 417.5'),
#  Text(409.1556615017878, 37.63384615384615, 'mse = 0.0\nsamples = 1\nvalue = 414.0'),
#  Text(411.2839094159713, 37.63384615384615, 'mse = 0.0\nsamples = 1\nvalue = 421.0'),
#  Text(412.3480333730631, 62.72307692307692, 'mse = 0.0\nsamples = 2\nvalue = 414.0'),
#  Text(413.4121573301549, 87.81230769230771, 'mse = 0.0\nsamples = 2\nvalue = 419.0'),
#  Text(418.73277711561377, 163.08, 'FUELCONSUMPTION_CITY <= 0.731\nmse = 545.84\nsamples = 5\nvalue = 442.6'),
#  Text(417.668653158522, 137.99076923076925, 'CYLINDERS <= 0.778\nmse = 38.188\nsamples = 4\nvalue = 431.25'),
#  Text(416.60452920143024, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.678\nmse = 4.222\nsamples = 3\nvalue = 434.667'),
#  Text(415.54040524433844, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 432.0'),
#  Text(417.668653158522, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.686\nmse = 1.0\nsamples = 2\nvalue = 436.0'),
#  Text(416.60452920143024, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 435.0'),
#  Text(418.73277711561377, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 437.0'),
#  Text(418.73277711561377, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 421.0'),
#  Text(419.79690107270557, 137.99076923076925, 'mse = 0.0\nsamples = 1\nvalue = 488.0'),
#  Text(433.49749702026213, 213.25846153846157, 'FUELCONSUMPTION_CITY <= 0.737\nmse = 1143.472\nsamples = 29\nvalue = 342.897'),
#  Text(426.1816448152562, 188.16923076923078, 'FUELCONSUMPTION_CITY <= 0.671\nmse = 305.5\nsamples = 8\nvalue = 301.0'),
#  Text(422.9892729439809, 163.08, 'FUELCONSUMPTION_CITY <= 0.624\nmse = 58.25\nsamples = 4\nvalue = 284.5'),
#  Text(421.9251489868891, 137.99076923076925, 'mse = 0.0\nsamples = 2\nvalue = 277.0'),
#  Text(424.05339690107263, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.655\nmse = 4.0\nsamples = 2\nvalue = 292.0'),
#  Text(422.9892729439809, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 290.0'),
#  Text(425.1175208581644, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 294.0'),
#  Text(429.37401668653155, 163.08, 'FUELCONSUMPTION_CITY <= 0.712\nmse = 8.25\nsamples = 4\nvalue = 317.5'),
#  Text(428.30989272943975, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.688\nmse = 2.0\nsamples = 3\nvalue = 316.0'),
#  Text(427.24576877234796, 112.90153846153848, 'mse = 0.0\nsamples = 2\nvalue = 315.0'),
#  Text(429.37401668653155, 112.90153846153848, 'mse = 0.0\nsamples = 1\nvalue = 318.0'),
#  Text(430.4381406436233, 137.99076923076925, 'mse = 0.0\nsamples = 1\nvalue = 322.0'),
#  Text(440.8133492252681, 188.16923076923078, 'FUELCONSUMPTION_CITY <= 0.908\nmse = 539.265\nsamples = 21\nvalue = 358.857'),
#  Text(437.35494636471986, 163.08, 'FUELCONSUMPTION_CITY <= 0.802\nmse = 86.719\nsamples = 18\nvalue = 350.056'),
#  Text(433.6305125148986, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.759\nmse = 38.576\nsamples = 12\nvalue = 344.917'),
#  Text(431.5022646007151, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.755\nmse = 20.694\nsamples = 7\nvalue = 342.143'),
#  Text(430.4381406436233, 87.81230769230771, 'mse = 0.0\nsamples = 6\nvalue = 344.0'),
#  Text(432.5663885578069, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 331.0'),
#  Text(435.7587604290822, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.794\nmse = 37.76\nsamples = 5\nvalue = 348.8'),
#  Text(434.6946364719904, 87.81230769230771, 'FUELCONSUMPTION_CITY <= 0.784\nmse = 32.75\nsamples = 4\nvalue = 350.5'),
#  Text(433.6305125148986, 62.72307692307692, 'FUELCONSUMPTION_CITY <= 0.769\nmse = 3.556\nsamples = 3\nvalue = 347.333'),
#  Text(432.5663885578069, 37.63384615384615, 'mse = 0.0\nsamples = 1\nvalue = 350.0'),
#  Text(434.6946364719904, 37.63384615384615, 'mse = 0.0\nsamples = 2\nvalue = 346.0'),
#  Text(435.7587604290822, 62.72307692307692, 'mse = 0.0\nsamples = 1\nvalue = 360.0'),
#  Text(436.82288438617394, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 342.0'),
#  Text(441.07938021454106, 137.99076923076925, 'FUELCONSUMPTION_CITY <= 0.82\nmse = 24.556\nsamples = 6\nvalue = 360.333'),
#  Text(440.01525625744927, 112.90153846153848, 'FUELCONSUMPTION_CITY <= 0.812\nmse = 6.75\nsamples = 4\nvalue = 363.5'),
#  Text(438.95113230035753, 87.81230769230771, 'mse = 0.0\nsamples = 3\nvalue = 362.0'),
#  Text(441.07938021454106, 87.81230769230771, 'mse = 0.0\nsamples = 1\nvalue = 368.0'),
#  Text(442.14350417163286, 112.90153846153848, 'mse = 0.0\nsamples = 2\nvalue = 354.0'),
#  Text(444.2717520858164, 163.08, 'FUELCONSUMPTION_CITY <= 0.996\nmse = 0.889\nsamples = 3\nvalue = 411.667'),
#  Text(443.2076281287246, 137.99076923076925, 'mse = 0.0\nsamples = 2\nvalue = 411.0'),
#  Text(445.3358760429082, 137.99076923076925, 'mse = 0.0\nsamples = 1\nvalue = 413.0')]

# %%
sns.lineplot(x=y_test, y=y_pred_test_lg)
plt.title('Decision Tree Model 1')
plt.xlabel(' Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %% [markdown]
# <a id=section713></a>

# %% [markdown]
# ### 7.1.3 Finding out RMSE and Adjusted R-squared for Train and Test Linear Regression Model

# %% [markdown]
# #### RMSE

# %%
#finding RMSE values
from sklearn import metrics
RMSE_train_dt=np.sqrt(metrics.mean_squared_error(y_train,y_train_pred_dt))
print('The RMSE Value of Train Dataset for Simple Decision Tree Model is  :',RMSE_train_dt)
# Out:
# The RMSE Value of Train Dataset for Simple Decision Tree Model is  : 3.5162749845560994

# %%
#finding RMSE values
from sklearn import metrics
RMSE_test_dt=np.sqrt(metrics.mean_squared_error(y_test,y_test_pred_dt))
print('The RMSE Value of Test Dataset for Simple Decision Tree Model is  :',RMSE_test_dt)
# Out:
# The RMSE Value of Test Dataset for Simple Decision Tree Model is  : 8.302928157845416

# %% [markdown]
# #### R-squared

# %%
from sklearn.metrics import r2_score
r2_dt_train=r2_score(y_train, y_train_pred_dt)
print('The R-square value for Train Data of simple Decision Tree Model is :', r2_dt_train)
# Out:
# The R-square value for Train Data of simple Decision Tree Model is : 0.9969013225678306

# %%
from sklearn.metrics import r2_score
r2_dt_test=r2_score(y_test, y_test_pred_dt)
print('The R-square value for Test Data of simple Decision Tree Model is :', r2_dt_test)
# Out:
# The R-square value for Test Data of simple Decision Tree Model is : 0.9829006898000539

# %% [markdown]
# #### Adjusted R-squared

# %%
adj_r2_train=Adjusted_r2(r2_dt_train,len(X_train))
print('The Adjusted R-square of Decision Tree first model Train Dataset is :', adj_r2_train)
adj_r2_test=Adjusted_r2(r2_dt_test,len(X_test))
print('The Adjusted R-square of Decision Tree first model Test Dataset is :', adj_r2_test)
# Out:
# The Adjusted R-square of Decision Tree first model Train Dataset is : 0.9968808015252334
# The Adjusted R-square of Decision Tree first model Test Dataset is : 0.9824385462811364

# %% [markdown]
# <a id=section72></a>

# %% [markdown]
# ### 7.2 Decision Tree Model 2

# %% [markdown]
# <a id=section721></a>

# %% [markdown]
# ### 7.2.1 Model Development

# %% [markdown]
# Let us slightly change few parameters of Model1 and see if we can get better results

# %%
from sklearn.tree import DecisionTreeRegressor
model2 = DecisionTreeRegressor( criterion='mse', max_depth=7,
                               max_features=None, max_leaf_nodes=None,
                               min_impurity_decrease=0.0, min_impurity_split=None,
                               min_samples_leaf=1, min_samples_split=2,
                               min_weight_fraction_leaf=0.0, presort=False,
                               random_state=None, splitter='best')
model2.fit(X_train_s, y_train)

#random state is a seed to start finding something randomly
# Out:
# DecisionTreeRegressor(max_depth=7, presort=False)

# %%
y_train_pred_dt_m2=model2.predict(X_train_s)
y_test_pred_dt_m2=model2.predict(X_test_s)

# %% [markdown]
# <a id=section722></a>

# %% [markdown]
# ### 7.2.2 Plotting the model

# %%
sns.lineplot(x=y_test, y=y_test_pred_dt)
plt.title('Decision Tree Model 2')
plt.xlabel(' Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %%
#Generating DOT File
#dot_data2 = export_graphviz(model2, filled=True, rounded=True, feature_names=X.columns, out_file=None)
#graph2 = graph_from_dot_data(dot_data2)
#graph2.write_png('tree2.png')

# %%
from sklearn.tree import plot_tree
 
plt.figure(figsize=(8, 6))
plot_tree(model2, feature_names=X_train.columns, filled=True, rounded=True)
# Out:
# [Text(213.61350710900476, 305.77500000000003, 'FUELCONSUMPTION_CITY <= 0.339\nmse = 3990.151\nsamples = 761\nvalue = 256.388'),
#  Text(106.31090047393366, 265.005, 'FUELCONSUMPTION_CITY <= 0.237\nmse = 1103.27\nsamples = 448\nvalue = 215.125'),
#  Text(54.2132701421801, 224.235, 'FUELCONSUMPTION_CITY <= 0.175\nmse = 410.958\nsamples = 217\nvalue = 187.544'),
#  Text(22.214218009478675, 183.465, 'FUELCONSUMPTION_CITY <= 0.106\nmse = 274.361\nsamples = 107\nvalue = 172.112'),
#  Text(8.462559241706161, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.033\nmse = 111.714\nsamples = 14\nvalue = 138.0'),
#  Text(4.231279620853081, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.012\nmse = 68.5\nsamples = 4\nvalue = 124.0'),
#  Text(2.1156398104265404, 61.15500000000003, 'mse = 0.0\nsamples = 1\nvalue = 110.0'),
#  Text(6.3469194312796215, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.027\nmse = 4.222\nsamples = 3\nvalue = 128.667'),
#  Text(4.231279620853081, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 126.0'),
#  Text(8.462559241706161, 20.38499999999999, 'mse = 1.0\nsamples = 2\nvalue = 130.0'),
#  Text(12.693838862559243, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.057\nmse = 19.24\nsamples = 10\nvalue = 143.6'),
#  Text(10.578199052132701, 61.15500000000003, 'mse = 0.0\nsamples = 3\nvalue = 138.0'),
#  Text(14.809478672985783, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.094\nmse = 8.286\nsamples = 7\nvalue = 146.0'),
#  Text(12.693838862559243, 20.38499999999999, 'mse = 2.667\nsamples = 6\nvalue = 145.0'),
#  Text(16.925118483412323, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 152.0'),
#  Text(35.96587677725119, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.147\nmse = 97.304\nsamples = 93\nvalue = 177.247'),
#  Text(27.503317535545026, 101.92500000000001, 'FUELTYPE_X <= 0.5\nmse = 128.798\nsamples = 38\nvalue = 171.789'),
#  Text(23.272037914691943, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.131\nmse = 34.43\nsamples = 11\nvalue = 184.455'),
#  Text(21.156398104265403, 20.38499999999999, 'mse = 22.025\nsamples = 9\nvalue = 182.556'),
#  Text(25.387677725118486, 20.38499999999999, 'mse = 1.0\nsamples = 2\nvalue = 193.0'),
#  Text(31.734597156398106, 61.15500000000003, 'CYLINDERS <= 0.222\nmse = 75.27\nsamples = 27\nvalue = 166.63'),
#  Text(29.618957345971566, 20.38499999999999, 'mse = 34.022\nsamples = 25\nvalue = 164.76'),
#  Text(33.850236966824646, 20.38499999999999, 'mse = 1.0\nsamples = 2\nvalue = 190.0'),
#  Text(44.42843601895735, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.159\nmse = 40.745\nsamples = 55\nvalue = 181.018'),
#  Text(40.19715639810427, 61.15500000000003, 'FUELTYPE_X <= 0.5\nmse = 37.594\nsamples = 31\nvalue = 179.226'),
#  Text(38.081516587677726, 20.38499999999999, 'mse = 53.471\nsamples = 11\nvalue = 183.727'),
#  Text(42.312796208530806, 20.38499999999999, 'mse = 11.588\nsamples = 20\nvalue = 176.75'),
#  Text(48.65971563981043, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.163\nmse = 35.306\nsamples = 24\nvalue = 183.333'),
#  Text(46.544075829383885, 20.38499999999999, 'mse = 59.76\nsamples = 5\nvalue = 181.8'),
#  Text(50.77535545023697, 20.38499999999999, 'mse = 28.089\nsamples = 19\nvalue = 183.737'),
#  Text(86.21232227488152, 183.465, 'FUELCONSUMPTION_CITY <= 0.206\nmse = 86.865\nsamples = 110\nvalue = 202.555'),
#  Text(69.81611374407584, 142.69500000000002, 'CYLINDERS <= 0.222\nmse = 42.15\nsamples = 54\nvalue = 196.13'),
#  Text(61.35355450236967, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.198\nmse = 22.252\nsamples = 50\nvalue = 195.22'),
#  Text(57.12227488151659, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.19\nmse = 17.256\nsamples = 36\nvalue = 193.722'),
#  Text(55.00663507109005, 20.38499999999999, 'mse = 18.154\nsamples = 21\nvalue = 192.476'),
#  Text(59.23791469194313, 20.38499999999999, 'mse = 10.782\nsamples = 15\nvalue = 195.467'),
#  Text(65.58483412322275, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.202\nmse = 14.495\nsamples = 14\nvalue = 199.071'),
#  Text(63.46919431279621, 20.38499999999999, 'mse = 11.959\nsamples = 7\nvalue = 197.429'),
#  Text(67.70047393364929, 20.38499999999999, 'mse = 11.633\nsamples = 7\nvalue = 200.714'),
#  Text(78.278672985782, 101.92500000000001, 'FUELTYPE_Z <= 0.5\nmse = 151.25\nsamples = 4\nvalue = 207.5'),
#  Text(74.04739336492891, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.188\nmse = 30.25\nsamples = 2\nvalue = 218.5'),
#  Text(71.93175355450238, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 213.0'),
#  Text(76.16303317535545, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 224.0'),
#  Text(82.50995260663507, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.184\nmse = 30.25\nsamples = 2\nvalue = 196.5'),
#  Text(80.39431279620854, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 191.0'),
#  Text(84.62559241706161, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 202.0'),
#  Text(102.60853080568721, 142.69500000000002, 'CYLINDERS <= 0.222\nmse = 51.795\nsamples = 56\nvalue = 208.75'),
#  Text(95.20379146919431, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.218\nmse = 39.501\nsamples = 52\nvalue = 207.865'),
#  Text(90.97251184834124, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.214\nmse = 35.202\nsamples = 21\nvalue = 203.81'),
#  Text(88.8568720379147, 20.38499999999999, 'mse = 32.959\nsamples = 11\nvalue = 201.636'),
#  Text(93.08815165876777, 20.38499999999999, 'mse = 26.76\nsamples = 10\nvalue = 206.2'),
#  Text(99.4350710900474, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.229\nmse = 23.721\nsamples = 31\nvalue = 210.613'),
#  Text(97.31943127962086, 20.38499999999999, 'mse = 27.747\nsamples = 20\nvalue = 209.55'),
#  Text(101.55071090047394, 20.38499999999999, 'mse = 10.612\nsamples = 11\nvalue = 212.545'),
#  Text(110.0132701421801, 101.92500000000001, 'FUELTYPE_Z <= 0.5\nmse = 69.188\nsamples = 4\nvalue = 220.25'),
#  Text(107.89763033175356, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.21\nmse = 2.25\nsamples = 2\nvalue = 228.5'),
#  Text(105.78199052132702, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 227.0'),
#  Text(110.0132701421801, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 230.0'),
#  Text(112.12890995260663, 61.15500000000003, 'mse = 0.0\nsamples = 2\nvalue = 212.0'),
#  Text(158.4085308056872, 224.235, 'FUELCONSUMPTION_CITY <= 0.284\nmse = 367.696\nsamples = 231\nvalue = 241.035'),
#  Text(139.63222748815167, 183.465, 'FUELTYPE_E <= 0.5\nmse = 273.713\nsamples = 109\nvalue = 226.89'),
#  Text(129.05402843601897, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.265\nmse = 134.786\nsamples = 105\nvalue = 229.229'),
#  Text(120.59146919431281, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.249\nmse = 67.007\nsamples = 61\nvalue = 223.328'),
#  Text(116.36018957345972, 61.15500000000003, 'CYLINDERS <= 0.278\nmse = 23.623\nsamples = 24\nvalue = 218.292'),
#  Text(114.24454976303318, 20.38499999999999, 'mse = 20.628\nsamples = 22\nvalue = 218.909'),
#  Text(118.47582938388626, 20.38499999999999, 'mse = 6.25\nsamples = 2\nvalue = 211.5'),
#  Text(124.82274881516588, 61.15500000000003, 'FUELTYPE_Z <= 0.5\nmse = 68.025\nsamples = 37\nvalue = 226.595'),
#  Text(122.70710900473934, 20.38499999999999, 'mse = 87.213\nsamples = 27\nvalue = 227.481'),
#  Text(126.93838862559242, 20.38499999999999, 'mse = 8.36\nsamples = 10\nvalue = 224.2'),
#  Text(137.5165876777251, 101.92500000000001, 'FUELTYPE_Z <= 0.5\nmse = 113.56\nsamples = 44\nvalue = 237.409'),
#  Text(133.28530805687205, 61.15500000000003, 'FUELTYPE_X <= 0.5\nmse = 215.152\nsamples = 16\nvalue = 241.188'),
#  Text(131.1696682464455, 20.38499999999999, 'mse = 2.25\nsamples = 2\nvalue = 276.5'),
#  Text(135.40094786729858, 20.38499999999999, 'mse = 41.98\nsamples = 14\nvalue = 236.143'),
#  Text(141.7478672985782, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.273\nmse = 42.688\nsamples = 28\nvalue = 235.25'),
#  Text(139.63222748815167, 20.38499999999999, 'mse = 20.173\nsamples = 9\nvalue = 230.222'),
#  Text(143.86350710900476, 20.38499999999999, 'mse = 35.706\nsamples = 19\nvalue = 237.632'),
#  Text(150.21042654028437, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.278\nmse = 8.25\nsamples = 4\nvalue = 165.5'),
#  Text(148.09478672985782, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.273\nmse = 2.0\nsamples = 3\nvalue = 164.0'),
#  Text(145.9791469194313, 61.15500000000003, 'mse = 0.0\nsamples = 1\nvalue = 162.0'),
#  Text(150.21042654028437, 61.15500000000003, 'mse = 0.0\nsamples = 2\nvalue = 165.0'),
#  Text(152.3260663507109, 101.92500000000001, 'mse = 0.0\nsamples = 1\nvalue = 170.0'),
#  Text(177.18483412322274, 183.465, 'FUELCONSUMPTION_CITY <= 0.32\nmse = 113.204\nsamples = 122\nvalue = 253.672'),
#  Text(161.84644549763033, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.292\nmse = 97.716\nsamples = 77\nvalue = 249.299'),
#  Text(156.557345971564, 101.92500000000001, 'CYLINDERS <= 0.444\nmse = 133.107\nsamples = 21\nvalue = 243.476'),
#  Text(154.44170616113746, 61.15500000000003, 'FUELTYPE_Z <= 0.5\nmse = 121.747\nsamples = 20\nvalue = 242.55'),
#  Text(152.3260663507109, 20.38499999999999, 'mse = 297.143\nsamples = 7\nvalue = 247.0'),
#  Text(156.557345971564, 20.38499999999999, 'mse = 10.899\nsamples = 13\nvalue = 240.154'),
#  Text(158.67298578199052, 61.15500000000003, 'mse = 0.0\nsamples = 1\nvalue = 262.0'),
#  Text(167.1355450236967, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.308\nmse = 66.964\nsamples = 56\nvalue = 251.482'),
#  Text(162.9042654028436, 61.15500000000003, 'FUELTYPE_Z <= 0.5\nmse = 96.378\nsamples = 29\nvalue = 249.966'),
#  Text(160.78862559241708, 20.38499999999999, 'mse = 152.109\nsamples = 16\nvalue = 252.375'),
#  Text(165.01990521327014, 20.38499999999999, 'mse = 11.846\nsamples = 13\nvalue = 247.0'),
#  Text(171.36682464454978, 61.15500000000003, 'CYLINDERS <= 0.222\nmse = 30.247\nsamples = 27\nvalue = 253.111'),
#  Text(169.25118483412322, 20.38499999999999, 'mse = 58.16\nsamples = 5\nvalue = 258.8'),
#  Text(173.4824644549763, 20.38499999999999, 'mse = 14.876\nsamples = 22\nvalue = 251.818'),
#  Text(192.5232227488152, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.331\nmse = 50.976\nsamples = 45\nvalue = 261.156'),
#  Text(184.060663507109, 101.92500000000001, 'FUELTYPE_Z <= 0.5\nmse = 73.485\nsamples = 26\nvalue = 259.769'),
#  Text(179.82938388625593, 61.15500000000003, 'FUELTYPE_X <= 0.5\nmse = 91.673\nsamples = 19\nvalue = 261.105'),
#  Text(177.7137440758294, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 294.0'),
#  Text(181.94502369668248, 20.38499999999999, 'mse = 33.312\nsamples = 18\nvalue = 259.278'),
#  Text(188.2919431279621, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.325\nmse = 6.122\nsamples = 7\nvalue = 256.143'),
#  Text(186.17630331753554, 20.38499999999999, 'mse = 8.25\nsamples = 4\nvalue = 255.5'),
#  Text(190.40758293838863, 20.38499999999999, 'mse = 2.0\nsamples = 3\nvalue = 257.0'),
#  Text(200.98578199052133, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.335\nmse = 13.945\nsamples = 19\nvalue = 263.053'),
#  Text(196.75450236966824, 61.15500000000003, 'FUELTYPE_X <= 0.5\nmse = 16.876\nsamples = 11\nvalue = 262.182'),
#  Text(194.63886255924172, 20.38499999999999, 'mse = 8.667\nsamples = 3\nvalue = 263.0'),
#  Text(198.8701421800948, 20.38499999999999, 'mse = 19.609\nsamples = 8\nvalue = 261.875'),
#  Text(205.21706161137442, 61.15500000000003, 'FUELTYPE_Z <= 0.5\nmse = 7.438\nsamples = 8\nvalue = 264.25'),
#  Text(203.1014218009479, 20.38499999999999, 'mse = 9.84\nsamples = 5\nvalue = 263.6'),
#  Text(207.33270142180095, 20.38499999999999, 'mse = 1.556\nsamples = 3\nvalue = 265.333'),
#  Text(320.91611374407586, 265.005, 'CYLINDERS <= 0.444\nmse = 2197.174\nsamples = 313\nvalue = 315.447'),
#  Text(263.13270142180096, 224.235, 'FUELTYPE_E <= 0.5\nmse = 538.193\nsamples = 133\nvalue = 280.098'),
#  Text(242.76966824644552, 183.465, 'FUELCONSUMPTION_CITY <= 0.402\nmse = 290.679\nsamples = 99\nvalue = 288.374'),
#  Text(226.37345971563983, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.363\nmse = 101.917\nsamples = 81\nvalue = 282.309'),
#  Text(217.91090047393365, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.351\nmse = 24.724\nsamples = 33\nvalue = 272.939'),
#  Text(213.67962085308056, 61.15500000000003, 'FUELTYPE_Z <= 0.5\nmse = 12.734\nsamples = 16\nvalue = 269.875'),
#  Text(211.56398104265404, 20.38499999999999, 'mse = 9.837\nsamples = 7\nvalue = 268.857'),
#  Text(215.79526066350712, 20.38499999999999, 'mse = 13.556\nsamples = 9\nvalue = 270.667'),
#  Text(222.14218009478674, 61.15500000000003, 'CYLINDERS <= 0.222\nmse = 18.851\nsamples = 17\nvalue = 275.824'),
#  Text(220.0265402843602, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 283.0'),
#  Text(224.25781990521327, 20.38499999999999, 'mse = 16.609\nsamples = 16\nvalue = 275.375'),
#  Text(234.83601895734597, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.39\nmse = 53.146\nsamples = 48\nvalue = 288.75'),
#  Text(230.6047393364929, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.375\nmse = 34.514\nsamples = 33\nvalue = 286.303'),
#  Text(228.48909952606635, 20.38499999999999, 'mse = 35.0\nsamples = 16\nvalue = 284.0'),
#  Text(232.72037914691944, 20.38499999999999, 'mse = 24.367\nsamples = 17\nvalue = 288.471'),
#  Text(239.06729857819906, 61.15500000000003, 'FUELTYPE_X <= 0.5\nmse = 51.982\nsamples = 15\nvalue = 294.133'),
#  Text(236.95165876777253, 20.38499999999999, 'mse = 18.5\nsamples = 4\nvalue = 287.0'),
#  Text(241.18293838862562, 20.38499999999999, 'mse = 38.926\nsamples = 11\nvalue = 296.727'),
#  Text(259.1658767772512, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.445\nmse = 229.667\nsamples = 18\nvalue = 315.667'),
#  Text(251.7611374407583, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.414\nmse = 78.352\nsamples = 14\nvalue = 309.071'),
#  Text(247.52985781990523, 61.15500000000003, 'FUELTYPE_Z <= 0.5\nmse = 58.98\nsamples = 7\nvalue = 304.143'),
#  Text(245.41421800947867, 20.38499999999999, 'mse = 9.188\nsamples = 4\nvalue = 309.75'),
#  Text(249.64549763033176, 20.38499999999999, 'mse = 27.556\nsamples = 3\nvalue = 296.667'),
#  Text(255.99241706161138, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.418\nmse = 49.143\nsamples = 7\nvalue = 314.0'),
#  Text(253.87677725118485, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 322.0'),
#  Text(258.10805687203793, 20.38499999999999, 'mse = 44.889\nsamples = 6\nvalue = 312.667'),
#  Text(266.5706161137441, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.471\nmse = 74.188\nsamples = 4\nvalue = 338.75'),
#  Text(264.45497630331755, 61.15500000000003, 'FUELTYPE_Z <= 0.5\nmse = 12.25\nsamples = 2\nvalue = 330.5'),
#  Text(262.339336492891, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 327.0'),
#  Text(266.5706161137441, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 334.0'),
#  Text(268.6862559241706, 61.15500000000003, 'mse = 0.0\nsamples = 2\nvalue = 347.0'),
#  Text(283.4957345971564, 183.465, 'FUELCONSUMPTION_CITY <= 0.502\nmse = 478.765\nsamples = 34\nvalue = 256.0'),
#  Text(272.9175355450237, 142.69500000000002, 'CYLINDERS <= 0.222\nmse = 141.432\nsamples = 9\nvalue = 225.889'),
#  Text(270.80189573459717, 101.92500000000001, 'mse = 0.0\nsamples = 1\nvalue = 195.0'),
#  Text(275.0331753554502, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.488\nmse = 24.938\nsamples = 8\nvalue = 229.75'),
#  Text(272.9175355450237, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.478\nmse = 9.889\nsamples = 6\nvalue = 227.333'),
#  Text(270.80189573459717, 20.38499999999999, 'mse = 8.667\nsamples = 3\nvalue = 225.0'),
#  Text(275.0331753554502, 20.38499999999999, 'mse = 0.222\nsamples = 3\nvalue = 229.667'),
#  Text(277.1488151658768, 61.15500000000003, 'mse = 0.0\nsamples = 2\nvalue = 237.0'),
#  Text(294.07393364928913, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.573\nmse = 156.294\nsamples = 25\nvalue = 266.84'),
#  Text(285.61137440758296, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.549\nmse = 45.638\nsamples = 14\nvalue = 257.929'),
#  Text(281.38009478672984, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.512\nmse = 5.265\nsamples = 7\nvalue = 252.143'),
#  Text(279.26445497630334, 20.38499999999999, 'mse = 0.0\nsamples = 2\nvalue = 250.0'),
#  Text(283.4957345971564, 20.38499999999999, 'mse = 4.8\nsamples = 5\nvalue = 253.0'),
#  Text(289.842654028436, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.555\nmse = 19.061\nsamples = 7\nvalue = 263.714'),
#  Text(287.7270142180095, 20.38499999999999, 'mse = 0.0\nsamples = 2\nvalue = 259.0'),
#  Text(291.9582938388626, 20.38499999999999, 'mse = 14.24\nsamples = 5\nvalue = 265.6'),
#  Text(302.53649289099525, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.596\nmse = 67.421\nsamples = 11\nvalue = 278.182'),
#  Text(298.3052132701422, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.582\nmse = 23.583\nsamples = 6\nvalue = 271.5'),
#  Text(296.18957345971563, 20.38499999999999, 'mse = 33.5\nsamples = 4\nvalue = 272.0'),
#  Text(300.42085308056875, 20.38499999999999, 'mse = 2.25\nsamples = 2\nvalue = 270.5'),
#  Text(306.76777251184836, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.604\nmse = 2.16\nsamples = 5\nvalue = 286.2'),
#  Text(304.6521327014218, 20.38499999999999, 'mse = 0.0\nsamples = 2\nvalue = 285.0'),
#  Text(308.8834123222749, 20.38499999999999, 'mse = 2.0\nsamples = 3\nvalue = 287.0'),
#  Text(378.6995260663507, 224.235, 'FUELCONSUMPTION_CITY <= 0.476\nmse = 1817.446\nsamples = 180\nvalue = 341.567'),
#  Text(344.84928909952606, 183.465, 'FUELCONSUMPTION_CITY <= 0.437\nmse = 427.998\nsamples = 74\nvalue = 304.689'),
#  Text(327.92417061611377, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.386\nmse = 166.572\nsamples = 44\nvalue = 290.705'),
#  Text(319.4616113744076, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.363\nmse = 80.65\nsamples = 10\nvalue = 271.5'),
#  Text(315.23033175355454, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.351\nmse = 17.36\nsamples = 5\nvalue = 263.2'),
#  Text(313.114691943128, 20.38499999999999, 'mse = 13.25\nsamples = 4\nvalue = 264.5'),
#  Text(317.34597156398104, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 258.0'),
#  Text(323.69289099526065, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.378\nmse = 6.16\nsamples = 5\nvalue = 279.8'),
#  Text(321.57725118483415, 20.38499999999999, 'mse = 1.0\nsamples = 2\nvalue = 277.0'),
#  Text(325.8085308056872, 20.38499999999999, 'mse = 0.889\nsamples = 3\nvalue = 281.667'),
#  Text(336.38672985781994, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.406\nmse = 51.464\nsamples = 34\nvalue = 296.353'),
#  Text(332.15545023696683, 61.15500000000003, 'FUELTYPE_Z <= 0.5\nmse = 27.184\nsamples = 16\nvalue = 292.062'),
#  Text(330.03981042654027, 20.38499999999999, 'mse = 12.25\nsamples = 4\nvalue = 295.5'),
#  Text(334.2710900473934, 20.38499999999999, 'mse = 26.91\nsamples = 12\nvalue = 290.917'),
#  Text(340.618009478673, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.429\nmse = 42.139\nsamples = 18\nvalue = 300.167'),
#  Text(338.50236966824644, 20.38499999999999, 'mse = 33.479\nsamples = 13\nvalue = 298.462'),
#  Text(342.73364928909956, 20.38499999999999, 'mse = 37.44\nsamples = 5\nvalue = 304.6'),
#  Text(361.7744075829384, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.457\nmse = 103.893\nsamples = 30\nvalue = 325.2'),
#  Text(353.31184834123223, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.453\nmse = 41.976\nsamples = 13\nvalue = 318.154'),
#  Text(349.0805687203792, 61.15500000000003, 'FUELTYPE_X <= 0.5\nmse = 44.222\nsamples = 9\nvalue = 316.0'),
#  Text(346.9649289099526, 20.38499999999999, 'mse = 26.333\nsamples = 6\nvalue = 315.0'),
#  Text(351.1962085308057, 20.38499999999999, 'mse = 74.0\nsamples = 3\nvalue = 318.0'),
#  Text(357.54312796208535, 61.15500000000003, 'FUELTYPE_X <= 0.5\nmse = 3.0\nsamples = 4\nvalue = 323.0'),
#  Text(355.4274881516588, 20.38499999999999, 'mse = 3.556\nsamples = 3\nvalue = 322.667'),
#  Text(359.65876777251185, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 324.0'),
#  Text(370.2369668246446, 101.92500000000001, 'FUELTYPE_Z <= 0.5\nmse = 84.242\nsamples = 17\nvalue = 330.588'),
#  Text(366.00568720379147, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.465\nmse = 8.688\nsamples = 4\nvalue = 338.75'),
#  Text(363.89004739336497, 20.38499999999999, 'mse = 0.0\nsamples = 2\nvalue = 336.0'),
#  Text(368.121327014218, 20.38499999999999, 'mse = 2.25\nsamples = 2\nvalue = 341.5'),
#  Text(374.46824644549764, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.473\nmse = 80.686\nsamples = 13\nvalue = 328.077'),
#  Text(372.3526066350711, 20.38499999999999, 'mse = 81.521\nsamples = 12\nvalue = 328.75'),
#  Text(376.5838862559242, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 320.0'),
#  Text(412.5497630331754, 183.465, 'FUELTYPE_E <= 0.5\nmse = 1175.252\nsamples = 106\nvalue = 367.311'),
#  Text(395.62464454976305, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.571\nmse = 878.172\nsamples = 77\nvalue = 376.506'),
#  Text(387.1620853080569, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.508\nmse = 246.448\nsamples = 51\nvalue = 359.941'),
#  Text(382.9308056872038, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.502\nmse = 68.651\nsamples = 17\nvalue = 343.235'),
#  Text(380.81516587677726, 20.38499999999999, 'mse = 38.222\nsamples = 12\nvalue = 341.333'),
#  Text(385.0464454976304, 20.38499999999999, 'mse = 112.16\nsamples = 5\nvalue = 347.8'),
#  Text(391.39336492891, 61.15500000000003, 'FUELTYPE_X <= 0.5\nmse = 126.031\nsamples = 34\nvalue = 368.294'),
#  Text(389.27772511848343, 20.38499999999999, 'mse = 93.778\nsamples = 19\nvalue = 362.105'),
#  Text(393.5090047393365, 20.38499999999999, 'mse = 56.916\nsamples = 15\nvalue = 376.133'),
#  Text(404.0872037914692, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.663\nmse = 523.231\nsamples = 26\nvalue = 409.0'),
#  Text(399.8559241706161, 61.15500000000003, 'FUELTYPE_X <= 0.5\nmse = 185.048\nsamples = 21\nvalue = 401.0'),
#  Text(397.7402843601896, 20.38499999999999, 'mse = 127.361\nsamples = 13\nvalue = 393.846'),
#  Text(401.97156398104266, 20.38499999999999, 'mse = 60.484\nsamples = 8\nvalue = 412.625'),
#  Text(408.3184834123223, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.731\nmse = 545.84\nsamples = 5\nvalue = 442.6'),
#  Text(406.2028436018958, 20.38499999999999, 'mse = 38.188\nsamples = 4\nvalue = 431.25'),
#  Text(410.43412322274884, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 488.0'),
#  Text(429.4748815165877, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.737\nmse = 1143.472\nsamples = 29\nvalue = 342.897'),
#  Text(421.0123222748815, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.671\nmse = 305.5\nsamples = 8\nvalue = 301.0'),
#  Text(416.78104265402845, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.624\nmse = 58.25\nsamples = 4\nvalue = 284.5'),
#  Text(414.6654028436019, 20.38499999999999, 'mse = 0.0\nsamples = 2\nvalue = 277.0'),
#  Text(418.896682464455, 20.38499999999999, 'mse = 4.0\nsamples = 2\nvalue = 292.0'),
#  Text(425.2436018957346, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.712\nmse = 8.25\nsamples = 4\nvalue = 317.5'),
#  Text(423.12796208530807, 20.38499999999999, 'mse = 2.0\nsamples = 3\nvalue = 316.0'),
#  Text(427.35924170616113, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 322.0'),
#  Text(437.93744075829386, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.908\nmse = 539.265\nsamples = 21\nvalue = 358.857'),
#  Text(433.7061611374408, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.802\nmse = 86.719\nsamples = 18\nvalue = 350.056'),
#  Text(431.59052132701424, 20.38499999999999, 'mse = 38.576\nsamples = 12\nvalue = 344.917'),
#  Text(435.8218009478673, 20.38499999999999, 'mse = 24.556\nsamples = 6\nvalue = 360.333'),
#  Text(442.1687203791469, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.996\nmse = 0.889\nsamples = 3\nvalue = 411.667'),
#  Text(440.0530805687204, 20.38499999999999, 'mse = 0.0\nsamples = 2\nvalue = 411.0'),
#  Text(444.2843601895735, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 413.0')]

# %% [markdown]
# <a id=section723></a>

# %% [markdown]
# ### 7.2.3 Finding out RMSE and Adjusted R-squared for Train and Test Linear Regression Model

# %% [markdown]
# #### RMSE

# %%
#finding RMSE values
from sklearn import metrics
RMSE_train_dt_m2=np.sqrt(metrics.mean_squared_error(y_train,y_train_pred_dt_m2))
print('The RMSE score of Train Dataset of Decision Tree Model 2 is :',RMSE_train_dt_m2)
# Out:
# The RMSE score of Train Dataset of Decision Tree Model 2 is : 5.954048895201773

# %%
#finding RMSE values
from sklearn import metrics
RMSE_test_dt_m2=np.sqrt(metrics.mean_squared_error(y_test,y_test_pred_dt_m2))
print('The RMSE score of Test Dataset of Decision Tree Model 2 is :',RMSE_test_dt_m2)
# Out:
# The RMSE score of Test Dataset of Decision Tree Model 2 is : 8.483951808792773

# %% [markdown]
# #### R-square

# %%
from sklearn.metrics import r2_score
r2_dt_m2_train=r2_score(y_train, y_train_pred_dt_m2)
print('The R-square value of Train Dataset of Decision Tree Model 2 is :',r2_dt_m2_train)
# Out:
# The R-square value of Train Dataset of Decision Tree Model 2 is : 0.9911154486722623

# %%
from sklearn.metrics import r2_score
r2_dt_m2_test=r2_score(y_test, y_test_pred_dt_m2)
print('The R-square value of Test Dataset of Decision Tree Model 2 is :',r2_dt_m2_test)
# Out:
# The R-square value of Test Dataset of Decision Tree Model 2 is : 0.9821469501957191

# %% [markdown]
# #### Adjusted R-squared

# %%
adj_r2_train=Adjusted_r2(r2_dt_m2_train,len(X_train))
print('The Adjusted R-square of Decisiom Tree Train Dataset for the second model is :', adj_r2_train)
adj_r2_test=Adjusted_r2(r2_dt_m2_test,len(X_test))
print('The Adjusted R-square of Decision Tree Test Dataset for the second model is :', adj_r2_test)
# Out:
# The Adjusted R-square of Decisiom Tree Train Dataset for the second model is : 0.9910566105839992
# The Adjusted R-square of Decision Tree Test Dataset for the second model is : 0.9816644353361439

# %% [markdown]
# <a id=section73></a>

# %% [markdown]
# ## 7.3 Decision Tree GridSearchCV Model

# %% [markdown]
# <a id=section731></a>

# %% [markdown]
# ### 7.3.1 Model Development

# %% [markdown]
# Let us use the powerful python tool called ```GridSearchCV``` and develop third model of our Decision Tree. In this model we will let the system iterate over different criteria and give us the best model

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV

decision_tree_regressor= DecisionTreeRegressor(random_state = 0)


tree_para = [{'criterion':["mse", "friedman_mse", "mae"],'max_depth': range(2,60),
              'splitter' : ["best", "random"],
              'max_features': ["auto", "sqrt", "log2"] }]
                            
                            

grid_search = GridSearchCV(decision_tree_regressor,tree_para, cv=10, refit='AUC')
grid_search.fit(X_train_s, y_train)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeRegressor(random_state=0),
#              param_grid=[{'criterion': ['mse', 'friedman_mse', 'mae'],
#                           'max_depth': range(2, 60),
#                           'max_features': ['auto', 'sqrt', 'log2'],
#                           'splitter': ['best', 'random']}],
#              refit='AUC')

# %%
y_train_pred_dt3 = grid_search.predict(X_train_s)
y_test_pred_dt3 = grid_search.predict(X_test_s)

# %% [markdown]
# <a id=section732></a>

# %% [markdown]
# ### 7.3.2 Plotting the model

# %%
sns.lineplot(x=y_test, y=y_test_pred_dt)
plt.title('Decision Tree Model 2')
plt.xlabel(' Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %%
#Generating DOT File
#dot_data2 = export_graphviz(model2, filled=True, rounded=True, feature_names=X.columns, out_file=None)
#graph2 = graph_from_dot_data(dot_data2)
#graph2.write_png('tree2.png')

# %%
from sklearn.tree import plot_tree
 
plt.figure(figsize=(8, 6))
plot_tree(model2, feature_names=X_train.columns, filled=True, rounded=True)
# Out:
# [Text(213.61350710900476, 305.77500000000003, 'FUELCONSUMPTION_CITY <= 0.339\nmse = 3990.151\nsamples = 761\nvalue = 256.388'),
#  Text(106.31090047393366, 265.005, 'FUELCONSUMPTION_CITY <= 0.237\nmse = 1103.27\nsamples = 448\nvalue = 215.125'),
#  Text(54.2132701421801, 224.235, 'FUELCONSUMPTION_CITY <= 0.175\nmse = 410.958\nsamples = 217\nvalue = 187.544'),
#  Text(22.214218009478675, 183.465, 'FUELCONSUMPTION_CITY <= 0.106\nmse = 274.361\nsamples = 107\nvalue = 172.112'),
#  Text(8.462559241706161, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.033\nmse = 111.714\nsamples = 14\nvalue = 138.0'),
#  Text(4.231279620853081, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.012\nmse = 68.5\nsamples = 4\nvalue = 124.0'),
#  Text(2.1156398104265404, 61.15500000000003, 'mse = 0.0\nsamples = 1\nvalue = 110.0'),
#  Text(6.3469194312796215, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.027\nmse = 4.222\nsamples = 3\nvalue = 128.667'),
#  Text(4.231279620853081, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 126.0'),
#  Text(8.462559241706161, 20.38499999999999, 'mse = 1.0\nsamples = 2\nvalue = 130.0'),
#  Text(12.693838862559243, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.057\nmse = 19.24\nsamples = 10\nvalue = 143.6'),
#  Text(10.578199052132701, 61.15500000000003, 'mse = 0.0\nsamples = 3\nvalue = 138.0'),
#  Text(14.809478672985783, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.094\nmse = 8.286\nsamples = 7\nvalue = 146.0'),
#  Text(12.693838862559243, 20.38499999999999, 'mse = 2.667\nsamples = 6\nvalue = 145.0'),
#  Text(16.925118483412323, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 152.0'),
#  Text(35.96587677725119, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.147\nmse = 97.304\nsamples = 93\nvalue = 177.247'),
#  Text(27.503317535545026, 101.92500000000001, 'FUELTYPE_X <= 0.5\nmse = 128.798\nsamples = 38\nvalue = 171.789'),
#  Text(23.272037914691943, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.131\nmse = 34.43\nsamples = 11\nvalue = 184.455'),
#  Text(21.156398104265403, 20.38499999999999, 'mse = 22.025\nsamples = 9\nvalue = 182.556'),
#  Text(25.387677725118486, 20.38499999999999, 'mse = 1.0\nsamples = 2\nvalue = 193.0'),
#  Text(31.734597156398106, 61.15500000000003, 'CYLINDERS <= 0.222\nmse = 75.27\nsamples = 27\nvalue = 166.63'),
#  Text(29.618957345971566, 20.38499999999999, 'mse = 34.022\nsamples = 25\nvalue = 164.76'),
#  Text(33.850236966824646, 20.38499999999999, 'mse = 1.0\nsamples = 2\nvalue = 190.0'),
#  Text(44.42843601895735, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.159\nmse = 40.745\nsamples = 55\nvalue = 181.018'),
#  Text(40.19715639810427, 61.15500000000003, 'FUELTYPE_X <= 0.5\nmse = 37.594\nsamples = 31\nvalue = 179.226'),
#  Text(38.081516587677726, 20.38499999999999, 'mse = 53.471\nsamples = 11\nvalue = 183.727'),
#  Text(42.312796208530806, 20.38499999999999, 'mse = 11.588\nsamples = 20\nvalue = 176.75'),
#  Text(48.65971563981043, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.163\nmse = 35.306\nsamples = 24\nvalue = 183.333'),
#  Text(46.544075829383885, 20.38499999999999, 'mse = 59.76\nsamples = 5\nvalue = 181.8'),
#  Text(50.77535545023697, 20.38499999999999, 'mse = 28.089\nsamples = 19\nvalue = 183.737'),
#  Text(86.21232227488152, 183.465, 'FUELCONSUMPTION_CITY <= 0.206\nmse = 86.865\nsamples = 110\nvalue = 202.555'),
#  Text(69.81611374407584, 142.69500000000002, 'CYLINDERS <= 0.222\nmse = 42.15\nsamples = 54\nvalue = 196.13'),
#  Text(61.35355450236967, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.198\nmse = 22.252\nsamples = 50\nvalue = 195.22'),
#  Text(57.12227488151659, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.19\nmse = 17.256\nsamples = 36\nvalue = 193.722'),
#  Text(55.00663507109005, 20.38499999999999, 'mse = 18.154\nsamples = 21\nvalue = 192.476'),
#  Text(59.23791469194313, 20.38499999999999, 'mse = 10.782\nsamples = 15\nvalue = 195.467'),
#  Text(65.58483412322275, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.202\nmse = 14.495\nsamples = 14\nvalue = 199.071'),
#  Text(63.46919431279621, 20.38499999999999, 'mse = 11.959\nsamples = 7\nvalue = 197.429'),
#  Text(67.70047393364929, 20.38499999999999, 'mse = 11.633\nsamples = 7\nvalue = 200.714'),
#  Text(78.278672985782, 101.92500000000001, 'FUELTYPE_Z <= 0.5\nmse = 151.25\nsamples = 4\nvalue = 207.5'),
#  Text(74.04739336492891, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.188\nmse = 30.25\nsamples = 2\nvalue = 218.5'),
#  Text(71.93175355450238, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 213.0'),
#  Text(76.16303317535545, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 224.0'),
#  Text(82.50995260663507, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.184\nmse = 30.25\nsamples = 2\nvalue = 196.5'),
#  Text(80.39431279620854, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 191.0'),
#  Text(84.62559241706161, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 202.0'),
#  Text(102.60853080568721, 142.69500000000002, 'CYLINDERS <= 0.222\nmse = 51.795\nsamples = 56\nvalue = 208.75'),
#  Text(95.20379146919431, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.218\nmse = 39.501\nsamples = 52\nvalue = 207.865'),
#  Text(90.97251184834124, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.214\nmse = 35.202\nsamples = 21\nvalue = 203.81'),
#  Text(88.8568720379147, 20.38499999999999, 'mse = 32.959\nsamples = 11\nvalue = 201.636'),
#  Text(93.08815165876777, 20.38499999999999, 'mse = 26.76\nsamples = 10\nvalue = 206.2'),
#  Text(99.4350710900474, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.229\nmse = 23.721\nsamples = 31\nvalue = 210.613'),
#  Text(97.31943127962086, 20.38499999999999, 'mse = 27.747\nsamples = 20\nvalue = 209.55'),
#  Text(101.55071090047394, 20.38499999999999, 'mse = 10.612\nsamples = 11\nvalue = 212.545'),
#  Text(110.0132701421801, 101.92500000000001, 'FUELTYPE_Z <= 0.5\nmse = 69.188\nsamples = 4\nvalue = 220.25'),
#  Text(107.89763033175356, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.21\nmse = 2.25\nsamples = 2\nvalue = 228.5'),
#  Text(105.78199052132702, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 227.0'),
#  Text(110.0132701421801, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 230.0'),
#  Text(112.12890995260663, 61.15500000000003, 'mse = 0.0\nsamples = 2\nvalue = 212.0'),
#  Text(158.4085308056872, 224.235, 'FUELCONSUMPTION_CITY <= 0.284\nmse = 367.696\nsamples = 231\nvalue = 241.035'),
#  Text(139.63222748815167, 183.465, 'FUELTYPE_E <= 0.5\nmse = 273.713\nsamples = 109\nvalue = 226.89'),
#  Text(129.05402843601897, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.265\nmse = 134.786\nsamples = 105\nvalue = 229.229'),
#  Text(120.59146919431281, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.249\nmse = 67.007\nsamples = 61\nvalue = 223.328'),
#  Text(116.36018957345972, 61.15500000000003, 'CYLINDERS <= 0.278\nmse = 23.623\nsamples = 24\nvalue = 218.292'),
#  Text(114.24454976303318, 20.38499999999999, 'mse = 20.628\nsamples = 22\nvalue = 218.909'),
#  Text(118.47582938388626, 20.38499999999999, 'mse = 6.25\nsamples = 2\nvalue = 211.5'),
#  Text(124.82274881516588, 61.15500000000003, 'FUELTYPE_Z <= 0.5\nmse = 68.025\nsamples = 37\nvalue = 226.595'),
#  Text(122.70710900473934, 20.38499999999999, 'mse = 87.213\nsamples = 27\nvalue = 227.481'),
#  Text(126.93838862559242, 20.38499999999999, 'mse = 8.36\nsamples = 10\nvalue = 224.2'),
#  Text(137.5165876777251, 101.92500000000001, 'FUELTYPE_Z <= 0.5\nmse = 113.56\nsamples = 44\nvalue = 237.409'),
#  Text(133.28530805687205, 61.15500000000003, 'FUELTYPE_X <= 0.5\nmse = 215.152\nsamples = 16\nvalue = 241.188'),
#  Text(131.1696682464455, 20.38499999999999, 'mse = 2.25\nsamples = 2\nvalue = 276.5'),
#  Text(135.40094786729858, 20.38499999999999, 'mse = 41.98\nsamples = 14\nvalue = 236.143'),
#  Text(141.7478672985782, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.273\nmse = 42.688\nsamples = 28\nvalue = 235.25'),
#  Text(139.63222748815167, 20.38499999999999, 'mse = 20.173\nsamples = 9\nvalue = 230.222'),
#  Text(143.86350710900476, 20.38499999999999, 'mse = 35.706\nsamples = 19\nvalue = 237.632'),
#  Text(150.21042654028437, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.278\nmse = 8.25\nsamples = 4\nvalue = 165.5'),
#  Text(148.09478672985782, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.273\nmse = 2.0\nsamples = 3\nvalue = 164.0'),
#  Text(145.9791469194313, 61.15500000000003, 'mse = 0.0\nsamples = 1\nvalue = 162.0'),
#  Text(150.21042654028437, 61.15500000000003, 'mse = 0.0\nsamples = 2\nvalue = 165.0'),
#  Text(152.3260663507109, 101.92500000000001, 'mse = 0.0\nsamples = 1\nvalue = 170.0'),
#  Text(177.18483412322274, 183.465, 'FUELCONSUMPTION_CITY <= 0.32\nmse = 113.204\nsamples = 122\nvalue = 253.672'),
#  Text(161.84644549763033, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.292\nmse = 97.716\nsamples = 77\nvalue = 249.299'),
#  Text(156.557345971564, 101.92500000000001, 'CYLINDERS <= 0.444\nmse = 133.107\nsamples = 21\nvalue = 243.476'),
#  Text(154.44170616113746, 61.15500000000003, 'FUELTYPE_Z <= 0.5\nmse = 121.747\nsamples = 20\nvalue = 242.55'),
#  Text(152.3260663507109, 20.38499999999999, 'mse = 297.143\nsamples = 7\nvalue = 247.0'),
#  Text(156.557345971564, 20.38499999999999, 'mse = 10.899\nsamples = 13\nvalue = 240.154'),
#  Text(158.67298578199052, 61.15500000000003, 'mse = 0.0\nsamples = 1\nvalue = 262.0'),
#  Text(167.1355450236967, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.308\nmse = 66.964\nsamples = 56\nvalue = 251.482'),
#  Text(162.9042654028436, 61.15500000000003, 'FUELTYPE_Z <= 0.5\nmse = 96.378\nsamples = 29\nvalue = 249.966'),
#  Text(160.78862559241708, 20.38499999999999, 'mse = 152.109\nsamples = 16\nvalue = 252.375'),
#  Text(165.01990521327014, 20.38499999999999, 'mse = 11.846\nsamples = 13\nvalue = 247.0'),
#  Text(171.36682464454978, 61.15500000000003, 'CYLINDERS <= 0.222\nmse = 30.247\nsamples = 27\nvalue = 253.111'),
#  Text(169.25118483412322, 20.38499999999999, 'mse = 58.16\nsamples = 5\nvalue = 258.8'),
#  Text(173.4824644549763, 20.38499999999999, 'mse = 14.876\nsamples = 22\nvalue = 251.818'),
#  Text(192.5232227488152, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.331\nmse = 50.976\nsamples = 45\nvalue = 261.156'),
#  Text(184.060663507109, 101.92500000000001, 'FUELTYPE_Z <= 0.5\nmse = 73.485\nsamples = 26\nvalue = 259.769'),
#  Text(179.82938388625593, 61.15500000000003, 'FUELTYPE_X <= 0.5\nmse = 91.673\nsamples = 19\nvalue = 261.105'),
#  Text(177.7137440758294, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 294.0'),
#  Text(181.94502369668248, 20.38499999999999, 'mse = 33.312\nsamples = 18\nvalue = 259.278'),
#  Text(188.2919431279621, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.325\nmse = 6.122\nsamples = 7\nvalue = 256.143'),
#  Text(186.17630331753554, 20.38499999999999, 'mse = 8.25\nsamples = 4\nvalue = 255.5'),
#  Text(190.40758293838863, 20.38499999999999, 'mse = 2.0\nsamples = 3\nvalue = 257.0'),
#  Text(200.98578199052133, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.335\nmse = 13.945\nsamples = 19\nvalue = 263.053'),
#  Text(196.75450236966824, 61.15500000000003, 'FUELTYPE_X <= 0.5\nmse = 16.876\nsamples = 11\nvalue = 262.182'),
#  Text(194.63886255924172, 20.38499999999999, 'mse = 8.667\nsamples = 3\nvalue = 263.0'),
#  Text(198.8701421800948, 20.38499999999999, 'mse = 19.609\nsamples = 8\nvalue = 261.875'),
#  Text(205.21706161137442, 61.15500000000003, 'FUELTYPE_Z <= 0.5\nmse = 7.438\nsamples = 8\nvalue = 264.25'),
#  Text(203.1014218009479, 20.38499999999999, 'mse = 9.84\nsamples = 5\nvalue = 263.6'),
#  Text(207.33270142180095, 20.38499999999999, 'mse = 1.556\nsamples = 3\nvalue = 265.333'),
#  Text(320.91611374407586, 265.005, 'CYLINDERS <= 0.444\nmse = 2197.174\nsamples = 313\nvalue = 315.447'),
#  Text(263.13270142180096, 224.235, 'FUELTYPE_E <= 0.5\nmse = 538.193\nsamples = 133\nvalue = 280.098'),
#  Text(242.76966824644552, 183.465, 'FUELCONSUMPTION_CITY <= 0.402\nmse = 290.679\nsamples = 99\nvalue = 288.374'),
#  Text(226.37345971563983, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.363\nmse = 101.917\nsamples = 81\nvalue = 282.309'),
#  Text(217.91090047393365, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.351\nmse = 24.724\nsamples = 33\nvalue = 272.939'),
#  Text(213.67962085308056, 61.15500000000003, 'FUELTYPE_Z <= 0.5\nmse = 12.734\nsamples = 16\nvalue = 269.875'),
#  Text(211.56398104265404, 20.38499999999999, 'mse = 9.837\nsamples = 7\nvalue = 268.857'),
#  Text(215.79526066350712, 20.38499999999999, 'mse = 13.556\nsamples = 9\nvalue = 270.667'),
#  Text(222.14218009478674, 61.15500000000003, 'CYLINDERS <= 0.222\nmse = 18.851\nsamples = 17\nvalue = 275.824'),
#  Text(220.0265402843602, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 283.0'),
#  Text(224.25781990521327, 20.38499999999999, 'mse = 16.609\nsamples = 16\nvalue = 275.375'),
#  Text(234.83601895734597, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.39\nmse = 53.146\nsamples = 48\nvalue = 288.75'),
#  Text(230.6047393364929, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.375\nmse = 34.514\nsamples = 33\nvalue = 286.303'),
#  Text(228.48909952606635, 20.38499999999999, 'mse = 35.0\nsamples = 16\nvalue = 284.0'),
#  Text(232.72037914691944, 20.38499999999999, 'mse = 24.367\nsamples = 17\nvalue = 288.471'),
#  Text(239.06729857819906, 61.15500000000003, 'FUELTYPE_X <= 0.5\nmse = 51.982\nsamples = 15\nvalue = 294.133'),
#  Text(236.95165876777253, 20.38499999999999, 'mse = 18.5\nsamples = 4\nvalue = 287.0'),
#  Text(241.18293838862562, 20.38499999999999, 'mse = 38.926\nsamples = 11\nvalue = 296.727'),
#  Text(259.1658767772512, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.445\nmse = 229.667\nsamples = 18\nvalue = 315.667'),
#  Text(251.7611374407583, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.414\nmse = 78.352\nsamples = 14\nvalue = 309.071'),
#  Text(247.52985781990523, 61.15500000000003, 'FUELTYPE_Z <= 0.5\nmse = 58.98\nsamples = 7\nvalue = 304.143'),
#  Text(245.41421800947867, 20.38499999999999, 'mse = 9.188\nsamples = 4\nvalue = 309.75'),
#  Text(249.64549763033176, 20.38499999999999, 'mse = 27.556\nsamples = 3\nvalue = 296.667'),
#  Text(255.99241706161138, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.418\nmse = 49.143\nsamples = 7\nvalue = 314.0'),
#  Text(253.87677725118485, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 322.0'),
#  Text(258.10805687203793, 20.38499999999999, 'mse = 44.889\nsamples = 6\nvalue = 312.667'),
#  Text(266.5706161137441, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.471\nmse = 74.188\nsamples = 4\nvalue = 338.75'),
#  Text(264.45497630331755, 61.15500000000003, 'FUELTYPE_Z <= 0.5\nmse = 12.25\nsamples = 2\nvalue = 330.5'),
#  Text(262.339336492891, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 327.0'),
#  Text(266.5706161137441, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 334.0'),
#  Text(268.6862559241706, 61.15500000000003, 'mse = 0.0\nsamples = 2\nvalue = 347.0'),
#  Text(283.4957345971564, 183.465, 'FUELCONSUMPTION_CITY <= 0.502\nmse = 478.765\nsamples = 34\nvalue = 256.0'),
#  Text(272.9175355450237, 142.69500000000002, 'CYLINDERS <= 0.222\nmse = 141.432\nsamples = 9\nvalue = 225.889'),
#  Text(270.80189573459717, 101.92500000000001, 'mse = 0.0\nsamples = 1\nvalue = 195.0'),
#  Text(275.0331753554502, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.488\nmse = 24.938\nsamples = 8\nvalue = 229.75'),
#  Text(272.9175355450237, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.478\nmse = 9.889\nsamples = 6\nvalue = 227.333'),
#  Text(270.80189573459717, 20.38499999999999, 'mse = 8.667\nsamples = 3\nvalue = 225.0'),
#  Text(275.0331753554502, 20.38499999999999, 'mse = 0.222\nsamples = 3\nvalue = 229.667'),
#  Text(277.1488151658768, 61.15500000000003, 'mse = 0.0\nsamples = 2\nvalue = 237.0'),
#  Text(294.07393364928913, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.573\nmse = 156.294\nsamples = 25\nvalue = 266.84'),
#  Text(285.61137440758296, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.549\nmse = 45.638\nsamples = 14\nvalue = 257.929'),
#  Text(281.38009478672984, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.512\nmse = 5.265\nsamples = 7\nvalue = 252.143'),
#  Text(279.26445497630334, 20.38499999999999, 'mse = 0.0\nsamples = 2\nvalue = 250.0'),
#  Text(283.4957345971564, 20.38499999999999, 'mse = 4.8\nsamples = 5\nvalue = 253.0'),
#  Text(289.842654028436, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.555\nmse = 19.061\nsamples = 7\nvalue = 263.714'),
#  Text(287.7270142180095, 20.38499999999999, 'mse = 0.0\nsamples = 2\nvalue = 259.0'),
#  Text(291.9582938388626, 20.38499999999999, 'mse = 14.24\nsamples = 5\nvalue = 265.6'),
#  Text(302.53649289099525, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.596\nmse = 67.421\nsamples = 11\nvalue = 278.182'),
#  Text(298.3052132701422, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.582\nmse = 23.583\nsamples = 6\nvalue = 271.5'),
#  Text(296.18957345971563, 20.38499999999999, 'mse = 33.5\nsamples = 4\nvalue = 272.0'),
#  Text(300.42085308056875, 20.38499999999999, 'mse = 2.25\nsamples = 2\nvalue = 270.5'),
#  Text(306.76777251184836, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.604\nmse = 2.16\nsamples = 5\nvalue = 286.2'),
#  Text(304.6521327014218, 20.38499999999999, 'mse = 0.0\nsamples = 2\nvalue = 285.0'),
#  Text(308.8834123222749, 20.38499999999999, 'mse = 2.0\nsamples = 3\nvalue = 287.0'),
#  Text(378.6995260663507, 224.235, 'FUELCONSUMPTION_CITY <= 0.476\nmse = 1817.446\nsamples = 180\nvalue = 341.567'),
#  Text(344.84928909952606, 183.465, 'FUELCONSUMPTION_CITY <= 0.437\nmse = 427.998\nsamples = 74\nvalue = 304.689'),
#  Text(327.92417061611377, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.386\nmse = 166.572\nsamples = 44\nvalue = 290.705'),
#  Text(319.4616113744076, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.363\nmse = 80.65\nsamples = 10\nvalue = 271.5'),
#  Text(315.23033175355454, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.351\nmse = 17.36\nsamples = 5\nvalue = 263.2'),
#  Text(313.114691943128, 20.38499999999999, 'mse = 13.25\nsamples = 4\nvalue = 264.5'),
#  Text(317.34597156398104, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 258.0'),
#  Text(323.69289099526065, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.378\nmse = 6.16\nsamples = 5\nvalue = 279.8'),
#  Text(321.57725118483415, 20.38499999999999, 'mse = 1.0\nsamples = 2\nvalue = 277.0'),
#  Text(325.8085308056872, 20.38499999999999, 'mse = 0.889\nsamples = 3\nvalue = 281.667'),
#  Text(336.38672985781994, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.406\nmse = 51.464\nsamples = 34\nvalue = 296.353'),
#  Text(332.15545023696683, 61.15500000000003, 'FUELTYPE_Z <= 0.5\nmse = 27.184\nsamples = 16\nvalue = 292.062'),
#  Text(330.03981042654027, 20.38499999999999, 'mse = 12.25\nsamples = 4\nvalue = 295.5'),
#  Text(334.2710900473934, 20.38499999999999, 'mse = 26.91\nsamples = 12\nvalue = 290.917'),
#  Text(340.618009478673, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.429\nmse = 42.139\nsamples = 18\nvalue = 300.167'),
#  Text(338.50236966824644, 20.38499999999999, 'mse = 33.479\nsamples = 13\nvalue = 298.462'),
#  Text(342.73364928909956, 20.38499999999999, 'mse = 37.44\nsamples = 5\nvalue = 304.6'),
#  Text(361.7744075829384, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.457\nmse = 103.893\nsamples = 30\nvalue = 325.2'),
#  Text(353.31184834123223, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.453\nmse = 41.976\nsamples = 13\nvalue = 318.154'),
#  Text(349.0805687203792, 61.15500000000003, 'FUELTYPE_X <= 0.5\nmse = 44.222\nsamples = 9\nvalue = 316.0'),
#  Text(346.9649289099526, 20.38499999999999, 'mse = 26.333\nsamples = 6\nvalue = 315.0'),
#  Text(351.1962085308057, 20.38499999999999, 'mse = 74.0\nsamples = 3\nvalue = 318.0'),
#  Text(357.54312796208535, 61.15500000000003, 'FUELTYPE_X <= 0.5\nmse = 3.0\nsamples = 4\nvalue = 323.0'),
#  Text(355.4274881516588, 20.38499999999999, 'mse = 3.556\nsamples = 3\nvalue = 322.667'),
#  Text(359.65876777251185, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 324.0'),
#  Text(370.2369668246446, 101.92500000000001, 'FUELTYPE_Z <= 0.5\nmse = 84.242\nsamples = 17\nvalue = 330.588'),
#  Text(366.00568720379147, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.465\nmse = 8.688\nsamples = 4\nvalue = 338.75'),
#  Text(363.89004739336497, 20.38499999999999, 'mse = 0.0\nsamples = 2\nvalue = 336.0'),
#  Text(368.121327014218, 20.38499999999999, 'mse = 2.25\nsamples = 2\nvalue = 341.5'),
#  Text(374.46824644549764, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.473\nmse = 80.686\nsamples = 13\nvalue = 328.077'),
#  Text(372.3526066350711, 20.38499999999999, 'mse = 81.521\nsamples = 12\nvalue = 328.75'),
#  Text(376.5838862559242, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 320.0'),
#  Text(412.5497630331754, 183.465, 'FUELTYPE_E <= 0.5\nmse = 1175.252\nsamples = 106\nvalue = 367.311'),
#  Text(395.62464454976305, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.571\nmse = 878.172\nsamples = 77\nvalue = 376.506'),
#  Text(387.1620853080569, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.508\nmse = 246.448\nsamples = 51\nvalue = 359.941'),
#  Text(382.9308056872038, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.502\nmse = 68.651\nsamples = 17\nvalue = 343.235'),
#  Text(380.81516587677726, 20.38499999999999, 'mse = 38.222\nsamples = 12\nvalue = 341.333'),
#  Text(385.0464454976304, 20.38499999999999, 'mse = 112.16\nsamples = 5\nvalue = 347.8'),
#  Text(391.39336492891, 61.15500000000003, 'FUELTYPE_X <= 0.5\nmse = 126.031\nsamples = 34\nvalue = 368.294'),
#  Text(389.27772511848343, 20.38499999999999, 'mse = 93.778\nsamples = 19\nvalue = 362.105'),
#  Text(393.5090047393365, 20.38499999999999, 'mse = 56.916\nsamples = 15\nvalue = 376.133'),
#  Text(404.0872037914692, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.663\nmse = 523.231\nsamples = 26\nvalue = 409.0'),
#  Text(399.8559241706161, 61.15500000000003, 'FUELTYPE_X <= 0.5\nmse = 185.048\nsamples = 21\nvalue = 401.0'),
#  Text(397.7402843601896, 20.38499999999999, 'mse = 127.361\nsamples = 13\nvalue = 393.846'),
#  Text(401.97156398104266, 20.38499999999999, 'mse = 60.484\nsamples = 8\nvalue = 412.625'),
#  Text(408.3184834123223, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.731\nmse = 545.84\nsamples = 5\nvalue = 442.6'),
#  Text(406.2028436018958, 20.38499999999999, 'mse = 38.188\nsamples = 4\nvalue = 431.25'),
#  Text(410.43412322274884, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 488.0'),
#  Text(429.4748815165877, 142.69500000000002, 'FUELCONSUMPTION_CITY <= 0.737\nmse = 1143.472\nsamples = 29\nvalue = 342.897'),
#  Text(421.0123222748815, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.671\nmse = 305.5\nsamples = 8\nvalue = 301.0'),
#  Text(416.78104265402845, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.624\nmse = 58.25\nsamples = 4\nvalue = 284.5'),
#  Text(414.6654028436019, 20.38499999999999, 'mse = 0.0\nsamples = 2\nvalue = 277.0'),
#  Text(418.896682464455, 20.38499999999999, 'mse = 4.0\nsamples = 2\nvalue = 292.0'),
#  Text(425.2436018957346, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.712\nmse = 8.25\nsamples = 4\nvalue = 317.5'),
#  Text(423.12796208530807, 20.38499999999999, 'mse = 2.0\nsamples = 3\nvalue = 316.0'),
#  Text(427.35924170616113, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 322.0'),
#  Text(437.93744075829386, 101.92500000000001, 'FUELCONSUMPTION_CITY <= 0.908\nmse = 539.265\nsamples = 21\nvalue = 358.857'),
#  Text(433.7061611374408, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.802\nmse = 86.719\nsamples = 18\nvalue = 350.056'),
#  Text(431.59052132701424, 20.38499999999999, 'mse = 38.576\nsamples = 12\nvalue = 344.917'),
#  Text(435.8218009478673, 20.38499999999999, 'mse = 24.556\nsamples = 6\nvalue = 360.333'),
#  Text(442.1687203791469, 61.15500000000003, 'FUELCONSUMPTION_CITY <= 0.996\nmse = 0.889\nsamples = 3\nvalue = 411.667'),
#  Text(440.0530805687204, 20.38499999999999, 'mse = 0.0\nsamples = 2\nvalue = 411.0'),
#  Text(444.2843601895735, 20.38499999999999, 'mse = 0.0\nsamples = 1\nvalue = 413.0')]

# %% [markdown]
# <a id=section733></a>

# %% [markdown]
# ### 7.3.3 FInding out RMSE and Adjusted R-squared for Train and Test Linear Regression Model

# %% [markdown]
# ### RMSE

# %%
#finding RMSE values
from sklearn import metrics
RMSE_train_dt_m3=np.sqrt(metrics.mean_squared_error(y_train,y_train_pred_dt3))
print('The RMSE value of Train dataset for Decision Tree Grid Search Model is :',RMSE_train_dt_m3)
# Out:
# The RMSE value of Train dataset for Decision Tree Grid Search Model is : 3.6269251570753847

# %%
#finding RMSE values
from sklearn import metrics
RMSE_test_dt_m3=np.sqrt(metrics.mean_squared_error(y_test,y_test_pred_dt3))
print('The RMSE value of Test dataset for Decision Tree Grid Search Model is :',RMSE_test_dt_m3)
# Out:
# The RMSE value of Test dataset for Decision Tree Grid Search Model is : 7.686317843797969

# %% [markdown]
# #### R-squared

# %%
from sklearn.metrics import r2_score
r2_m3_train=r2_score(y_train, y_train_pred_dt3)
print('The R-square value of Train dataset for Decision Tree Grid Search Model is :',r2_m3_train)
# Out:
# The R-square value of Train dataset for Decision Tree Grid Search Model is : 0.9967032357291271

# %%
from sklearn.metrics import r2_score
r2_m3_test=r2_score(y_test, y_test_pred_dt3)
print('The R-square value of Test dataset for Decision Tree Grid Search Model is :',r2_m3_test)
# Out:
# The R-square value of Test dataset for Decision Tree Grid Search Model is : 0.9853461173461516

# %% [markdown]
# #### Adjusted R-squared

# %%
adj_r2_train=Adjusted_r2(r2_m3_train,len(X_train))
print('The Adjusted R-square of Decision Tree GridSearch model Train Dataset for the second model is :', adj_r2_train)
adj_r2_test=Adjusted_r2(r2_m3_test,len(X_test))
print('The Adjusted R-square of Decision Tree Test GridSearch model Test Dataset for the second model is :', adj_r2_test)
# Out:
# The Adjusted R-square of Decision Tree GridSearch model Train Dataset for the second model is : 0.9966814028531611
# The Adjusted R-square of Decision Tree Test GridSearch model Test Dataset for the second model is : 0.9849500664636152

# %% [markdown]
# <a id=section74></a>

# %% [markdown]
# ## 7.4 Summary of Decision Tree

# %% [markdown]
# The summary of the 3 Decision Tree Models we have for the train and test dataset details as under
#
# |Model Name||RMSE Score Train||RMSE Score Test ||R-square Value Train||R-square Value Test||Adjusted R-squared Train||Adjusted R-square Test|
# |---------||------------||-------------||------||-------------||--------||--------|
# |Decision Tree Moidel-1|| 3.5162  ||8.3830|| 0.9969   ||0.9825||0.9968||0.9819|
# |Decision Tree Model-2|| 5.9540  ||8.4839|| 0.9911    ||0.9821||0.9910||0.9819|
# |GridSearchCV Model|| 3.6269 ||7.6863||  0.9967  ||0.9853|| 0.9966||0.9849|

# %% [markdown]
# **Based on the R2 Score for test data, we can say that Decision Tree GridSearchCV model is the best model**

# %% [markdown]
# <a id=section8></a>

# %% [markdown]
# ## 8.Random Forest Regressor

# %% [markdown]
# Developing and understanding few models under Random Forest to check if we can get beter models

# %% [markdown]
# <a id=section81></a>

# %% [markdown]
# ### 8.1 Random Forest Model 1

# %% [markdown]
# <a id=section811></a>

# %% [markdown]
# ### 8.1.1 Model Development

# %%
from sklearn.ensemble import RandomForestRegressor
model_rf1 = RandomForestRegressor(random_state = 0)
model_rf1.fit(X_train_s, y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
y_pred_train_rf1 = model_rf1.predict(X_train_s)
y_pred_test_rf1 = model_rf1.predict(X_test_s)

# %% [markdown]
#  <a id=section812></a>

# %% [markdown]
# ### 8.1.2 Plotting the model

# %%
sns.lineplot(x=y_test, y=y_pred_test_rf1)
plt.title('Random Forest Model 1')
plt.xlabel(' Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %% [markdown]
# <a id=section813></a>

# %% [markdown]
# ### 8.1.3 FInding out RMSE and Adjusted R-squared for Train and Test Linear Regression Model

# %% [markdown]
# #### RMSE

# %%
#finding RMSE values
from sklearn import metrics
RMSE_train_rf1=np.sqrt(metrics.mean_squared_error(y_train,y_pred_train_rf1))
RMSE_test_rf1=np.sqrt(metrics.mean_squared_error(y_test,y_pred_test_rf1))
print('RMSE of Random Forest Model 1 for train dataset : ',RMSE_train_rf1)
print('RMSE of Random Forest Model 1 for test dataset : ',RMSE_test_rf1)
# Out:
# RMSE of Random Forest Model 1 for train dataset :  4.240950227529691
# RMSE of Random Forest Model 1 for test dataset :  7.996334987332707

# %% [markdown]
# #### R-squared

# %%
from sklearn.metrics import r2_score
r2_rf1_train=r2_score(y_train, y_pred_train_rf1)
r2_rf1_test=r2_score(y_test, y_pred_test_rf1)
print('The R-square Value of train dataset of Simple Random Forest Model is :',r2_rf1_train)
print('The R-square Value of test dataset of Simple Random Forest Model is :',r2_rf1_test)
# Out:
# The R-square Value of train dataset of Simple Random Forest Model is : 0.9954924862706905
# The R-square Value of test dataset of Simple Random Forest Model is : 0.9841401896499649

# %% [markdown]
# #### Adjusted R-squared

# %%
adj_r2_train=Adjusted_r2(r2_rf1_train,len(X_train))
print('The Adjusted R-square of Random Forest Train Dataset for the first model is :', adj_r2_train)
adj_r2_test=Adjusted_r2(r2_rf1_test,len(X_test))
print('The Adjusted R-square of Random Forest Test Dataset for the first model is :', adj_r2_test)
# Out:
# The Adjusted R-square of Random Forest Train Dataset for the first model is : 0.9954626351863904
# The Adjusted R-square of Random Forest Test Dataset for the first model is : 0.983711546126991

# %% [markdown]
# #### Plotting the data

# %%
sns.lineplot(x=y_test, y=y_pred_test_rf1)
plt.title('Random Forest Model 1')
plt.xlabel(' Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %% [markdown]
# ### 8.2 Random Forest Model 2

# %% [markdown]
# <a id=section821></a>

# %% [markdown]
# ### 8.2.1 Model Development

# %%
model_rf2 = RandomForestRegressor(random_state = 0,
                                n_estimators = 15,
                                min_samples_split = 2,
                                min_samples_leaf = 1)

model_rf2.fit(X_train_s, y_train)
# Out:
# RandomForestRegressor(n_estimators=15, random_state=0)

# %%
y_pred_train_rf2 = model_rf2.predict(X_train_s)
y_pred_test_rf2 = model_rf2.predict(X_test_s)

# %% [markdown]
# <a id=section822></a>

# %% [markdown]
# ### 8.2.2 Plotting the model

# %%
sns.lineplot(x=y_test, y=y_pred_test_rf2)
plt.title('Random Forest Model 2')
plt.xlabel(' Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %% [markdown]
# <a id=section823></a>
# ### 8.2.3 FInding out RMSE and Adjusted R-squared for Train and Test Linear Regression Model

# %% [markdown]
# #### RMSE

# %%
#finding RMSE values
from sklearn import metrics
RMSE_train_rf2=np.sqrt(metrics.mean_squared_error(y_train,y_pred_train_rf2))
RMSE_test_rf2=np.sqrt(metrics.mean_squared_error(y_test,y_pred_test_rf2))
print('RMSE value of Random Forest model 2 for train dataset is : ',RMSE_train_rf2)
print('RMSE value of Random Forest model 2 for test dataset is : ',RMSE_test_rf2)
# Out:
# RMSE value of Random Forest model 2 for train dataset is :  4.391458058801435
# RMSE value of Random Forest model 2 for test dataset is :  8.016600149547628

# %% [markdown]
# #### R-squared

# %%
from sklearn.metrics import r2_score
r2_rf2_train=r2_score(y_train, y_pred_train_rf2)
r2_rf2_test=r2_score(y_test, y_pred_test_rf2)
print('The R-square value of train dataset of Random Forest 2nd Model is :',r2_rf2_train)
print('The R-square value of test dataset of Random Forest 2nd Model is :',r2_rf2_test)
# Out:
# The R-square value of train dataset of Random Forest 2nd Model is : 0.9951668732389738
# The R-square value of test dataset of Random Forest 2nd Model is : 0.984059700552137

# %% [markdown]
# #### Adjusted R-squared

# %%
adj_r2_train=Adjusted_r2(r2_rf2_train,len(X_train))
print('The Adjusted R-square of Random Forest Train Dataset for the second model is :', adj_r2_train)
adj_r2_test=Adjusted_r2(r2_rf2_test,len(X_test))
print('The Adjusted R-square of Random Forest Test Dataset for the second model is :', adj_r2_test)
# Out:
# The Adjusted R-square of Random Forest Train Dataset for the second model is : 0.9951348657769803
# The Adjusted R-square of Random Forest Test Dataset for the second model is : 0.9836288816481407

# %% [markdown]
# <a id=section83></a>

# %% [markdown]
# ### 8.3 Random Forest Model 3

# %% [markdown]
# <a id=section831></a>

# %% [markdown]
# ### 8.3.1 Model Development

# %% [markdown]
# Here we sue the most popular python search module called ```RandomizedSearchCV``` to iterate over all possible parameters and give us the best model there is for the dataset

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint as sp_randint
# parameters for GridSearchCV
# specify parameters and distributions to sample from
param_dist = {"max_depth": range(2,100),
              "min_samples_split": sp_randint(2, 11),
              "min_samples_leaf": sp_randint(1, 11),
              "bootstrap": [True, False],
              "n_estimators": [100, 400, 700, 1000, 1500],
              "criterion" : ["mse", "friedman_mse", "mae"],
              'max_features': ["auto", "sqrt", "log2"]
             }
# run randomized search
n_iter_search = 50
random_search = RandomizedSearchCV(model_rf2, param_distributions = param_dist,
                                   n_iter = n_iter_search,
                                   n_jobs = -1)

# %%
random_search.fit(X_train_s, y_train)
# Out:
# RandomizedSearchCV(estimator=RandomForestRegressor(n_estimators=15,
#                                                    random_state=0),
#                    n_iter=50, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['mse', 'friedman_mse',
#                                                       'mae'],
#                                         'max_depth': range(2, 100),
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000086A037D7F0>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000086A037D550>,
#                                         'n_estimators': [100, 400, 700, 1000,
#                                                          1500]})

# %%
y_pred_test_rf3 = random_search.predict(X_test_s)
y_pred_train_rf3=random_search.predict(X_train_s)

# %% [markdown]
# <a id=section832></a>

# %% [markdown]
# ### 8.3.2 Plotting the data

# %%
sns.lineplot(x=y_test, y=y_pred_test_rf2)
plt.title('RandomizedSearchCV Model')
plt.xlabel(' Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %% [markdown]
# <a id=section833></a>

# %% [markdown]
# ### 8.3.3 FInding out RMSE and Adjusted R-squared for Train and Test Linear Regression Model

# %% [markdown]
# #### RMSE

# %%
#finding RMSE values
from sklearn import metrics
RMSE_train_rf3=np.sqrt(metrics.mean_squared_error(y_train,y_pred_train_rf3))
RMSE_test_rf3=np.sqrt(metrics.mean_squared_error(y_test,y_pred_test_rf3))
print('RMSE value of Random Forest model 3 for train dataset is : ',RMSE_train_rf3)
print('RMSE value of Random Forest model 3 for test dataset is : ',RMSE_test_rf3)
# Out:
# RMSE value of Random Forest model 3 for train dataset is :  4.133544891157034
# RMSE value of Random Forest model 3 for test dataset is :  8.921806813408319

# %% [markdown]
# #### R-squared

# %%
from sklearn.metrics import r2_score
r2_rf3_train=r2_score(y_train, y_pred_train_rf3)
r2_rf3_test=r2_score(y_test, y_pred_test_rf3)
print('The R-square Value of train dataset of Random Forest 3rd Model is :',r2_rf3_train)
print('The R-square Value of test dataset of Random Forest 3rd Model is :',r2_rf3_test)
# Out:
# The R-square Value of train dataset of Random Forest 3rd Model is : 0.9957179077006807
# The R-square Value of test dataset of Random Forest 3rd Model is : 0.9802566128899721

# %% [markdown]
# #### Adjusted R-squared

# %%
adj_r2_train=Adjusted_r2(r2_rf3_train,len(X_train))
print('The Adjusted R-square of Random Forest Train Dataset for the Randomized Search model is :', adj_r2_train)
adj_r2_test=Adjusted_r2(r2_rf3_test,len(X_test))
print('The Adjusted R-square of Random Forest Test Dataset for the Randomized Search model is :', adj_r2_test)
# Out:
# The Adjusted R-square of Random Forest Train Dataset for the Randomized Search model is : 0.9956895494735328
# The Adjusted R-square of Random Forest Test Dataset for the Randomized Search model is : 0.9797230078329443

# %% [markdown]
# <a id=section84></a>

# %% [markdown]
# ### 8.4 Summary of Random Forest

# %% [markdown]
# The summary of the 3 Random Forest Models we have the test dataset are as under;
#
# |Model Name||RMSE Score Train||RMSE Score test||R-square Value train|| R-square value test||Adjusted R-squared Train||Adjusted R-squared test|
# |---------||------------||-------------||----------||-------------||-------||------|
# |Random Forest Model-1||  4.2409  ||7.9963||  0.9954      ||0.9841||0.9954||0.9837|
# |Random Forest Mode2-2|| 4.3914    ||8.0166||  0.9951      ||0.9840||0.9951||0.9836|
# |RandomizedSearchCV Model||  4.0816 ||88103||   0.9958    ||0.9807||0.9957||0.9802|

# %% [markdown]
# <a id=section9></a>

# %% [markdown]
# ## 9. Conclusion

# %% [markdown]
# To sum up, we have developed a total of 7 models under Linear Regression, Decision Tree and Random Forest. We trained these models with our train dataset and tested each models with our test dataset. Each model gave us excellent results with an accuracy of >97%.
#
# The RMSE and R2 Score for each models for train and test datasets are as under;
#
# |Sl. No.|| Model Name || RMSE Score Test || R-square Value test || Adjusted R-squared test|
# |----||---------||------------||-------------||----------|
# |1|| Linear Regression Model|| 8.2269||0.9832||0.9827|
# |2|| Decision Tree Model-1|| 8.3830||0.9825||0.9820|
# |3|| Decision Tree Model-2|| 8.4839||0.9821||0.9816|
# |4|| GridSearchCV Model|| 7.6863||0.9853||0.9849|
# |5|| Random Forest Model-1|| 7.9963||0.9841||0.9837|
# |6|| Random Forest Model-2||8.0166||0.9840||0.9836|
# |7|| Randomized Search Model||8.8103||0.9807||0.9802|

# %% [markdown]
# **Therefore based on R2 score, GridSearchCV- model is the best model for this dataset**
